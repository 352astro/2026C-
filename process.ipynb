# %%
import pandas as pd

# %%
# 区别season和year
# 读取CSV文件
df = pd.read_csv('2026_MCM_Problem_C_Data.csv')

# 定义season到年份的映射函数
def season_to_year(season):
    """
    映射规则：
    - Season 1 = 2005
    - Season 2-27 = 2006-2018 (每年2季)
    - Season 28-34 = 2019-2025 (每年1季)
    """
    if season == 1:
        return 2005
    elif 2 <= season <= 27:
        # 2006-2018年，每年2季
        # Season 2-3 -> 2006, Season 4-5 -> 2007, ...
        return 2005 + (season - 2) // 2 + 1
    elif season >= 28:
        # 2019-2025年，每年1季
        return 2019 + (season - 28)
    else:
        return None

# 添加年份列
df['year'] = df['season'].apply(season_to_year)

# 提取需要的列：celebrity_name, ballroom_partner, season, year
df_filtered = df[['celebrity_name', 'ballroom_partner', 'season', 'year']]

# 保存处理后的数据到新文件
df_filtered.to_csv('name.csv', index=False)

print(f"处理完成！共处理了 {len(df_filtered)} 行数据")
print("处理后的数据已保存到: name.csv")
print("\n前10行数据预览:")
print(df_filtered.head(10))
print("\n各season对应的年份:")
print(df_filtered[['season', 'year']].drop_duplicates().sort_values('season'))
# Out:
# 处理完成！共处理了 421 行数据
# 处理后的数据已保存到: name.csv
#
# 前10行数据预览:
#       celebrity_name     ballroom_partner  season  year
# 0      John O'Hurley  Charlotte Jorgensen       1  2005
# 1       Kelly Monaco            Alec Mazo       1  2005
# 2  Evander Holyfield      Edyta Sliwinska       1  2005
# 3      Rachel Hunter     Jonathan Roberts       1  2005
# 4      Joey McIntyre      Ashly DelGrosso       1  2005
# 5      Trista Sutter     Louis van Amstel       1  2005
# 6       Tatum O'Neal        Nick Kosovich       2  2006
# 7        Tia Carrere   Maksim Chmerkoskiy       2  2006
# 8    George Hamilton      Edyta Sliwinska       2  2006
# 9         Lisa Rinna     Louis van Amstel       2  2006
#
# 各season对应的年份:
#      season  year
# 0         1  2005
# 6         2  2006
# 16        3  2006
# 27        4  2007
# 38        5  2007
# 50        6  2008
# 62        7  2008
# 75        8  2009
# 88        9  2009
# 104      10  2010
# 115      11  2010
# 127      12  2011
# 138      13  2011
# 150      14  2012
# 162      15  2012
# 175      16  2013
# 187      17  2013
# 199      18  2014
# 211      19  2014
# 224      20  2015
# 236      21  2015
# 249      22  2016
# 261      23  2016
# 274      24  2017
# 286      25  2017
# 299      26  2018
# 309      27  2018
# 322      28  2019
# 334      29  2020
# 349      30  2021
# 364      31  2022
# 380      32  2023
# 394      33  2024
# 407      34  2025

# %%
# 统计所有ballroom_partner的姓名并去重
# 如果df_filtered存在，直接使用；否则从name.csv读取
if 'df_filtered' in globals():
    partners = df_filtered['ballroom_partner'].unique()
else:
    df_name = pd.read_csv('name.csv')
    partners = df_name['ballroom_partner'].unique()

# 创建DataFrame并保存
df_partners = pd.DataFrame({'partner_name': sorted(partners)})
df_partners.to_csv('partner_name.csv', index=False)

print(f"统计完成！共找到 {len(partners)} 个不同的舞伴")
print("去重后的舞伴姓名已保存到: partner_name.csv")
print("\n前10个舞伴姓名:")
print(df_partners.head(10))
# Out:
# 统计完成！共找到 60 个不同的舞伴
# 去重后的舞伴姓名已保存到: partner_name.csv
#
# 前10个舞伴姓名:
#                             partner_name
# 0                           Alan Bersten
# 1  Alan Bersten (Rashad Jennings week 9)
# 2                              Alec Mazo
# 3                         Allison Holker
# 4                            Andrea Hale
# 5                          Anna Demidova
# 6                       Anna Trebunskaya
# 7                      Artem Chigvintsev
# 8                        Ashly DelGrosso
# 9                      Brandon Armstrong

# %%
#示例爬取
import wikipedia
import requests
import pandas as pd
import time
from urllib.parse import quote
from datetime import datetime, timedelta

def get_yearly_pageviews(page_title, year):
    # 1. 标题规范化
    page_title = page_title.replace(" ", "_")
    page_title = quote(page_title, safe="")

    url = (
        "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/"
        f"en.wikipedia.org/all-access/all-agents/"
        f"{page_title}/monthly/"
        f"{year}0101/{year}1231"
    )

    headers = {
        "User-Agent": "Academic-Research-Bot/1.0 (contact: your_email@example.com)"
    }

    r = requests.get(url, headers=headers)

    if r.status_code != 200:
        print("Pageviews API failed:")
        print("URL:", url)
        print("Status:", r.status_code)
        print("Response:", r.text)
        return None

    items = r.json().get("items", [])
    return sum(item["views"] for item in items)

def get_yearly_edit_count(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的编辑次数
    """
    url = "https://en.wikipedia.org/w/api.php"

    start = f"{year}-01-01T00:00:00Z"
    end = f"{year}-12-31T23:59:59Z"

    params = {
        "action": "query",
        "format": "json",
        "prop": "revisions",
        "titles": page_title,
        "rvstart": end,      # 注意：先新后旧
        "rvend": start,
        "rvlimit": "max"
    }

    headers = {
        "User-Agent": "Academic-Research-Bot/1.0 (contact: your_email@example.com)"
    }

    total_edits = 0

    while True:
        r = requests.get(url, params=params, headers=headers)
        data = r.json()

        pages = data["query"]["pages"]
        page_data = next(iter(pages.values()))

        if "revisions" in page_data:
            total_edits += len(page_data["revisions"])

        if "continue" in data:
            params.update(data["continue"])
        else:
            break

    return total_edits


wikipedia.set_lang("en")  # 设置为英文维基，如需中文改为"zh"

# 获取前5个celebrity_name
if 'df_filtered' in globals():
    celebrities = df_filtered['celebrity_name'].head(5).tolist()
else:
    df_name = pd.read_csv('name.csv')
    celebrities = df_name['celebrity_name'].head(5).tolist()

print(f"查询前5个名人: {celebrities}\n")

results = []

for name in celebrities:
    search_results = wikipedia.search(name)
    # print(f"搜索结果列表{search_results}")

    page=wikipedia.page(search_results[0], auto_suggest=False)
    print("---匹配结果---")
    print(f"页面标题：{page.title}")
    print(f"页面URL：{page.url}")
    print(f"页面摘要：{page.summary[:100]}")

    year = 2023
    views = get_yearly_pageviews(page.title, year)
    print(f"{page.title} 在 {year} 年的浏览量：{views}")

    edit_counts=get_yearly_edit_count("Donald Trump", year)
    print(f"{page.title} 在 {year} 年的编辑次数：{edit_counts}")
# Out:
# 查询前5个名人: ["John O'Hurley", 'Kelly Monaco', 'Evander Holyfield', 'Rachel Hunter', 'Joey McIntyre']
#
# ---匹配结果---
# 页面标题：John O'Hurley
# 页面URL：https://en.wikipedia.org/wiki/John_O%27Hurley
# 页面摘要：John George O'Hurley Jr. (born October 9, 1954) is an American actor and game show host. He played J
# John O'Hurley 在 2023 年的浏览量：388916
# John O'Hurley 在 2023 年的编辑次数：1863
# ---匹配结果---
# 页面标题：Kelly Monaco
# 页面URL：https://en.wikipedia.org/wiki/Kelly_Monaco
# 页面摘要：Kelly Marie Monaco (born May 23, 1976) is an American actress, model, and reality television persona
# Kelly Monaco 在 2023 年的浏览量：254426
# Kelly Monaco 在 2023 年的编辑次数：1863
# ---匹配结果---
# 页面标题：Evander Holyfield
# 页面URL：https://en.wikipedia.org/wiki/Evander_Holyfield
# 页面摘要：Evander Holyfield (born October 19, 1962) is an American former professional boxer who competed betw
# Evander Holyfield 在 2023 年的浏览量：1331834
# Evander Holyfield 在 2023 年的编辑次数：1863
# ---匹配结果---
# 页面标题：Rachel Hunter
# 页面URL：https://en.wikipedia.org/wiki/Rachel_Hunter
# 页面摘要：Rachel Hunter (born 8 September 1969) is a New Zealand model, actress, and the host of Imagination T
# Rachel Hunter 在 2023 年的浏览量：622236
# Rachel Hunter 在 2023 年的编辑次数：1863
# ---匹配结果---
# 页面标题：Joey McIntyre
# 页面URL：https://en.wikipedia.org/wiki/Joey_McIntyre
# 页面摘要：Joseph Mulrey McIntyre (born December 31, 1972) is an American singer-songwriter and actor. He is be
# Joey McIntyre 在 2023 年的浏览量：408759
# Joey McIntyre 在 2023 年的编辑次数：1863

# %%
#整理最终处理数据
import wikipedia
import requests
import pandas as pd
import time
from urllib.parse import quote
from datetime import datetime

# 设置维基百科语言为英文
wikipedia.set_lang("en")

def get_yearly_pageviews(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的总浏览量
    """
    try:
        page_title = page_title.replace(" ", "_")
        page_title = quote(page_title, safe="")
        
        url = (
            "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/"
            f"en.wikipedia.org/all-access/all-agents/"
            f"{page_title}/monthly/"
            f"{year}0101/{year}1231"
        )
        
        headers = {
            "User-Agent": "Academic-Research-Bot/1.0"
        }
        
        r = requests.get(url, headers=headers, timeout=10)
        
        if r.status_code != 200:
            return 0
        
        items = r.json().get("items", [])
        return sum(item["views"] for item in items)
    except Exception as e:
        return 0

def get_yearly_edit_count(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的编辑次数
    """
    try:
        url = "https://en.wikipedia.org/w/api.php"
        
        start = f"{year}-01-01T00:00:00Z"
        end = f"{year}-12-31T23:59:59Z"
        
        params = {
            "action": "query",
            "format": "json",
            "prop": "revisions",
            "titles": page_title,
            "rvstart": end,
            "rvend": start,
            "rvlimit": "max"
        }
        
        headers = {
            "User-Agent": "Academic-Research-Bot/1.0"
        }
        
        total_edits = 0
        
        while True:
            r = requests.get(url, params=params, headers=headers, timeout=10)
            data = r.json()
            
            if "query" not in data or "pages" not in data["query"]:
                break
                
            pages = data["query"]["pages"]
            if not pages:
                break
                
            page_data = next(iter(pages.values()))
            
            if "revisions" in page_data:
                total_edits += len(page_data["revisions"])
            
            if "continue" in data:
                params.update(data["continue"])
            else:
                break
        
        return total_edits
    except Exception as e:
        return 0

def get_cumulative_stats_for_partner(page_title, target_year):
    """
    获取舞伴页面在target_year及之前所有年份的累计浏览量和编辑次数
    """
    total_pageviews = 0
    total_edits = 0
    
    # 从2005年开始统计（因为第一季是2005年）
    start_year = 2005
    current_year = datetime.now().year
    
    # 只统计到target_year
    end_year = min(target_year, current_year)
    
    # 统计从2005年到target_year的累计数据
    for year in range(start_year, end_year + 1):
        year_views = get_yearly_pageviews(page_title, year)
        year_edits = get_yearly_edit_count(page_title, year)
        
        total_pageviews += year_views
        total_edits += year_edits
        
        # 避免请求过快
        time.sleep(0.3)
    
    return total_pageviews, total_edits

# 读取数据
print("="*60)
print("读取数据文件...")
print("="*60)

df_name = pd.read_csv('name.csv')
df_celebrity_stats = pd.read_csv('celebrity_wikipedia_stats.csv')

print(f"name.csv: {len(df_name)} 行")
print(f"celebrity_wikipedia_stats.csv: {len(df_celebrity_stats)} 行")

# 合并数据（基于celebrity_name, season, year）
df_merged = df_name.merge(
    df_celebrity_stats[['celebrity_name', 'season', 'year', 'total_pageviews', 'total_edits']],
    on=['celebrity_name', 'season', 'year'],
    how='left'
)

print(f"\n合并后数据: {len(df_merged)} 行")

# 重命名列以便区分
df_merged = df_merged.rename(columns={
    'total_pageviews': 'celebrity_total_pageviews',
    'total_edits': 'celebrity_total_edits'
})

# 获取所有唯一的舞伴及其对应的年份
print("\n" + "="*60)
print("分析舞伴数据...")
print("="*60)

# 为每个舞伴找到其最早出现的年份（用于查询累计数据）
partner_years = df_merged.groupby('ballroom_partner')['year'].min().to_dict()
unique_partners = df_merged['ballroom_partner'].unique()

print(f"找到 {len(unique_partners)} 个不同的舞伴")

# 查询每个舞伴的维基百科统计数据
print("\n" + "="*60)
print("开始查询舞伴的维基百科数据...")
print("="*60)
print("注意：每个舞伴需要查询多个年份的数据，请耐心等待...\n")

partner_stats = {}
partner_page_titles = {}

for idx, partner_name in enumerate(unique_partners, 1):
    year = partner_years[partner_name]
    
    print(f"[{idx}/{len(unique_partners)}] 查询舞伴: {partner_name} (最早出现年份: {year})")
    
    try:
        # 搜索维基百科页面
        search_results = wikipedia.search(partner_name, results=5)
        
        if not search_results:
            print(f"  ✗ 未找到页面")
            partner_stats[partner_name] = {
                'wikipedia_title': 'Not Found',
                'total_pageviews': 0,
                'total_edits': 0,
                'status': 'Not Found'
            }
            partner_page_titles[partner_name] = None
            continue
        
        # 尝试使用第一个搜索结果
        page = None
        for search_result in search_results:
            try:
                page = wikipedia.page(search_result, auto_suggest=False)
                # 验证页面标题是否匹配（简单检查）
                if partner_name.lower() in page.title.lower() or page.title.lower() in partner_name.lower():
                    break
            except:
                continue
        
        if page is None:
            # 如果都失败，使用第一个结果
            page = wikipedia.page(search_results[0], auto_suggest=False)
        
        print(f"  ✓ 找到页面: {page.title}")
        partner_page_titles[partner_name] = page.title
        
        # 获取累计统计（到对应年份及之前）
        total_pageviews, total_edits = get_cumulative_stats_for_partner(page.title, year)
        
        print(f"  ✓ 累计浏览量（至{year}年）: {total_pageviews:,}")
        print(f"  ✓ 累计编辑次数（至{year}年）: {total_edits:,}\n")
        
        partner_stats[partner_name] = {
            'wikipedia_title': page.title,
            'total_pageviews': total_pageviews,
            'total_edits': total_edits,
            'status': 'Success'
        }
        
        # 避免请求过快
        time.sleep(1)
        
    except wikipedia.exceptions.DisambiguationError as e:
        print(f"  ✗ 存在歧义，尝试第一个选项: {e.options[0] if e.options else 'N/A'}")
        try:
            if e.options:
                page = wikipedia.page(e.options[0], auto_suggest=False)
                total_pageviews, total_edits = get_cumulative_stats_for_partner(page.title, year)
                partner_stats[partner_name] = {
                    'wikipedia_title': page.title,
                    'total_pageviews': total_pageviews,
                    'total_edits': total_edits,
                    'status': 'Disambiguation'
                }
                partner_page_titles[partner_name] = page.title
                print(f"  ✓ 使用歧义选项: {page.title}\n")
            else:
                partner_stats[partner_name] = {
                    'wikipedia_title': 'Disambiguation Error',
                    'total_pageviews': 0,
                    'total_edits': 0,
                    'status': 'Disambiguation Error'
                }
                partner_page_titles[partner_name] = None
        except Exception as e2:
            print(f"  ✗ 处理歧义失败: {str(e2)}\n")
            partner_stats[partner_name] = {
                'wikipedia_title': 'Error',
                'total_pageviews': 0,
                'total_edits': 0,
                'status': f'Error: {str(e2)}'
            }
            partner_page_titles[partner_name] = None
    except Exception as e:
        print(f"  ✗ 查询失败: {str(e)}\n")
        partner_stats[partner_name] = {
            'wikipedia_title': 'Error',
            'total_pageviews': 0,
            'total_edits': 0,
            'status': f'Error: {str(e)}'
        }
        partner_page_titles[partner_name] = None

# 为每行数据添加舞伴的统计数据
# 注意：每个舞伴的统计数据是基于其最早出现的年份，但我们需要根据每行的年份来查询
# 所以我们需要为每个(partner, year)组合重新查询
print("\n" + "="*60)
print("为每行数据查询舞伴的统计数据...")
print("="*60)

# 获取所有唯一的(partner, year)组合
partner_year_combos = df_merged[['ballroom_partner', 'year']].drop_duplicates()
print(f"需要查询 {len(partner_year_combos)} 个(舞伴, 年份)组合\n")

partner_year_stats = {}

for idx, row in partner_year_combos.iterrows():
    partner_name = row['ballroom_partner']
    year = row['year']
    combo_key = (partner_name, year)
    
    print(f"[{idx+1}/{len(partner_year_combos)}] 查询: {partner_name} (年份: {year})")
    
    # 如果已经有页面标题，使用它；否则先搜索
    if partner_name in partner_page_titles and partner_page_titles[partner_name]:
        page_title = partner_page_titles[partner_name]
    else:
        try:
            search_results = wikipedia.search(partner_name, results=1)
            if search_results:
                page = wikipedia.page(search_results[0], auto_suggest=False)
                page_title = page.title
                partner_page_titles[partner_name] = page_title
            else:
                page_title = None
        except:
            page_title = None
    
    if page_title:
        total_pageviews, total_edits = get_cumulative_stats_for_partner(page_title, year)
        partner_year_stats[combo_key] = {
            'total_pageviews': total_pageviews,
            'total_edits': total_edits
        }
        print(f"  ✓ 累计浏览量（至{year}年）: {total_pageviews:,}")
        print(f"  ✓ 累计编辑次数（至{year}年）: {total_edits:,}\n")
    else:
        partner_year_stats[combo_key] = {
            'total_pageviews': 0,
            'total_edits': 0
        }
        print(f"  ✗ 未找到页面\n")
    
    time.sleep(0.5)

# 将舞伴统计数据添加到合并的数据框中
def get_partner_stats(row):
    combo_key = (row['ballroom_partner'], row['year'])
    if combo_key in partner_year_stats:
        return pd.Series({
            'ballroom_total_pageviews': partner_year_stats[combo_key]['total_pageviews'],
            'ballroom_total_edits': partner_year_stats[combo_key]['total_edits']
        })
    else:
        return pd.Series({
            'ballroom_total_pageviews': 0,
            'ballroom_total_edits': 0
        })

df_merged[['ballroom_total_pageviews', 'ballroom_total_edits']] = df_merged.apply(get_partner_stats, axis=1)

# 重新排列列的顺序
final_columns = [
    'season',
    'year',
    'celebrity_name',
    'celebrity_total_pageviews',
    'celebrity_total_edits',
    'ballroom_partner',
    'ballroom_total_pageviews',
    'ballroom_total_edits'
]

df_final = df_merged[final_columns].copy()

# 保存最终结果
output_file = 'combined_season_stats.csv'
df_final.to_csv(output_file, index=False, encoding='utf-8-sig')

print("="*60)
print(f"完成！结果已保存到: {output_file}")
print("="*60)
print(f"\n最终数据: {len(df_final)} 行")
print("\n前10行预览:")
print(df_final.head(10))
print("\n数据统计:")
print(f"  季节数: {df_final['season'].nunique()}")
print(f"  年份范围: {df_final['year'].min()} - {df_final['year'].max()}")
print(f"  明星数: {df_final['celebrity_name'].nunique()}")
print(f"  舞伴数: {df_final['ballroom_partner'].nunique()}")
# Out:
# ============================================================
# 读取数据文件...
# ============================================================
# name.csv: 421 行
# celebrity_wikipedia_stats.csv: 421 行
#
# 合并后数据: 421 行
#
# ============================================================
# 分析舞伴数据...
# ============================================================
# 找到 60 个不同的舞伴
#
# ============================================================
# 开始查询舞伴的维基百科数据...
# ============================================================
# 注意：每个舞伴需要查询多个年份的数据，请耐心等待...
#
# [1/60] 查询舞伴: Charlotte Jorgensen (最早出现年份: 2005)
#   ✓ 找到页面: Jorgensen
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 0
#
# [2/60] 查询舞伴: Alec Mazo (最早出现年份: 2005)
#   ✓ 找到页面: Alec Mazo
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 0
#
# [3/60] 查询舞伴: Edyta Sliwinska (最早出现年份: 2005)
#   ✓ 找到页面: Dancing with the Stars (American TV series)
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 12
#
# [4/60] 查询舞伴: Jonathan Roberts (最早出现年份: 2005)
# d:\app\miniconda3\envs\mlwork\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file d:\app\miniconda3\envs\mlwork\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
#   ✓ 找到页面: Jonathan Roberts (writer)
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 2
#
# [5/60] 查询舞伴: Ashly DelGrosso (最早出现年份: 2005)
#   ✓ 找到页面: Ashly DelGrosso
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 0
#
# [6/60] 查询舞伴: Louis van Amstel (最早出现年份: 2005)
#   ✓ 找到页面: Louis van Amstel
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 0
#
# [7/60] 查询舞伴: Nick Kosovich (最早出现年份: 2006)
#   ✓ 找到页面: Nick Kosovich
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 17
#
# [8/60] 查询舞伴: Maksim Chmerkoskiy (最早出现年份: 2006)
#   ✓ 找到页面: Paige Hemmis
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [9/60] 查询舞伴: Tony Dovolani (最早出现年份: 2006)
#   ✓ 找到页面: Tony Dovolani
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 43
#
# [10/60] 查询舞伴: Anna Trebunskaya (最早出现年份: 2006)
#   ✓ 找到页面: Anna Trebunskaya
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [11/60] 查询舞伴: Cheryl Burke (最早出现年份: 2006)
#   ✓ 找到页面: Cheryl Burke
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 123
#
# [12/60] 查询舞伴: Andrea Hale (最早出现年份: 2006)
#   ✓ 找到页面: Andrea Botez
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [13/60] 查询舞伴: Karina Smirnoff (最早出现年份: 2006)
#   ✓ 找到页面: Karina Smirnoff
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 109
#
# [14/60] 查询舞伴: Jesse DeSoto (最早出现年份: 2006)
#   ✓ 找到页面: Jesse Watters
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [15/60] 查询舞伴: Kym Johnson (最早出现年份: 2006)
#   ✓ 找到页面: List of Dancing with the Stars (American TV series) competitors
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [16/60] 查询舞伴: Elena Grinenko (最早出现年份: 2006)
#   ✓ 找到页面: Elena Grinenko
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [17/60] 查询舞伴: Julianne Hough (最早出现年份: 2007)
#   ✓ 找到页面: Julianne Hough
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 363
#
# [18/60] 查询舞伴: Brian Fortuna (最早出现年份: 2007)
#   ✓ 找到页面: Brian Fortuna
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 17
#
# [19/60] 查询舞伴: Mark Ballas (最早出现年份: 2007)
#   ✓ 找到页面: Mark Ballas
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 61
#
# [20/60] 查询舞伴: Derek Hough (最早出现年份: 2007)
#   ✓ 找到页面: Derek Hough
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 65
#
# [21/60] 查询舞伴: Fabian Sanchez (最早出现年份: 2008)
#   ✓ 找到页面: Fabian Sanchez (dancer)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 24
#
# [22/60] 查询舞伴: Inna Brayer (最早出现年份: 2008)
#   ✓ 找到页面: Inna Brayer
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 18
#
# [23/60] 查询舞伴: Corky Ballas (最早出现年份: 2008)
#   ✓ 找到页面: Corky Ballas
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 92
#
# [24/60] 查询舞伴: Lacey Schwimmer (最早出现年份: 2008)
#   ✓ 找到页面: Lacey Schwimmer
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 374
#
# [25/60] 查询舞伴: Chelsie Hightower (最早出现年份: 2009)
#   ✓ 找到页面: Chelsie Hightower
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 174
#
# [26/60] 查询舞伴: Dmitry Chaplin (最早出现年份: 2009)
#   ✓ 找到页面: Dmitry Chaplin
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 219
#
# [27/60] 查询舞伴: Anna Demidova (最早出现年份: 2009)
#   ✓ 找到页面: Anna Demidova
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 44
#
# [28/60] 查询舞伴: Damian Whitewood (最早出现年份: 2010)
#   ✓ 找到页面: Damian Whitewood
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 14
#
# [29/60] 查询舞伴: Valentin Chmerkovskiy (最早出现年份: 2011)
#   ✓ 找到页面: Valentin Chmerkovskiy
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 104
#
# [30/60] 查询舞伴: Peta Murgatroyd (最早出现年份: 2011)
#   ✓ 找到页面: Peta Murgatroyd
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 19
#
# [31/60] 查询舞伴: Tristan MacManus (最早出现年份: 2011)
#   ✓ 找到页面: Tristan MacManus
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 83
#
# [32/60] 查询舞伴: Lindsay Arnold (最早出现年份: 2013)
#   ✓ 找到页面: Lindsay Arnold
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 19
#
# [33/60] 查询舞伴: Sharna Burgess (最早出现年份: 2013)
#   ✓ 找到页面: Sharna Burgess
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 86
#
# [34/60] 查询舞伴: Gleb Savchenko (最早出现年份: 2013)
#   ✓ 找到页面: Gleb Savchenko
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [35/60] 查询舞伴: Emma Slater (最早出现年份: 2013)
#   ✓ 找到页面: Emma Slater
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 93
#
# [36/60] 查询舞伴: Sasha Farber (最早出现年份: 2013)
#   ✓ 找到页面: Sasha Farber
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [37/60] 查询舞伴: Tyne Stecklein (最早出现年份: 2013)
#   ✓ 找到页面: Bill Nye
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 3,841
#
# [38/60] 查询舞伴: Henry Byalikov (最早出现年份: 2014)
#   ✓ 找到页面: Henry Byalikov
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 25
#
# [39/60] 查询舞伴: Witney Carson (最早出现年份: 2014)
#   ✓ 找到页面: Witney Carson
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 192
#
# [40/60] 查询舞伴: Allison Holker (最早出现年份: 2014)
#   ✓ 找到页面: Allison Holker
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 278
#
# [41/60] 查询舞伴: Artem Chigvintsev (最早出现年份: 2014)
#   ✓ 找到页面: Artem Chigvintsev
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 308
#
# [42/60] 查询舞伴: Keo Motsepe (最早出现年份: 2014)
#   ✓ 找到页面: Keo Motsepe
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 0
#
# [43/60] 查询舞伴: Jenna Johnson (最早出现年份: 2016)
#   ✓ 找到页面: Jenna Johnson (dancer)
#   ✓ 累计浏览量（至2016年）: 64,912
#   ✓ 累计编辑次数（至2016年）: 62
#
# [44/60] 查询舞伴: Kym Herjavec (最早出现年份: 2017)
#   ✓ 找到页面: Kym Herjavec
#   ✓ 累计浏览量（至2017年）: 89,496
#   ✓ 累计编辑次数（至2017年）: 792
#
# [45/60] 查询舞伴: Alan Bersten (最早出现年份: 2017)
#   ✓ 找到页面: Alan Bersten
#   ✓ 累计浏览量（至2017年）: 15,513
#   ✓ 累计编辑次数（至2017年）: 3
#
# [46/60] 查询舞伴: Brandon Armstrong (最早出现年份: 2018)
#   ✓ 找到页面: Brandon Armstrong (dancer)
#   ✓ 累计浏览量（至2018年）: 21,337
#   ✓ 累计编辑次数（至2018年）: 1
#
# [47/60] 查询舞伴: Pasha Pashkov (最早出现年份: 2019)
#   ✓ 找到页面: Pasha Pashkov
#   ✓ 累计浏览量（至2019年）: 17,509
#   ✓ 累计编辑次数（至2019年）: 1
#
# [48/60] 查询舞伴: Britt Stewart (最早出现年份: 2020)
#   ✓ 找到页面: Britt Stewart
#   ✓ 累计浏览量（至2020年）: 16,576
#   ✓ 累计编辑次数（至2020年）: 1
#
# [49/60] 查询舞伴: Daniella Karagach (最早出现年份: 2020)
#   ✓ 找到页面: Daniella Karagach
#   ✓ 累计浏览量（至2020年）: 191,033
#   ✓ 累计编辑次数（至2020年）: 156
#
# [50/60] 查询舞伴: Koko Iwasaki (最早出现年份: 2022)
#   ✓ 找到页面: Dancing with the Stars (American TV series) season 32
#   ✓ 累计浏览量（至2022年）: 0
#   ✓ 累计编辑次数（至2022年）: 0
#
# [51/60] 查询舞伴: Rylee Arnold (最早出现年份: 2023)
#   ✓ 找到页面: Rylee Arnold
#   ✓ 累计浏览量（至2023年）: 18,686
#   ✓ 累计编辑次数（至2023年）: 0
#
# [52/60] 查询舞伴: Ezra Sosa (最早出现年份: 2024)
#   ✓ 找到页面: Ezra Sosa
#   ✓ 累计浏览量（至2024年）: 22,539
#   ✓ 累计编辑次数（至2024年）: 1
#
# [53/60] 查询舞伴: Val Chmerkovskiy (最早出现年份: 2024)
#   ✓ 找到页面: Dancing with the Stars (American TV series) season 32
#   ✓ 累计浏览量（至2024年）: 409,271
#   ✓ 累计编辑次数（至2024年）: 1,334
#
# [54/60] 查询舞伴: Alan Bersten (Rashad Jennings week 9) (最早出现年份: 2025)
#   ✓ 找到页面: Rashad Jennings
#   ✓ 累计浏览量（至2025年）: 1,974,996
#   ✓ 累计编辑次数（至2025年）: 495
#
# [55/60] 查询舞伴: Ezra Sosa (Apolo Anton Ohno week 9) (最早出现年份: 2025)
#   ✓ 找到页面: Ezra Sosa
#   ✓ 累计浏览量（至2025年）: 196,020
#   ✓ 累计编辑次数（至2025年）: 64
#
# [56/60] 查询舞伴: Emma Slater/Kaitlyn Bristowe (week 9) (最早出现年份: 2025)
#   ✓ 找到页面: Andy Richter
#   ✓ 累计浏览量（至2025年）: 4,659,901
#   ✓ 累计编辑次数（至2025年）: 1,454
#
# [57/60] 查询舞伴: Witney Carson (Xoshitl Gomez week 9) (最早出现年份: 2025)
#   ✗ 未找到页面
# [58/60] 查询舞伴: Val Chmerkovskiy (Joey Graziadei week 9) (最早出现年份: 2025)
#   ✓ 找到页面: Dancing with the Stars (American TV series)
#   ✓ 累计浏览量（至2025年）: 9,941,674
#   ✓ 累计编辑次数（至2025年）: 13,226
#
# [59/60] 查询舞伴: Jan Ravnik (最早出现年份: 2025)
#   ✓ 找到页面: Jan Ravnik
#   ✓ 累计浏览量（至2025年）: 77,361
#   ✓ 累计编辑次数（至2025年）: 29
#
# [60/60] 查询舞伴: Daniella Karagach (Rumer Willis week 9) (最早出现年份: 2025)
#   ✓ 找到页面: Daniella Karagach
#   ✓ 累计浏览量（至2025年）: 1,496,769
#   ✓ 累计编辑次数（至2025年）: 434
#
#
# ============================================================
# 为每行数据查询舞伴的统计数据...
# ============================================================
# 需要查询 303 个(舞伴, 年份)组合
#
# [1/303] 查询: Charlotte Jorgensen (年份: 2005)
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 0
#
# [2/303] 查询: Alec Mazo (年份: 2005)
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 0
#
# [3/303] 查询: Edyta Sliwinska (年份: 2005)
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 12
#
# [4/303] 查询: Jonathan Roberts (年份: 2005)
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 2
#
# [5/303] 查询: Ashly DelGrosso (年份: 2005)
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 0
#
# [6/303] 查询: Louis van Amstel (年份: 2005)
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 0
#
# [7/303] 查询: Nick Kosovich (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 17
#
# [8/303] 查询: Maksim Chmerkoskiy (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [9/303] 查询: Edyta Sliwinska (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 771
#
# [10/303] 查询: Louis van Amstel (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 34
#
# [11/303] 查询: Tony Dovolani (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 43
#
# [12/303] 查询: Anna Trebunskaya (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [13/303] 查询: Jonathan Roberts (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 5
#
# [14/303] 查询: Ashly DelGrosso (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 39
#
# [15/303] 查询: Cheryl Burke (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 123
#
# [16/303] 查询: Andrea Hale (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [21/303] 查询: Karina Smirnoff (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 109
#
# [23/303] 查询: Jesse DeSoto (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [26/303] 查询: Kym Johnson (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [27/303] 查询: Elena Grinenko (年份: 2006)
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [28/303] 查询: Edyta Sliwinska (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 2,095
#
# [29/303] 查询: Cheryl Burke (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 288
#
# [30/303] 查询: Elena Grinenko (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 6
#
# [31/303] 查询: Maksim Chmerkoskiy (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 11
#
# [32/303] 查询: Julianne Hough (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 363
#
# [33/303] 查询: Brian Fortuna (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 17
#
# [34/303] 查询: Alec Mazo (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 37
#
# [35/303] 查询: Jonathan Roberts (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 9
#
# [36/303] 查询: Karina Smirnoff (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 218
#
# [37/303] 查询: Kym Johnson (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 0
#
# [38/303] 查询: Tony Dovolani (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 129
#
# [41/303] 查询: Mark Ballas (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 61
#
# [42/303] 查询: Derek Hough (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 65
#
# [45/303] 查询: Anna Trebunskaya (年份: 2007)
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 34
#
# [51/303] 查询: Cheryl Burke (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 466
#
# [52/303] 查询: Anna Trebunskaya (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 50
#
# [53/303] 查询: Louis van Amstel (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 63
#
# [54/303] 查询: Fabian Sanchez (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 24
#
# [55/303] 查询: Derek Hough (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 315
#
# [56/303] 查询: Tony Dovolani (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 235
#
# [57/303] 查询: Edyta Sliwinska (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 3,193
#
# [58/303] 查询: Mark Ballas (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 248
#
# [59/303] 查询: Jonathan Roberts (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 11
#
# [60/303] 查询: Kym Johnson (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [61/303] 查询: Julianne Hough (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 979
#
# [62/303] 查询: Karina Smirnoff (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 365
#
# [63/303] 查询: Inna Brayer (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 18
#
# [64/303] 查询: Corky Ballas (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 92
#
# [67/303] 查询: Maksim Chmerkoskiy (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 43
#
# [71/303] 查询: Alec Mazo (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 51
#
# [72/303] 查询: Lacey Schwimmer (年份: 2008)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 374
#
# [76/303] 查询: Cheryl Burke (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 617
#
# [77/303] 查询: Maksim Chmerkoskiy (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 80
#
# [78/303] 查询: Kym Johnson (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 35
#
# [79/303] 查询: Edyta Sliwinska (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 4,447
#
# [80/303] 查询: Chelsie Hightower (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 173
#
# [81/303] 查询: Mark Ballas (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 567
#
# [82/303] 查询: Karina Smirnoff (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 523
#
# [83/303] 查询: Jonathan Roberts (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 17
#
# [84/303] 查询: Julianne Hough (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,370
#
# [85/303] 查询: Derek Hough (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 514
#
# [86/303] 查询: Lacey Schwimmer (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 580
#
# [87/303] 查询: Dmitry Chaplin (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 219
#
# [88/303] 查询: Tony Dovolani (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 376
#
# [93/303] 查询: Anna Trebunskaya (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 69
#
# [94/303] 查询: Alec Mazo (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 138
#
# [96/303] 查询: Anna Demidova (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 44
#
# [104/303] 查询: Louis van Amstel (年份: 2009)
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 132
#
# [105/303] 查询: Edyta Sliwinska (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 5,606
#
# [106/303] 查询: Mark Ballas (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 693
#
# [107/303] 查询: Louis van Amstel (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 171
#
# [108/303] 查询: Ashly DelGrosso (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 141
#
# [109/303] 查询: Cheryl Burke (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 552
#
# [110/303] 查询: Anna Trebunskaya (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 175
#
# [111/303] 查询: Damian Whitewood (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 14
#
# [112/303] 查询: Derek Hough (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 879
#
# [113/303] 查询: Maksim Chmerkoskiy (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 32
#
# [114/303] 查询: Tony Dovolani (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 466
#
# [115/303] 查询: Chelsie Hightower (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 151
#
# [116/303] 查询: Kym Johnson (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 133
#
# [117/303] 查询: Corky Ballas (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 111
#
# [118/303] 查询: Lacey Schwimmer (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 373
#
# [125/303] 查询: Karina Smirnoff (年份: 2010)
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 645
#
# [128/303] 查询: Karina Smirnoff (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 839
#
# [129/303] 查询: Mark Ballas (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 847
#
# [130/303] 查询: Maksim Chmerkoskiy (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 114
#
# [131/303] 查询: Kym Johnson (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 295
#
# [132/303] 查询: Anna Trebunskaya (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 220
#
# [133/303] 查询: Cheryl Burke (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 635
#
# [134/303] 查询: Dmitry Chaplin (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 191
#
# [135/303] 查询: Lacey Schwimmer (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 750
#
# [136/303] 查询: Chelsie Hightower (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 453
#
# [137/303] 查询: Tony Dovolani (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 466
#
# [138/303] 查询: Louis van Amstel (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 100
#
# [139/303] 查询: Valentin Chmerkovskiy (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 96
#
# [141/303] 查询: Derek Hough (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,079
#
# [143/303] 查询: Peta Murgatroyd (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 0
#
# [149/303] 查询: Tristan MacManus (年份: 2011)
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 83
#
# [151/303] 查询: Cheryl Burke (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 953
#
# [152/303] 查询: Anna Trebunskaya (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 236
#
# [153/303] 查询: Valentin Chmerkovskiy (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 207
#
# [154/303] 查询: Kym Johnson (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 365
#
# [155/303] 查询: Chelsie Hightower (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 602
#
# [156/303] 查询: Maksim Chmerkoskiy (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 126
#
# [157/303] 查询: Tony Dovolani (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 723
#
# [158/303] 查询: Peta Murgatroyd (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 153
#
# [159/303] 查询: Karina Smirnoff (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 974
#
# [160/303] 查询: Tristan MacManus (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 136
#
# [161/303] 查询: Mark Ballas (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,027
#
# [162/303] 查询: Derek Hough (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,419
#
# [164/303] 查询: Louis van Amstel (年份: 2012)
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 749
#
# [176/303] 查询: Kym Johnson (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 509
#
# [177/303] 查询: Valentin Chmerkovskiy (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 392
#
# [178/303] 查询: Tristan MacManus (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 210
#
# [179/303] 查询: Lindsay Arnold (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 19
#
# [180/303] 查询: Mark Ballas (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 1,241
#
# [181/303] 查询: Karina Smirnoff (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 1,108
#
# [182/303] 查询: Cheryl Burke (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 1,093
#
# [183/303] 查询: Sharna Burgess (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [184/303] 查询: Tony Dovolani (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 820
#
# [185/303] 查询: Derek Hough (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 1,826
#
# [186/303] 查询: Gleb Savchenko (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [187/303] 查询: Peta Murgatroyd (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 265
#
# [195/303] 查询: Emma Slater (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 93
#
# [197/303] 查询: Sasha Farber (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [199/303] 查询: Tyne Stecklein (年份: 2013)
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 3,841
#
# [200/303] 查询: Emma Slater (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 159
#
# [201/303] 查询: Valentin Chmerkovskiy (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 599
#
# [202/303] 查询: Peta Murgatroyd (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 380
#
# [203/303] 查询: Mark Ballas (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,392
#
# [204/303] 查询: Karina Smirnoff (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,178
#
# [205/303] 查询: Henry Byalikov (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 25
#
# [206/303] 查询: Sharna Burgess (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 174
#
# [207/303] 查询: Derek Hough (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 2,134
#
# [208/303] 查询: Maksim Chmerkoskiy (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 135
#
# [209/303] 查询: Cheryl Burke (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,187
#
# [210/303] 查询: Witney Carson (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 192
#
# [211/303] 查询: Tony Dovolani (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 921
#
# [213/303] 查询: Allison Holker (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 278
#
# [214/303] 查询: Artem Chigvintsev (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 308
#
# [217/303] 查询: Keo Motsepe (年份: 2014)
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 0
#
# [225/303] 查询: Tony Dovolani (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 103,367
#   ✓ 累计编辑次数（至2015年）: 981
#
# [226/303] 查询: Mark Ballas (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 254,929
#   ✓ 累计编辑次数（至2015年）: 1,444
#
# [227/303] 查询: Allison Holker (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 430,122
#   ✓ 累计编辑次数（至2015年）: 440
#
# [228/303] 查询: Valentin Chmerkovskiy (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 237,093
#   ✓ 累计编辑次数（至2015年）: 851
#
# [229/303] 查询: Derek Hough (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 942,035
#   ✓ 累计编辑次数（至2015年）: 2,448
#
# [230/303] 查询: Peta Murgatroyd (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 224,947
#   ✓ 累计编辑次数（至2015年）: 494
#
# [231/303] 查询: Kym Johnson (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 0
#   ✓ 累计编辑次数（至2015年）: 907
#
# [232/303] 查询: Keo Motsepe (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 54,243
#   ✓ 累计编辑次数（至2015年）: 66
#
# [233/303] 查询: Sharna Burgess (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 198,452
#   ✓ 累计编辑次数（至2015年）: 311
#
# [234/303] 查询: Emma Slater (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 182,876
#   ✓ 累计编辑次数（至2015年）: 222
#
# [235/303] 查询: Artem Chigvintsev (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 210,749
#   ✓ 累计编辑次数（至2015年）: 390
#
# [236/303] 查询: Witney Carson (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 292,128
#   ✓ 累计编辑次数（至2015年）: 438
#
# [237/303] 查询: Anna Trebunskaya (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 108,155
#   ✓ 累计编辑次数（至2015年）: 356
#
# [240/303] 查询: Karina Smirnoff (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 244,070
#   ✓ 累计编辑次数（至2015年）: 1,254
#
# [241/303] 查询: Lindsay Arnold (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 191,620
#   ✓ 累计编辑次数（至2015年）: 159
#
# [249/303] 查询: Louis van Amstel (年份: 2015)
#   ✓ 累计浏览量（至2015年）: 35,521
#   ✓ 累计编辑次数（至2015年）: 807
#
# [250/303] 查询: Artem Chigvintsev (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 607,087
#   ✓ 累计编辑次数（至2016年）: 490
#
# [251/303] 查询: Sasha Farber (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 238,341
#   ✓ 累计编辑次数（至2016年）: 128
#
# [252/303] 查询: Keo Motsepe (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 189,988
#   ✓ 累计编辑次数（至2016年）: 125
#
# [253/303] 查询: Karina Smirnoff (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 588,757
#   ✓ 累计编辑次数（至2016年）: 1,295
#
# [254/303] 查询: Witney Carson (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 725,902
#   ✓ 累计编辑次数（至2016年）: 482
#
# [255/303] 查询: Sharna Burgess (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 676,880
#   ✓ 累计编辑次数（至2016年）: 335
#
# [256/303] 查询: Mark Ballas (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 779,296
#   ✓ 累计编辑次数（至2016年）: 1,689
#
# [257/303] 查询: Edyta Sliwinska (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 0
#   ✓ 累计编辑次数（至2016年）: 9,135
#
# [258/303] 查询: Peta Murgatroyd (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 890,144
#   ✓ 累计编辑次数（至2016年）: 645
#
# [259/303] 查询: Valentin Chmerkovskiy (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 916,054
#   ✓ 累计编辑次数（至2016年）: 1,065
#
# [260/303] 查询: Lindsay Arnold (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 489,577
#   ✓ 累计编辑次数（至2016年）: 293
#
# [261/303] 查询: Tony Dovolani (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 224,835
#   ✓ 累计编辑次数（至2016年）: 1,022
#
# [262/303] 查询: Jenna Johnson (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 64,912
#   ✓ 累计编辑次数（至2016年）: 62
#
# [264/303] 查询: Derek Hough (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 2,113,396
#   ✓ 累计编辑次数（至2016年）: 2,739
#
# [265/303] 查询: Cheryl Burke (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 652,130
#   ✓ 累计编辑次数（至2016年）: 1,271
#
# [268/303] 查询: Maksim Chmerkoskiy (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 44,091
#   ✓ 累计编辑次数（至2016年）: 157
#
# [269/303] 查询: Emma Slater (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 439,233
#   ✓ 累计编辑次数（至2016年）: 280
#
# [271/303] 查询: Allison Holker (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 848,036
#   ✓ 累计编辑次数（至2016年）: 516
#
# [273/303] 查询: Gleb Savchenko (年份: 2016)
#   ✓ 累计浏览量（至2016年）: 382,867
#   ✓ 累计编辑次数（至2016年）: 132
#
# [275/303] 查询: Keo Motsepe (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 295,102
#   ✓ 累计编辑次数（至2017年）: 173
#
# [276/303] 查询: Kym Herjavec (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 89,496
#   ✓ 累计编辑次数（至2017年）: 792
#
# [277/303] 查询: Maksim Chmerkoskiy (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 74,493
#   ✓ 累计编辑次数（至2017年）: 159
#
# [278/303] 查询: Artem Chigvintsev (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 1,094,833
#   ✓ 累计编辑次数（至2017年）: 577
#
# [279/303] 查询: Sharna Burgess (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 1,182,244
#   ✓ 累计编辑次数（至2017年）: 566
#
# [280/303] 查询: Sasha Farber (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 535,924
#   ✓ 累计编辑次数（至2017年）: 200
#
# [281/303] 查询: Lindsay Arnold (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 1,080,550
#   ✓ 累计编辑次数（至2017年）: 436
#
# [282/303] 查询: Emma Slater (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 918,284
#   ✓ 累计编辑次数（至2017年）: 405
#
# [283/303] 查询: Witney Carson (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 1,315,555
#   ✓ 累计编辑次数（至2017年）: 744
#
# [284/303] 查询: Gleb Savchenko (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 576,826
#   ✓ 累计编辑次数（至2017年）: 213
#
# [285/303] 查询: Valentin Chmerkovskiy (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 1,482,464
#   ✓ 累计编辑次数（至2017年）: 1,257
#
# [286/303] 查询: Peta Murgatroyd (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 1,417,347
#   ✓ 累计编辑次数（至2017年）: 737
#
# [292/303] 查询: Cheryl Burke (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 1,161,660
#   ✓ 累计编辑次数（至2017年）: 1,348
#
# [295/303] 查询: Mark Ballas (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 1,308,697
#   ✓ 累计编辑次数（至2017年）: 1,748
#
# [296/303] 查询: Alan Bersten (年份: 2017)
#   ✓ 累计浏览量（至2017年）: 15,513
#   ✓ 累计编辑次数（至2017年）: 3
#
# [300/303] 查询: Artem Chigvintsev (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 1,363,067
#   ✓ 累计编辑次数（至2018年）: 643
#
# [301/303] 查询: Emma Slater (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 1,126,022
#   ✓ 累计编辑次数（至2018年）: 484
#
# [302/303] 查询: Lindsay Arnold (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 1,394,292
#   ✓ 累计编辑次数（至2018年）: 511
#
# [303/303] 查询: Gleb Savchenko (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 701,083
#   ✓ 累计编辑次数（至2018年）: 259
#
# [304/303] 查询: Keo Motsepe (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 414,557
#   ✓ 累计编辑次数（至2018年）: 265
#
# [305/303] 查询: Witney Carson (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 1,685,355
#   ✓ 累计编辑次数（至2018年）: 824
#
# [306/303] 查询: Alan Bersten (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 90,766
#   ✓ 累计编辑次数（至2018年）: 3
#
# [307/303] 查询: Sasha Farber (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 688,112
#   ✓ 累计编辑次数（至2018年）: 291
#
# [308/303] 查询: Sharna Burgess (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 1,537,082
#   ✓ 累计编辑次数（至2018年）: 659
#
# [309/303] 查询: Jenna Johnson (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 732,137
#   ✓ 累计编辑次数（至2018年）: 241
#
# [310/303] 查询: Cheryl Burke (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 1,744,322
#   ✓ 累计编辑次数（至2018年）: 1,426
#
# [312/303] 查询: Valentin Chmerkovskiy (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 1,798,590
#   ✓ 累计编辑次数（至2018年）: 1,345
#
# [320/303] 查询: Brandon Armstrong (年份: 2018)
#   ✓ 累计浏览量（至2018年）: 21,337
#   ✓ 累计编辑次数（至2018年）: 1
#
# [323/303] 查询: Pasha Pashkov (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 17,509
#   ✓ 累计编辑次数（至2019年）: 1
#
# [324/303] 查询: Emma Slater (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 848,648
#   ✓ 累计编辑次数（至2019年）: 562
#
# [325/303] 查询: Witney Carson (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 1,948,962
#   ✓ 累计编辑次数（至2019年）: 933
#
# [326/303] 查询: Cheryl Burke (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 1,265,764
#   ✓ 累计编辑次数（至2019年）: 1,484
#
# [327/303] 查询: Peta Murgatroyd (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 1,644,020
#   ✓ 累计编辑次数（至2019年）: 789
#
# [328/303] 查询: Valentin Chmerkovskiy (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 1,373,293
#   ✓ 累计编辑次数（至2019年）: 1,405
#
# [329/303] 查询: Lindsay Arnold (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 1,589,805
#   ✓ 累计编辑次数（至2019年）: 581
#
# [330/303] 查询: Brandon Armstrong (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 33,350
#   ✓ 累计编辑次数（至2019年）: 2
#
# [331/303] 查询: Gleb Savchenko (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 863,719
#   ✓ 累计编辑次数（至2019年）: 331
#
# [332/303] 查询: Sasha Farber (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 830,139
#   ✓ 累计编辑次数（至2019年）: 366
#
# [333/303] 查询: Jenna Johnson (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 1,008,262
#   ✓ 累计编辑次数（至2019年）: 458
#
# [334/303] 查询: Alan Bersten (年份: 2019)
#   ✓ 累计浏览量（至2019年）: 311,967
#   ✓ 累计编辑次数（至2019年）: 171
#
# [335/303] 查询: Keo Motsepe (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 789,215
#   ✓ 累计编辑次数（至2020年）: 296
#
# [336/303] 查询: Sharna Burgess (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 2,030,169
#   ✓ 累计编辑次数（至2020年）: 708
#
# [337/303] 查询: Gleb Savchenko (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 1,090,325
#   ✓ 累计编辑次数（至2020年）: 377
#
# [338/303] 查询: Alan Bersten (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 445,482
#   ✓ 累计编辑次数（至2020年）: 199
#
# [339/303] 查询: Sasha Farber (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 951,975
#   ✓ 累计编辑次数（至2020年）: 399
#
# [340/303] 查询: Emma Slater (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 1,484,478
#   ✓ 累计编辑次数（至2020年）: 593
#
# [341/303] 查询: Peta Murgatroyd (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 2,138,004
#   ✓ 累计编辑次数（至2020年）: 815
#
# [342/303] 查询: Britt Stewart (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 16,576
#   ✓ 累计编辑次数（至2020年）: 1
#
# [343/303] 查询: Jenna Johnson (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 1,294,270
#   ✓ 累计编辑次数（至2020年）: 547
#
# [344/303] 查询: Cheryl Burke (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 2,794,289
#   ✓ 累计编辑次数（至2020年）: 1,555
#
# [345/303] 查询: Daniella Karagach (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 191,033
#   ✓ 累计编辑次数（至2020年）: 156
#
# [346/303] 查询: Artem Chigvintsev (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 3,184,900
#   ✓ 累计编辑次数（至2020年）: 828
#
# [347/303] 查询: Pasha Pashkov (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 46,972
#   ✓ 累计编辑次数（至2020年）: 1
#
# [348/303] 查询: Valentin Chmerkovskiy (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 2,290,002
#   ✓ 累计编辑次数（至2020年）: 1,449
#
# [349/303] 查询: Brandon Armstrong (年份: 2020)
#   ✓ 累计浏览量（至2020年）: 47,633
#   ✓ 累计编辑次数（至2020年）: 2
#
# [350/303] 查询: Britt Stewart (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 29,373
#   ✓ 累计编辑次数（至2021年）: 10
#
# [351/303] 查询: Sharna Burgess (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 2,676,977
#   ✓ 累计编辑次数（至2021年）: 746
#
# [352/303] 查询: Artem Chigvintsev (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 3,184,900
#   ✓ 累计编辑次数（至2021年）: 867
#
# [353/303] 查询: Lindsay Arnold (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 1,950,442
#   ✓ 累计编辑次数（至2021年）: 662
#
# [354/303] 查询: Witney Carson (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 2,484,419
#   ✓ 累计编辑次数（至2021年）: 1,024
#
# [355/303] 查询: Sasha Farber (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 1,052,238
#   ✓ 累计编辑次数（至2021年）: 409
#
# [356/303] 查询: Daniella Karagach (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 372,048
#   ✓ 累计编辑次数（至2021年）: 220
#
# [357/303] 查询: Cheryl Burke (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 3,290,959
#   ✓ 累计编辑次数（至2021年）: 1,555
#
# [358/303] 查询: Gleb Savchenko (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 1,198,770
#   ✓ 累计编辑次数（至2021年）: 402
#
# [359/303] 查询: Emma Slater (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 1,611,802
#   ✓ 累计编辑次数（至2021年）: 612
#
# [360/303] 查询: Valentin Chmerkovskiy (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 2,554,220
#   ✓ 累计编辑次数（至2021年）: 1,474
#
# [361/303] 查询: Jenna Johnson (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 1,648,208
#   ✓ 累计编辑次数（至2021年）: 600
#
# [362/303] 查询: Pasha Pashkov (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 70,747
#   ✓ 累计编辑次数（至2021年）: 3
#
# [363/303] 查询: Brandon Armstrong (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 57,340
#   ✓ 累计编辑次数（至2021年）: 2
#
# [364/303] 查询: Alan Bersten (年份: 2021)
#   ✓ 累计浏览量（至2021年）: 569,157
#   ✓ 累计编辑次数（至2021年）: 242
#
# [365/303] 查询: Peta Murgatroyd (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 2,620,056
#   ✓ 累计编辑次数（至2022年）: 835
#
# [366/303] 查询: Louis van Amstel (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 111,502
#   ✓ 累计编辑次数（至2022年）: 880
#
# [367/303] 查询: Sasha Farber (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 1,055,934
#   ✓ 累计编辑次数（至2022年）: 436
#
# [368/303] 查询: Daniella Karagach (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 501,377
#   ✓ 累计编辑次数（至2022年）: 253
#
# [369/303] 查询: Emma Slater (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 1,820,886
#   ✓ 累计编辑次数（至2022年）: 554
#
# [370/303] 查询: Britt Stewart (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 80,909
#   ✓ 累计编辑次数（至2022年）: 53
#
# [371/303] 查询: Witney Carson (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 2,680,078
#   ✓ 累计编辑次数（至2022年）: 1,057
#
# [372/303] 查询: Cheryl Burke (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 3,829,334
#   ✓ 累计编辑次数（至2022年）: 1,672
#
# [373/303] 查询: Alan Bersten (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 658,434
#   ✓ 累计编辑次数（至2022年）: 265
#
# [374/303] 查询: Brandon Armstrong (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 92,425
#   ✓ 累计编辑次数（至2022年）: 26
#
# [375/303] 查询: Artem Chigvintsev (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 4,073,053
#   ✓ 累计编辑次数（至2022年）: 913
#
# [376/303] 查询: Mark Ballas (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 2,702,692
#   ✓ 累计编辑次数（至2022年）: 1,832
#
# [377/303] 查询: Pasha Pashkov (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 104,043
#   ✓ 累计编辑次数（至2022年）: 9
#
# [378/303] 查询: Koko Iwasaki (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 0
#   ✓ 累计编辑次数（至2022年）: 0
#
# [379/303] 查询: Gleb Savchenko (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 1,350,541
#   ✓ 累计编辑次数（至2022年）: 424
#
# [380/303] 查询: Valentin Chmerkovskiy (年份: 2022)
#   ✓ 累计浏览量（至2022年）: 2,783,273
#   ✓ 累计编辑次数（至2022年）: 1,509
#
# [381/303] 查询: Alan Bersten (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 754,667
#   ✓ 累计编辑次数（至2023年）: 283
#
# [382/303] 查询: Gleb Savchenko (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 1,498,327
#   ✓ 累计编辑次数（至2023年）: 440
#
# [383/303] 查询: Peta Murgatroyd (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 2,946,706
#   ✓ 累计编辑次数（至2023年）: 861
#
# [384/303] 查询: Sasha Farber (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 1,448,972
#   ✓ 累计编辑次数（至2023年）: 436
#
# [385/303] 查询: Valentin Chmerkovskiy (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 3,121,683
#   ✓ 累计编辑次数（至2023年）: 1,556
#
# [386/303] 查询: Britt Stewart (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 201,532
#   ✓ 累计编辑次数（至2023年）: 75
#
# [387/303] 查询: Koko Iwasaki (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 0
#   ✓ 累计编辑次数（至2023年）: 1,299
#
# [388/303] 查询: Jenna Johnson (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 2,189,868
#   ✓ 累计编辑次数（至2023年）: 655
#
# [389/303] 查询: Daniella Karagach (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 768,419
#   ✓ 累计编辑次数（至2023年）: 305
#
# [390/303] 查询: Brandon Armstrong (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 149,814
#   ✓ 累计编辑次数（至2023年）: 37
#
# [391/303] 查询: Rylee Arnold (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 18,686
#   ✓ 累计编辑次数（至2023年）: 0
#
# [392/303] 查询: Emma Slater (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 2,172,315
#   ✓ 累计编辑次数（至2023年）: 660
#
# [393/303] 查询: Artem Chigvintsev (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 4,730,500
#   ✓ 累计编辑次数（至2023年）: 964
#
# [394/303] 查询: Pasha Pashkov (年份: 2023)
#   ✓ 累计浏览量（至2023年）: 141,219
#   ✓ 累计编辑次数（至2023年）: 9
#
# [395/303] 查询: Pasha Pashkov (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 187,220
#   ✓ 累计编辑次数（至2024年）: 10
#
# [396/303] 查询: Britt Stewart (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 336,140
#   ✓ 累计编辑次数（至2024年）: 95
#
# [397/303] 查询: Emma Slater (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 2,502,354
#   ✓ 累计编辑次数（至2024年）: 679
#
# [398/303] 查询: Brandon Armstrong (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 341,013
#   ✓ 累计编辑次数（至2024年）: 120
#
# [399/303] 查询: Daniella Karagach (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 1,019,535
#   ✓ 累计编辑次数（至2024年）: 365
#
# [400/303] 查询: Witney Carson (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 3,260,060
#   ✓ 累计编辑次数（至2024年）: 1,109
#
# [401/303] 查询: Rylee Arnold (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 275,077
#   ✓ 累计编辑次数（至2024年）: 127
#
# [402/303] 查询: Alan Bersten (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 1,068,358
#   ✓ 累计编辑次数（至2024年）: 309
#
# [403/303] 查询: Ezra Sosa (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 22,539
#   ✓ 累计编辑次数（至2024年）: 1
#
# [404/303] 查询: Gleb Savchenko (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 1,867,128
#   ✓ 累计编辑次数（至2024年）: 480
#
# [405/303] 查询: Val Chmerkovskiy (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 409,271
#   ✓ 累计编辑次数（至2024年）: 1,334
#
# [406/303] 查询: Sasha Farber (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 1,833,713
#   ✓ 累计编辑次数（至2024年）: 533
#
# [407/303] 查询: Jenna Johnson (年份: 2024)
#   ✓ 累计浏览量（至2024年）: 2,593,116
#   ✓ 累计编辑次数（至2024年）: 725
#
# [408/303] 查询: Jenna Johnson (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 3,036,627
#   ✓ 累计编辑次数（至2025年）: 769
#
# [409/303] 查询: Pasha Pashkov (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 331,896
#   ✓ 累计编辑次数（至2025年）: 51
#
# [410/303] 查询: Alan Bersten (Rashad Jennings week 9) (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 1,974,996
#   ✓ 累计编辑次数（至2025年）: 495
#
# [411/303] 查询: Britt Stewart (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 511,111
#   ✓ 累计编辑次数（至2025年）: 155
#
# [412/303] 查询: Ezra Sosa (Apolo Anton Ohno week 9) (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 196,020
#   ✓ 累计编辑次数（至2025年）: 64
#
# [413/303] 查询: Emma Slater/Kaitlyn Bristowe (week 9) (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 4,659,901
#   ✓ 累计编辑次数（至2025年）: 1,454
#
# [414/303] 查询: Witney Carson (Xoshitl Gomez week 9) (年份: 2025)
#   ✗ 未找到页面
#
# [415/303] 查询: Gleb Savchenko (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 2,142,119
#   ✓ 累计编辑次数（至2025年）: 497
#
# [416/303] 查询: Brandon Armstrong (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 449,036
#   ✓ 累计编辑次数（至2025年）: 145
#
# [417/303] 查询: Rylee Arnold (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 560,029
#   ✓ 累计编辑次数（至2025年）: 192
#
# [418/303] 查询: Val Chmerkovskiy (Joey Graziadei week 9) (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 9,941,674
#   ✓ 累计编辑次数（至2025年）: 13,226
#
# [419/303] 查询: Jan Ravnik (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 77,361
#   ✓ 累计编辑次数（至2025年）: 29
#
# [420/303] 查询: Mark Ballas (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 4,053,961
#   ✓ 累计编辑次数（至2025年）: 1,967
#
# [421/303] 查询: Daniella Karagach (Rumer Willis week 9) (年份: 2025)
#   ✓ 累计浏览量（至2025年）: 1,496,769
#   ✓ 累计编辑次数（至2025年）: 434
#
# ============================================================
# 完成！结果已保存到: combined_season_stats.csv
# ============================================================
#
# 最终数据: 421 行
#
# 前10行预览:
#    season  year     celebrity_name  celebrity_total_pageviews  \
# 0       1  2005      John O'Hurley                          0
# 1       1  2005       Kelly Monaco                          0
# 2       1  2005  Evander Holyfield                          0
# 3       1  2005      Rachel Hunter                          0
# 4       1  2005      Joey McIntyre                          0
# 5       1  2005      Trista Sutter                          0
# 6       2  2006       Tatum O'Neal                          0
# 7       2  2006        Tia Carrere                          0
# 8       2  2006    George Hamilton                          0
# 9       2  2006         Lisa Rinna                          0
#
#    celebrity_total_edits     ballroom_partner  ballroom_total_pageviews  \
# 0                     49  Charlotte Jorgensen                         0
# 1                    114            Alec Mazo                         0
# 2                     47      Edyta Sliwinska                         0
# 3                     24     Jonathan Roberts                         0
# 4                     31      Ashly DelGrosso                         0
# 5                     39     Louis van Amstel                         0
# 6                     83        Nick Kosovich                         0
# 7                    123   Maksim Chmerkoskiy                         0
# 8                      0      Edyta Sliwinska                         0
# 9                     98     Louis van Amstel                         0
#
#    ballroom_total_edits
# 0                     0
# 1                     0
# 2                    12
# 3                     2
# 4                     0
# 5                     0
# 6                    17
# 7                     0
# 8                   771
# 9                    34
#
# 数据统计:
#   季节数: 34
#   年份范围: 2005 - 2025
#   明星数: 408
#   舞伴数: 60

# %%
# Out:
# 3777

# %%
import wikipedia
import requests
import pandas as pd
import time
from urllib.parse import quote
from datetime import datetime

# 设置维基百科语言为英文
wikipedia.set_lang("en")

def get_yearly_pageviews(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的总浏览量
    """
    try:
        page_title = page_title.replace(" ", "_")
        page_title = quote(page_title, safe="")
        
        url = (
            "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/"
            f"en.wikipedia.org/all-access/all-agents/"
            f"{page_title}/monthly/"
            f"{year}0101/{year}1231"
        )
        
        headers = {
            "User-Agent": "Academic-Research-Bot/1.0"
        }
        
        r = requests.get(url, headers=headers, timeout=10)
        
        if r.status_code != 200:
            return 0
        
        items = r.json().get("items", [])
        return sum(item["views"] for item in items)
    except Exception as e:
        return 0

def get_yearly_edit_count(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的编辑次数
    """
    try:
        url = "https://en.wikipedia.org/w/api.php"
        
        start = f"{year}-01-01T00:00:00Z"
        end = f"{year}-12-31T23:59:59Z"
        
        params = {
            "action": "query",
            "format": "json",
            "prop": "revisions",
            "titles": page_title,
            "rvstart": end,
            "rvend": start,
            "rvlimit": "max"
        }
        
        headers = {
            "User-Agent": "Academic-Research-Bot/1.0"
        }
        
        total_edits = 0
        
        while True:
            r = requests.get(url, params=params, headers=headers, timeout=10)
            data = r.json()
            
            if "query" not in data or "pages" not in data["query"]:
                break
                
            pages = data["query"]["pages"]
            if not pages:
                break
                
            page_data = next(iter(pages.values()))
            
            if "revisions" in page_data:
                total_edits += len(page_data["revisions"])
            
            if "continue" in data:
                params.update(data["continue"])
            else:
                break
        
        return total_edits
    except Exception as e:
        return 0

def get_cumulative_stats(page_title, target_year):
    """
    获取页面在target_year及之前所有年份的累计浏览量和编辑次数
    """
    total_pageviews = 0
    total_edits = 0
    
    # 从2005年开始统计（因为第一季是2005年）
    start_year = 2005
    current_year = datetime.now().year
    
    # 只统计到target_year
    end_year = min(target_year, current_year)
    
    print(f"    统计年份范围: {start_year} - {end_year}")
    
    #改成只统计一年
    for year in range(start_year, end_year + 1):
        year=end_year
        year_views = get_yearly_pageviews(page_title, year)
        year_edits = get_yearly_edit_count(page_title, year)
            
        total_pageviews += year_views
        total_edits += year_edits
            
        # 避免请求过快
        time.sleep(0.3)
    
    return total_pageviews, total_edits

# 读取name.csv文件
if 'df_filtered' in globals():
    df_celebrities = df_filtered.copy()
else:
    df_celebrities = pd.read_csv('name.csv')

print(f"开始查询 {len(df_celebrities)} 个celebrity的维基百科数据...\n")
print("注意：每个celebrity需要查询多个年份的数据，请耐心等待...\n")

results = []

for idx, row in df_celebrities.iterrows():
    celebrity_name = row['celebrity_name']
    year = row['year']
    season = row['season']
    
    print(f"[{idx+1}/{len(df_celebrities)}] 查询: {celebrity_name} (Season {season}, Year {year})")
    
    try:
        # 搜索维基百科页面
        search_results = wikipedia.search(celebrity_name, results=5)
        
        if not search_results:
            print(f"  ✗ 未找到页面")
            results.append({
                'celebrity_name': celebrity_name,
                'season': season,
                'year': year,
                'wikipedia_title': 'Not Found',
                'wikipedia_url': '',
                'total_pageviews': 0,
                'total_edits': 0,
                'status': 'Not Found'
            })
            continue
        
        # 尝试使用第一个搜索结果
        page = None
        for search_result in search_results:
            try:
                page = wikipedia.page(search_result, auto_suggest=False)
                # 验证页面标题是否匹配（简单检查）
                if celebrity_name.lower() in page.title.lower() or page.title.lower() in celebrity_name.lower():
                    break
            except:
                continue
        
        if page is None:
            # 如果都失败，使用第一个结果
            page = wikipedia.page(search_results[0], auto_suggest=False)
        
        print(f"  ✓ 找到页面: {page.title}")
        
        # 获取累计统计（到对应年份及之前）
        total_pageviews, total_edits = get_cumulative_stats(page.title, year)
        
        print(f"  ✓ 累计浏览量（至{year}年）: {total_pageviews:,}")
        print(f"  ✓ 累计编辑次数（至{year}年）: {total_edits:,}\n")
        
        results.append({
            'celebrity_name': celebrity_name,
            'season': season,
            'year': year,
            'wikipedia_title': page.title,
            'wikipedia_url': page.url,
            'total_pageviews': total_pageviews,
            'total_edits': total_edits,
            'status': 'Success'
        })
        
        # 避免请求过快
        time.sleep(1)
        
    except wikipedia.exceptions.DisambiguationError as e:
        print(f"  ✗ 存在歧义，尝试第一个选项: {e.options[0] if e.options else 'N/A'}")
        try:
            if e.options:
                page = wikipedia.page(e.options[0], auto_suggest=False)
                total_pageviews, total_edits = get_cumulative_stats(page.title, year)
                results.append({
                    'celebrity_name': celebrity_name,
                    'season': season,
                    'year': year,
                    'wikipedia_title': page.title,
                    'wikipedia_url': page.url,
                    'total_pageviews': total_pageviews,
                    'total_edits': total_edits,
                    'status': 'Disambiguation'
                })
                print(f"  ✓ 使用歧义选项: {page.title}\n")
            else:
                results.append({
                    'celebrity_name': celebrity_name,
                    'season': season,
                    'year': year,
                    'wikipedia_title': 'Disambiguation Error',
                    'wikipedia_url': '',
                    'total_pageviews': 0,
                    'total_edits': 0,
                    'status': 'Disambiguation Error'
                })
        except Exception as e2:
            print(f"  ✗ 处理歧义失败: {str(e2)}\n")
            results.append({
                'celebrity_name': celebrity_name,
                'season': season,
                'year': year,
                'wikipedia_title': 'Error',
                'wikipedia_url': '',
                'total_pageviews': 0,
                'total_edits': 0,
                'status': f'Error: {str(e2)}'
            })
    except Exception as e:
        print(f"  ✗ 查询失败: {str(e)}\n")
        results.append({
            'celebrity_name': celebrity_name,
            'season': season,
            'year': year,
            'wikipedia_title': 'Error',
            'wikipedia_url': '',
            'total_pageviews': 0,
            'total_edits': 0,
            'status': f'Error: {str(e)}'
        })

# 保存结果到CSV
df_results = pd.DataFrame(results)
df_results.to_csv('celebrity_wikipedia_stats.csv', index=False, encoding='utf-8-sig')

print("=" * 60)
print("查询完成！结果已保存到: celebrity_wikipedia_stats(one_year).csv")
print("=" * 60)
print(f"\n成功查询: {len(df_results[df_results['status'] == 'Success'])} 个")
print(f"失败查询: {len(df_results[df_results['status'] != 'Success'])} 个")
print("\n结果预览:")
print(df_results[['celebrity_name', 'year', 'wikipedia_title', 'total_pageviews', 'total_edits']].head(10))
# Out:
# 开始查询 421 个celebrity的维基百科数据...
#
# 注意：每个celebrity需要查询多个年份的数据，请耐心等待...
#
# [1/421] 查询: John O'Hurley (Season 1, Year 2005)
#   ✓ 找到页面: John O'Hurley
#     统计年份范围: 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 49
#
# [2/421] 查询: Kelly Monaco (Season 1, Year 2005)
#   ✓ 找到页面: Kelly Monaco
#     统计年份范围: 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 114
#
# [3/421] 查询: Evander Holyfield (Season 1, Year 2005)
#   ✓ 找到页面: Evander Holyfield
#     统计年份范围: 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 47
#
# [4/421] 查询: Rachel Hunter (Season 1, Year 2005)
#   ✓ 找到页面: Rachel Hunter
#     统计年份范围: 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 24
#
# [5/421] 查询: Joey McIntyre (Season 1, Year 2005)
#   ✓ 找到页面: Joey McIntyre
#     统计年份范围: 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 31
#
# [6/421] 查询: Trista Sutter (Season 1, Year 2005)
#   ✓ 找到页面: Trista Sutter
#     统计年份范围: 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 39
#
# [7/421] 查询: Tatum O'Neal (Season 2, Year 2006)
#   ✓ 找到页面: Tatum O'Neal
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 83
#
# [8/421] 查询: Tia Carrere (Season 2, Year 2006)
#   ✓ 找到页面: Tia Carrere
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 123
#
# [9/421] 查询: George Hamilton (Season 2, Year 2006)
#   ✓ 找到页面: George Hamilton (actor)
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [10/421] 查询: Lisa Rinna (Season 2, Year 2006)
#   ✓ 找到页面: Lisa Rinna
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 98
#
# [11/421] 查询: Stacy Keibler (Season 2, Year 2006)
#   ✓ 找到页面: Stacy Keibler
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 1,098
#
# [12/421] 查询: Jerry Rice (Season 2, Year 2006)
#   ✓ 找到页面: Jerry Rice
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 495
#
# [13/421] 查询: Giselle Fernandez (Season 2, Year 2006)
#   ✓ 找到页面: Barbie & Teresa: Recipe for Friendship
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [14/421] 查询: Master P (Season 2, Year 2006)
#   ✓ 找到页面: Master P
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 668
#
# [15/421] 查询: Drew Lachey (Season 2, Year 2006)
#   ✓ 找到页面: Drew Lachey
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 97
#
# [16/421] 查询: Kenny Mayne (Season 2, Year 2006)
#   ✓ 找到页面: Kenny Mayne
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 64
#
# [17/421] 查询: Harry Hamlin (Season 3, Year 2006)
#   ✓ 找到页面: Mayfair Witches
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [18/421] 查询: Vivica A. Fox (Season 3, Year 2006)
#   ✓ 找到页面: Vivica A. Fox
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 104
#
# [19/421] 查询: Monique Coleman (Season 3, Year 2006)
#   ✓ 找到页面: Monique Coleman
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 427
#
# [20/421] 查询: Joey Lawrence (Season 3, Year 2006)
#   ✓ 找到页面: Joey Lawrence
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 123
#
# [21/421] 查询: Mario Lopez (Season 3, Year 2006)
#   ✓ 找到页面: Mario Lopez
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 369
#
# [22/421] 查询: Emmitt Smith (Season 3, Year 2006)
#   ✓ 找到页面: Emmitt Smith
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 372
#
# [23/421] 查询: Shanna Moakler (Season 3, Year 2006)
#   ✓ 找到页面: Shanna Moakler
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 173
#
# [24/421] 查询: Willa Ford (Season 3, Year 2006)
#   ✓ 找到页面: Willa Ford
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 642
#
# [25/421] 查询: Sara Evans (Season 3, Year 2006)
#   ✓ 找到页面: Sara Evans
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 476
#
# [26/421] 查询: Jerry Springer (Season 3, Year 2006)
#   ✓ 找到页面: Jerry Springer
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 330
#
# [27/421] 查询: Tucker Carlson (Season 3, Year 2006)
#   ✓ 找到页面: Tucker Carlson
#     统计年份范围: 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 750
#
# [28/421] 查询: John Ratzenberger (Season 4, Year 2007)
#   ✓ 找到页面: John Ratzenberger
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 193
#
# [29/421] 查询: Ian Ziering (Season 4, Year 2007)
#   ✓ 找到页面: Ian Ziering
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 104
#
# [30/421] 查询: Clyde Drexler (Season 4, Year 2007)
#   ✓ 找到页面: Clyde Drexler
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 133
#
# [31/421] 查询: Laila Ali (Season 4, Year 2007)
#   ✓ 找到页面: Laila Ali
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 170
#
# [32/421] 查询: Apolo Anton Ohno (Season 4, Year 2007)
#   ✓ 找到页面: Karina Smirnoff
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 109
#
# [33/421] 查询: Shandi Finnessey (Season 4, Year 2007)
#   ✓ 找到页面: Shandi Finnessey
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 136
#
# [34/421] 查询: Paulina Porizkova (Season 4, Year 2007)
#   ✓ 找到页面: Paulina Porizkova
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 136
#
# [35/421] 查询: Heather Mills (Season 4, Year 2007)
#   ✓ 找到页面: Heather Mills
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 594
#
# [36/421] 查询: Billy Ray Cyrus (Season 4, Year 2007)
#   ✓ 找到页面: Billy Ray Cyrus
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 1,847
#
# [37/421] 查询: Joey Fatone (Season 4, Year 2007)
#   ✓ 找到页面: Joey Fatone
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 344
#
# [38/421] 查询: Leeza Gibbons (Season 4, Year 2007)
#   ✓ 找到页面: Leeza Gibbons
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 36
#
# [39/421] 查询: Cameron Mathison (Season 5, Year 2007)
#   ✓ 找到页面: Cameron Mathison
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 54
#
# [40/421] 查询: Jane Seymour (Season 5, Year 2007)
#   ✓ 找到页面: Jane Seymour
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 235
#
# [41/421] 查询: Sabrina Bryan (Season 5, Year 2007)
#   ✓ 找到页面: Sabrina Bryan
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 481
#
# [42/421] 查询: Jennie Garth (Season 5, Year 2007)
#   ✓ 找到页面: Jennie Garth
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 155
#
# [43/421] 查询: Floyd Mayweather Jr.  (Season 5, Year 2007)
#   ✓ 找到页面: Floyd Mayweather Jr.
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 1,249
#
# [44/421] 查询: Josie Maran (Season 5, Year 2007)
#   ✓ 找到页面: Josie Maran
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 190
#
# [45/421] 查询: Albert Reed (Season 5, Year 2007)
# d:\app\miniconda3\envs\mlwork\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file d:\app\miniconda3\envs\mlwork\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
#   ✓ 找到页面: Albert Reed Jr.
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 30
#
# [46/421] 查询: Helio Castroneves (Season 5, Year 2007)
#   ✓ 找到页面: 2002 Indy Racing League
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 16
#
# [47/421] 查询: Mel B (Season 5, Year 2007)
#   ✓ 找到页面: Mel B
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 520
#
# [48/421] 查询: Wayne Newton (Season 5, Year 2007)
#   ✓ 找到页面: Wayne Newton
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 224
#
# [49/421] 查询: Marie Osmond (Season 5, Year 2007)
#   ✓ 找到页面: Marie Osmond
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 431
#
# [50/421] 查询: Mark Cuban (Season 5, Year 2007)
#   ✓ 找到页面: Mark Cuban
#     统计年份范围: 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 734
#
# [51/421] 查询: Cristian de la Fuente (Season 6, Year 2008)
#   ✓ 找到页面: La Jefa (TV series)
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [52/421] 查询: Steve Guttenberg (Season 6, Year 2008)
#   ✓ 找到页面: Steve Guttenberg
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 207
#
# [53/421] 查询: Priscilla Presley (Season 6, Year 2008)
#   ✓ 找到页面: Priscilla Presley
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 297
#
# [54/421] 查询: Marlee Matlin (Season 6, Year 2008)
#   ✓ 找到页面: Marlee Matlin
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 182
#
# [55/421] 查询: Shannon Elizabeth (Season 6, Year 2008)
#   ✓ 找到页面: Shannon Elizabeth
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 300
#
# [56/421] 查询: Marissa Jaret Winokur (Season 6, Year 2008)
#   ✓ 找到页面: Marissa Jaret Winokur
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 123
#
# [57/421] 查询: Jason Taylor (Season 6, Year 2008)
#   ✓ 找到页面: Jason Taylor (American football)
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 340
#
# [58/421] 查询: Kristi Yamaguchi (Season 6, Year 2008)
#   ✓ 找到页面: Kristi Yamaguchi
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 368
#
# [59/421] 查询: Monica Seles (Season 6, Year 2008)
#   ✓ 找到页面: Monica Seles
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 297
#
# [60/421] 查询: Penn Jillette (Season 6, Year 2008)
#   ✓ 找到页面: Penn Jillette
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 183
#
# [61/421] 查询: Adam Carolla (Season 6, Year 2008)
#   ✓ 找到页面: Adam Carolla
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 305
#
# [62/421] 查询: Mario (Season 6, Year 2008)
#   ✓ 找到页面: Mario
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 842
#
# [63/421] 查询: Ted McGinley (Season 7, Year 2008)
#   ✓ 找到页面: Ted McGinley
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 72
#
# [64/421] 查询: Cloris Leachman (Season 7, Year 2008)
#   ✓ 找到页面: Cloris Leachman
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 206
#
# [65/421] 查询: Susan Lucci (Season 7, Year 2008)
#   ✓ 找到页面: Susan Lucci
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 160
#
# [66/421] 查询: Cody Linley (Season 7, Year 2008)
#   ✓ 找到页面: Cody Linley
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 877
#
# [67/421] 查询: Misty May-Treanor (Season 7, Year 2008)
#   ✓ 找到页面: Misty May-Treanor
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [68/421] 查询: Maurice Greene (Season 7, Year 2008)
#   ✓ 找到页面: Maurice Greene (fighter)
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [69/421] 查询: Warren Sapp (Season 7, Year 2008)
#   ✓ 找到页面: Warren Sapp
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 357
#
# [70/421] 查询: Jeffrey Ross (Season 7, Year 2008)
#   ✓ 找到页面: Jeffrey Ross Gunter
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [71/421] 查询: Toni Braxton (Season 7, Year 2008)
#   ✓ 找到页面: Toni Braxton
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 436
#
# [72/421] 查询: Lance Bass (Season 7, Year 2008)
#   ✓ 找到页面: Lance Bass
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 571
#
# [73/421] 查询: Kim Kardashian (Season 7, Year 2008)
#   ✓ 找到页面: Kim Kardashian
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 1,243
#
# [74/421] 查询: Rocco DiSpirito (Season 7, Year 2008)
#   ✓ 找到页面: Rocco DiSpirito
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 53
#
# [75/421] 查询: Brooke Burke (Season 7, Year 2008)
#   ✓ 找到页面: Brooke Burke
#     统计年份范围: 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 339
#
# [76/421] 查询: Gilles Marini (Season 8, Year 2009)
#   ✓ 找到页面: Gilles Marini
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 128
#
# [77/421] 查询: Denise Richards (Season 8, Year 2009)
#   ✓ 找到页面: Denise Richards
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 240
#
# [78/421] 查询: David Alan Grier (Season 8, Year 2009)
#   ✓ 找到页面: David Alan Grier
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 127
#
# [79/421] 查询: Lawrence Taylor (Season 8, Year 2009)
#   ✓ 找到页面: Lawrence Taylor
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 174
#
# [80/421] 查询: Ty Murray (Season 8, Year 2009)
#   ✓ 找到页面: Ty Murray
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 132
#
# [81/421] 查询: Shawn Johnson (Season 8, Year 2009)
#   ✓ 找到页面: Shawn Johnson East
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 477
#
# [82/421] 查询: Steve Wozniak (Season 8, Year 2009)
#   ✓ 找到页面: Steve Wozniak
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 556
#
# [83/421] 查询: Belinda Carlisle (Season 8, Year 2009)
#   ✓ 找到页面: Belinda Carlisle
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 412
#
# [84/421] 查询: Chuck Wicks (Season 8, Year 2009)
#   ✓ 找到页面: Chuck Wicks
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 157
#
# [85/421] 查询: Lil' Kim (Season 8, Year 2009)
#   ✓ 找到页面: Lil' Kim
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 532
#
# [86/421] 查询: Steve-O (Season 8, Year 2009)
#   ✓ 找到页面: Steve-O
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 195
#
# [87/421] 查询: Holly Madison (Season 8, Year 2009)
#   ✓ 找到页面: Holly Madison
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 335
#
# [88/421] 查询: Melissa Rycroft (Season 8, Year 2009)
#   ✓ 找到页面: Melissa Rycroft
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 381
#
# [89/421] 查询: Ashley Hamiliton (Season 9, Year 2009)
#   ✓ 找到页面: Chronology of discoveries of water on Mars
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 0
#
# [90/421] 查询: Debi Mazar (Season 9, Year 2009)
#   ✓ 找到页面: Debi Mazar
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 77
#
# [91/421] 查询: Melissa Joan Hart (Season 9, Year 2009)
#   ✓ 找到页面: Melissa Joan Hart
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 322
#
# [92/421] 查询: Mark Dacascos (Season 9, Year 2009)
#   ✓ 找到页面: Mark Dacascos
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 95
#
# [93/421] 查询: Chuck Liddell (Season 9, Year 2009)
#   ✓ 找到页面: Chuck Liddell
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 315
#
# [94/421] 查询: Natalie Coughlin (Season 9, Year 2009)
#   ✓ 找到页面: Natalie Coughlin
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 97
#
# [95/421] 查询: Louie Vito (Season 9, Year 2009)
#   ✓ 找到页面: Louie Vito
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 103
#
# [96/421] 查询: Michael Irvin (Season 9, Year 2009)
#   ✓ 找到页面: Michael Irvin
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 158
#
# [97/421] 查询: Joanna Krupa (Season 9, Year 2009)
#   ✓ 找到页面: Joanna Krupa
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 348
#
# [98/421] 查询: Kathy Ireland (Season 9, Year 2009)
#   ✓ 找到页面: Kathy Ireland
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 132
#
# [99/421] 查询: Tom DeLay (Season 9, Year 2009)
#   ✓ 找到页面: Tom DeLay
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 505
#
# [100/421] 查询: Macy Gray (Season 9, Year 2009)
#   ✓ 找到页面: Macy Gray
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 129
#
# [101/421] 查询: Aaron Carter (Season 9, Year 2009)
#   ✓ 找到页面: Aaron Carter
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 130
#
# [102/421] 查询: Mya (Season 9, Year 2009)
#   ✓ 找到页面: Mya (singer)
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 671
#
# [103/421] 查询: Donny Osmond (Season 9, Year 2009)
#   ✓ 找到页面: Donny Osmond
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 264
#
# [104/421] 查询: Kelly Osbourne (Season 9, Year 2009)
#   ✓ 找到页面: Kelly Osbourne
#     统计年份范围: 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 357
#
# [105/421] 查询: Aiden Turner (Season 10, Year 2010)
#   ✓ 找到页面: Aiden Turner
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 52
#
# [106/421] 查询: Shannen Doherty (Season 10, Year 2010)
#   ✓ 找到页面: Shannen Doherty
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 357
#
# [107/421] 查询: Niecy Nash (Season 10, Year 2010)
#   ✓ 找到页面: Niecy Nash
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 127
#
# [108/421] 查询: Buzz Aldrin (Season 10, Year 2010)
#   ✓ 找到页面: Buzz Aldrin
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 185
#
# [109/421] 查询: Chad Ochocinco (Season 10, Year 2010)
#   ✓ 找到页面: American Reunion
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 0
#
# [110/421] 查询: Evan Lysacek (Season 10, Year 2010)
#   ✓ 找到页面: Evan Lysacek
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 463
#
# [111/421] 查询: Pamela Anderson (Season 10, Year 2010)
#   ✓ 找到页面: Pamela Anderson
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 868
#
# [112/421] 查询: Nicole Scherzinger (Season 10, Year 2010)
#   ✓ 找到页面: Nicole Scherzinger
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,002
#
# [113/421] 查询: Erin Andrews (Season 10, Year 2010)
#   ✓ 找到页面: Erin Andrews
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 246
#
# [114/421] 查询: Kate Gosselin (Season 10, Year 2010)
#   ✓ 找到页面: Kate Gosselin
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 602
#
# [115/421] 查询: Jake Pavelka (Season 10, Year 2010)
#   ✓ 找到页面: Jake Pavelka
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 67
#
# [116/421] 查询: David Hasselhoff (Season 11, Year 2010)
#   ✓ 找到页面: David Hasselhoff
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 680
#
# [117/421] 查询: Florence Henderson (Season 11, Year 2010)
#   ✓ 找到页面: Florence Henderson
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 121
#
# [118/421] 查询: Kyle Massey (Season 11, Year 2010)
#   ✓ 找到页面: Kyle Massey
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 371
#
# [119/421] 查询: Jennifer Grey (Season 11, Year 2010)
#   ✓ 找到页面: Jennifer Grey
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 224
#
# [120/421] 查询: Rick Fox (Season 11, Year 2010)
#   ✓ 找到页面: Rick Fox
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 132
#
# [121/421] 查询: Kurt Warner (Season 11, Year 2010)
#   ✓ 找到页面: Kurt Warner
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 640
#
# [122/421] 查询: Margaret Cho (Season 11, Year 2010)
#   ✓ 找到页面: Margaret Cho
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 169
#
# [123/421] 查询: Michael Bolton (Season 11, Year 2010)
#   ✓ 找到页面: Michael Bolton
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 163
#
# [124/421] 查询: Brandy (Season 11, Year 2010)
#   ✓ 找到页面: Brandy
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 112
#
# [125/421] 查询: The Situation (Season 11, Year 2010)
#   ✓ 找到页面: Situation awareness
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 32
#
# [126/421] 查询: Audrina Patridge (Season 11, Year 2010)
#   ✓ 找到页面: Audrina Patridge
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 345
#
# [127/421] 查询: Bristol Palin (Season 11, Year 2010)
#   ✓ 找到页面: Bristol Palin
#     统计年份范围: 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 809
#
# [128/421] 查询: Ralph Macchio (Season 12, Year 2011)
#   ✓ 找到页面: Ralph Macchio
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 268
#
# [129/421] 查询: Chelsea Kane (Season 12, Year 2011)
#   ✓ 找到页面: Chelsea Kane
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 579
#
# [130/421] 查询: Kirstie Alley (Season 12, Year 2011)
#   ✓ 找到页面: Kirstie Alley
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 249
#
# [131/421] 查询: Hines Ward (Season 12, Year 2011)
#   ✓ 找到页面: Hines Ward
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 351
#
# [132/421] 查询: Sugar Ray Leonard (Season 12, Year 2011)
#   ✓ 找到页面: Sugar Ray Leonard
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 197
#
# [133/421] 查询: Chris Jericho (Season 12, Year 2011)
#   ✓ 找到页面: Chris Jericho
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,368
#
# [134/421] 查询: Petra Nemcova (Season 12, Year 2011)
#   ✓ 找到页面: Petra (given name)
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 11
#
# [135/421] 查询: Mike Catherwood (Season 12, Year 2011)
#   ✓ 找到页面: Drew Pinsky
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 102
#
# [136/421] 查询: Romeo (Season 12, Year 2011)
#   ✓ 找到页面: Romeo
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 163
#
# [137/421] 查询: Wendy Williams (Season 12, Year 2011)
#   ✓ 找到页面: Wendy Williams
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 300
#
# [138/421] 查询: Kendra Wilkinson (Season 12, Year 2011)
#   ✓ 找到页面: Kendra Wilkinson
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 38
#
# [139/421] 查询: Elisabetta Canalis (Season 13, Year 2011)
#   ✓ 找到页面: Elisabetta Canalis
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 136
#
# [140/421] 查询: David Arquette (Season 13, Year 2011)
#   ✓ 找到页面: David Arquette
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 173
#
# [141/421] 查询: Ricki Lake (Season 13, Year 2011)
#   ✓ 找到页面: Ricki Lake
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 183
#
# [142/421] 查询: J.R. Martinez (Season 13, Year 2011)
#   ✓ 找到页面: Sergio Martínez (boxer)
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 221
#
# [143/421] 查询: Metta World Peace (Ron) (Season 13, Year 2011)
#   ✓ 找到页面: Jeremy Geffen
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 0
#
# [144/421] 查询: Hope Solo (Season 13, Year 2011)
#   ✓ 找到页面: Hope Solo
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 410
#
# [145/421] 查询: Chynna Phillips (Season 13, Year 2011)
#   ✓ 找到页面: Chynna Phillips
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 55
#
# [146/421] 查询: Kristin Cavallari (Season 13, Year 2011)
#   ✓ 找到页面: Kristin Cavallari
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 305
#
# [147/421] 查询: Carson Kressley (Season 13, Year 2011)
#   ✓ 找到页面: Carson Kressley
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 39
#
# [148/421] 查询: Chaz Bono (Season 13, Year 2011)
#   ✓ 找到页面: Chaz Bono
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 156
#
# [149/421] 查询: Nancy Grace (Season 13, Year 2011)
#   ✓ 找到页面: Nancy Grace
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 252
#
# [150/421] 查询: Rob Kardashian (Season 13, Year 2011)
#   ✓ 找到页面: Rob Kardashian
#     统计年份范围: 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 0
#
# [151/421] 查询: William Levy (Season 14, Year 2012)
#   ✓ 找到页面: William Levy (actor)
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 449
#
# [152/421] 查询: Jack Wagner (Season 14, Year 2012)
#   ✓ 找到页面: Jack Wagner (actor)
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 61
#
# [153/421] 查询: Sherri Sheperd (Season 14, Year 2012)
#   ✓ 找到页面: List of dramatic television series with LGBTQ characters: 1960s–2000s
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 0
#
# [154/421] 查询: Jaleel White (Season 14, Year 2012)
#   ✓ 找到页面: Jaleel White
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 360
#
# [155/421] 查询: Roshon Fegan (Season 14, Year 2012)
#   ✓ 找到页面: Roshon Fegan
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 286
#
# [156/421] 查询: Melissa Gilbert (Season 14, Year 2012)
#   ✓ 找到页面: Melissa Gilbert
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 81
#
# [157/421] 查询: Martina Navratilova (Season 14, Year 2012)
#   ✓ 找到页面: Martina Navratilova
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 192
#
# [158/421] 查询: Donald Driver (Season 14, Year 2012)
#   ✓ 找到页面: Donald Driver
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 138
#
# [159/421] 查询: Gavin DeGraw (Season 14, Year 2012)
#   ✓ 找到页面: Gavin DeGraw
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 279
#
# [160/421] 查询: Gladys Knight (Season 14, Year 2012)
#   ✓ 找到页面: Gladys Knight
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 74
#
# [161/421] 查询: Katherine Jenkins (Season 14, Year 2012)
#   ✓ 找到页面: Katherine Jenkins
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 111
#
# [162/421] 查询: Maria Menounos (Season 14, Year 2012)
#   ✓ 找到页面: Maria Menounos
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 195
#
# [163/421] 查询: Gilles Marini (Season 15, Year 2012)
#   ✓ 找到页面: Gilles Marini
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 47
#
# [164/421] 查询: Sabrina Bryan (Season 15, Year 2012)
#   ✓ 找到页面: Sabrina Bryan
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 103
#
# [165/421] 查询: Kirstie Alley (Season 15, Year 2012)
#   ✓ 找到页面: Kirstie Alley
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 122
#
# [166/421] 查询: Kelly Monaco (Season 15, Year 2012)
#   ✓ 找到页面: Kelly Monaco
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 100
#
# [167/421] 查询: Apolo Anton Ohno (Season 15, Year 2012)
#   ✓ 找到页面: Karina Smirnoff
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 135
#
# [168/421] 查询: Emmitt Smith (Season 15, Year 2012)
#   ✓ 找到页面: Emmitt Smith
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 148
#
# [169/421] 查询: Shawn Johnson (Season 15, Year 2012)
#   ✓ 找到页面: Shawn Johnson East
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 202
#
# [170/421] 查询: Pamela Anderson (Season 15, Year 2012)
#   ✓ 找到页面: Pamela Anderson
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 255
#
# [171/421] 查询: Helio Castroneves (Season 15, Year 2012)
#   ✓ 找到页面: 2002 Indy Racing League
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 5
#
# [172/421] 查询: Joey Fatone (Season 15, Year 2012)
#   ✓ 找到页面: Joey Fatone
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 88
#
# [173/421] 查询: Drew Lachey (Season 15, Year 2012)
#   ✓ 找到页面: Drew Lachey
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 32
#
# [174/421] 查询: Bristol Palin (Season 15, Year 2012)
#   ✓ 找到页面: Bristol Palin
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 140
#
# [175/421] 查询: Melissa Rycroft (Season 15, Year 2012)
#   ✓ 找到页面: Melissa Rycroft
#     统计年份范围: 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 58
#
# [176/421] 查询: Ingo Rademacher (Season 16, Year 2013)
#   ✓ 找到页面: Ingo Rademacher
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 40
#
# [177/421] 查询: Zendaya (Season 16, Year 2013)
#   ✓ 找到页面: Zendaya
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 229
#
# [178/421] 查询: Dorothy Hamill (Season 16, Year 2013)
#   ✓ 找到页面: Dorothy Hamill
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 30
#
# [179/421] 查询: Victor Ortiz (Season 16, Year 2013)
#   ✓ 找到页面: Victor Ortiz
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 124
#
# [180/421] 查询: Alexandra Raisman (Season 16, Year 2013)
#   ✓ 找到页面: Gymnastics at the 2016 Summer Olympics – Women's balance beam
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [181/421] 查询: Jacoby Jones (Season 16, Year 2013)
#   ✓ 找到页面: Jacoby Jones
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 272
#
# [182/421] 查询: D. L. Hughley (Season 16, Year 2013)
#   ✓ 找到页面: D. L. Hughley
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 62
#
# [183/421] 查询: Andy Dick (Season 16, Year 2013)
#   ✓ 找到页面: Andy Dick
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 47
#
# [184/421] 查询: Wynonna Judd (Season 16, Year 2013)
#   ✓ 找到页面: Wynonna Judd discography
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 9
#
# [185/421] 查询: Kellie Pickler (Season 16, Year 2013)
#   ✓ 找到页面: Kellie Pickler
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 316
#
# [186/421] 查询: Lisa Vanderpump (Season 16, Year 2013)
#   ✓ 找到页面: Lisa Vanderpump
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 102
#
# [187/421] 查询: Sean Lowe (Season 16, Year 2013)
#   ✓ 找到页面: Sean Lowe (television personality)
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [188/421] 查询: Valerie Harper (Season 17, Year 2013)
#   ✓ 找到页面: Valerie Harper
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 180
#
# [189/421] 查询: Brant Daugherty (Season 17, Year 2013)
#   ✓ 找到页面: Brant Daugherty
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 56
#
# [190/421] 查询: Elizabeth Berkley Lauren (Season 17, Year 2013)
#   ✓ 找到页面: Elizabeth Berkley
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 45
#
# [191/421] 查询: Leah Remini (Season 17, Year 2013)
#   ✓ 找到页面: Leah Remini
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 298
#
# [192/421] 查询: Corbin Bleu (Season 17, Year 2013)
#   ✓ 找到页面: Corbin Bleu
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 80
#
# [193/421] 查询: Amber Riley (Season 17, Year 2013)
#   ✓ 找到页面: Amber Riley
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 149
#
# [194/421] 查询: Keyshawn Johnson (Season 17, Year 2013)
#   ✓ 找到页面: Keyshawn Johnson
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 42
#
# [195/421] 查询: Bill Engvall (Season 17, Year 2013)
#   ✓ 找到页面: Bill Engvall
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 41
#
# [196/421] 查询: Christina Milian (Season 17, Year 2013)
#   ✓ 找到页面: Christina Milian
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 191
#
# [197/421] 查询: Nicole "Snooki" Polizzi (Season 17, Year 2013)
#   ✓ 找到页面: Snooki
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 106
#
# [198/421] 查询: Jack Osbourne (Season 17, Year 2013)
#   ✓ 找到页面: Jack Osbourne
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 64
#
# [199/421] 查询: Bill Nye (Season 17, Year 2013)
#   ✓ 找到页面: Bill Nye
#     统计年份范围: 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 75
#
# [200/421] 查询: Billy Dee Williams (Season 18, Year 2014)
#   ✓ 找到页面: Billy Dee Williams
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 76
#
# [201/421] 查询: Danica McKellar (Season 18, Year 2014)
#   ✓ 找到页面: Danica McKellar
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 75
#
# [202/421] 查询: James Maslow (Season 18, Year 2014)
#   ✓ 找到页面: James Maslow
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 320
#
# [203/421] 查询: Candace Cameron Bure (Season 18, Year 2014)
#   ✓ 找到页面: Candace Cameron Bure
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 124
#
# [204/421] 查询: Sean Avery (Season 18, Year 2014)
#   ✓ 找到页面: Sean Avery
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 65
#
# [205/421] 查询: Diana Nyad (Season 18, Year 2014)
#   ✓ 找到页面: Diana Nyad
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 91
#
# [206/421] 查询: Charlie White (Season 18, Year 2014)
#   ✓ 找到页面: Charlie White (figure skater)
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 199
#
# [207/421] 查询: Amy Purdy (Season 18, Year 2014)
#   ✓ 找到页面: Amy Purdy
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 138
#
# [208/421] 查询: Meryl Davis (Season 18, Year 2014)
#   ✓ 找到页面: Meryl Davis
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 244
#
# [209/421] 查询: Drew Carey (Season 18, Year 2014)
#   ✓ 找到页面: Drew Carey
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 82
#
# [210/421] 查询: Cody Simpson (Season 18, Year 2014)
#   ✓ 找到页面: Cody Simpson
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 378
#
# [211/421] 查询: NeNe Leakes (Season 18, Year 2014)
#   ✓ 找到页面: NeNe Leakes
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 153
#
# [212/421] 查询: Antonio Sabato Jr. (Season 19, Year 2014)
#   ✓ 找到页面: Bugs (2003 film)
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 3
#
# [213/421] 查询: Jonathan Bennett (Season 19, Year 2014)
#   ✓ 找到页面: Jonathan Bennett (actor)
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 86
#
# [214/421] 查询: Lea Thompson (Season 19, Year 2014)
#   ✓ 找到页面: Lea Thompson
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 70
#
# [215/421] 查询: Janel Parrish (Season 19, Year 2014)
#   ✓ 找到页面: Janel Parrish
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 165
#
# [216/421] 查询: Alfonso Ribeiro (Season 19, Year 2014)
#   ✓ 找到页面: Alfonso Ribeiro
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 162
#
# [217/421] 查询: Lolo Jones (Season 19, Year 2014)
#   ✓ 找到页面: Lolo Jones
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 96
#
# [218/421] 查询: Randy Couture (Season 19, Year 2014)
#   ✓ 找到页面: Randy Couture
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 77
#
# [219/421] 查询: Tommy Chong (Season 19, Year 2014)
#   ✓ 找到页面: Tommy Chong
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 104
#
# [220/421] 查询: Betsey Johnson (Season 19, Year 2014)
#   ✓ 找到页面: Betsey Johnson
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 27
#
# [221/421] 查询: Michael Waltrip (Season 19, Year 2014)
#   ✓ 找到页面: Michael Waltrip
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 182
#
# [222/421] 查询: Tavis Smiley (Season 19, Year 2014)
#   ✓ 找到页面: Tavis Smiley
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 37
#
# [223/421] 查询: Bethany Mota (Season 19, Year 2014)
#   ✓ 找到页面: Bethany Mota
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 412
#
# [224/421] 查询: Sadie Robertson (Season 19, Year 2014)
#   ✓ 找到页面: Sadie Robertson
#     统计年份范围: 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 192
#
# [225/421] 查询: Suzanne Somers (Season 20, Year 2015)
#   ✓ 找到页面: Suzanne Somers
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 235,691
#   ✓ 累计编辑次数（至2015年）: 76
#
# [226/421] 查询: Willow Shields (Season 20, Year 2015)
#   ✓ 找到页面: Willow Shields
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 234,385
#   ✓ 累计编辑次数（至2015年）: 150
#
# [227/421] 查询: Riker Lynch (Season 20, Year 2015)
#   ✓ 找到页面: Riker Lynch
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 159,374
#   ✓ 累计编辑次数（至2015年）: 197
#
# [228/421] 查询: Rumer Willis (Season 20, Year 2015)
#   ✓ 找到页面: Rumer Willis
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 439,034
#   ✓ 累计编辑次数（至2015年）: 120
#
# [229/421] 查询: Nastia Liukin (Season 20, Year 2015)
#   ✓ 找到页面: Nastia Liukin
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 144,701
#   ✓ 累计编辑次数（至2015年）: 75
#
# [230/421] 查询: Michael Sam (Season 20, Year 2015)
#   ✓ 找到页面: Michael Sam
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 317,811
#   ✓ 累计编辑次数（至2015年）: 122
#
# [231/421] 查询: Robert Herjavec (Season 20, Year 2015)
#   ✓ 找到页面: Robert Herjavec
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 553,249
#   ✓ 累计编辑次数（至2015年）: 147
#
# [232/421] 查询: Charlotte McKinney (Season 20, Year 2015)
#   ✓ 找到页面: Charlotte McKinney
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 493,035
#   ✓ 累计编辑次数（至2015年）: 190
#
# [233/421] 查询: Noah Galloway (Season 20, Year 2015)
#   ✓ 找到页面: Noah Galloway
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 94,003
#   ✓ 累计编辑次数（至2015年）: 166
#
# [234/421] 查询: Redfoo (Season 20, Year 2015)
#   ✓ 找到页面: Redfoo
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 436,746
#   ✓ 累计编辑次数（至2015年）: 222
#
# [235/421] 查询: Patti LaBelle (Season 20, Year 2015)
#   ✓ 找到页面: Patti LaBelle
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 324,013
#   ✓ 累计编辑次数（至2015年）: 168
#
# [236/421] 查询: Chris Soules (Season 20, Year 2015)
#   ✓ 找到页面: Chris Soules
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 99,152
#   ✓ 累计编辑次数（至2015年）: 65
#
# [237/421] 查询: Gary Busey (Season 21, Year 2015)
#   ✓ 找到页面: Gary Busey
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 1,365,004
#   ✓ 累计编辑次数（至2015年）: 168
#
# [238/421] 查询: Alexa PenaVega (Season 21, Year 2015)
#   ✓ 找到页面: Alexa PenaVega
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 233,251
#   ✓ 累计编辑次数（至2015年）: 164
#
# [239/421] 查询: Carlos PenaVega (Season 21, Year 2015)
#   ✓ 找到页面: Carlos PenaVega
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 97,826
#   ✓ 累计编辑次数（至2015年）: 151
#
# [240/421] 查询: Victor Espinoza (Season 21, Year 2015)
#   ✓ 找到页面: Victor Espinoza
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 189,012
#   ✓ 累计编辑次数（至2015年）: 146
#
# [241/421] 查询: Alek Skarlatos (Season 21, Year 2015)
#   ✓ 找到页面: Alek Skarlatos
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 520,847
#   ✓ 累计编辑次数（至2015年）: 150
#
# [242/421] 查询: Chaka Khan (Season 21, Year 2015)
#   ✓ 找到页面: Chaka Khan
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 508,082
#   ✓ 累计编辑次数（至2015年）: 109
#
# [243/421] 查询: Andy Grammer (Season 21, Year 2015)
#   ✓ 找到页面: Andy Grammer
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 775,284
#   ✓ 累计编辑次数（至2015年）: 231
#
# [244/421] 查询: Tamar Braxton (Season 21, Year 2015)
#   ✓ 找到页面: Tamar Braxton
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 828,412
#   ✓ 累计编辑次数（至2015年）: 462
#
# [245/421] 查询: Nick Carter (Season 21, Year 2015)
#   ✓ 找到页面: Nick Carter
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 25,902
#   ✓ 累计编辑次数（至2015年）: 145
#
# [246/421] 查询: Hayes Grier (Season 21, Year 2015)
#   ✓ 找到页面: Hayes Grier
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 384,198
#   ✓ 累计编辑次数（至2015年）: 147
#
# [247/421] 查询: Bindi Irwin (Season 21, Year 2015)
#   ✓ 找到页面: Bindi Irwin
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 1,561,823
#   ✓ 累计编辑次数（至2015年）: 232
#
# [248/421] 查询: Kim Zolciak-Biermann (Season 21, Year 2015)
#   ✓ 找到页面: Kim Zolciak
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 1,242,975
#   ✓ 累计编辑次数（至2015年）: 164
#
# [249/421] 查询: Paula Deen (Season 21, Year 2015)
#   ✓ 找到页面: Paula Deen
#     统计年份范围: 2015
#   ✓ 累计浏览量（至2015年）: 416,444
#   ✓ 累计编辑次数（至2015年）: 122
#
# [250/421] 查询: Mischa Barton (Season 22, Year 2016)
#   ✓ 找到页面: Mischa Barton
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,358,069
#   ✓ 累计编辑次数（至2016年）: 28
#
# [251/421] 查询: Kim Fields (Season 22, Year 2016)
#   ✓ 找到页面: Kim Fields
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 912,405
#   ✓ 累计编辑次数（至2016年）: 85
#
# [252/421] 查询: Jodie Sweetin (Season 22, Year 2016)
#   ✓ 找到页面: Jodie Sweetin
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 3,920,642
#   ✓ 累计编辑次数（至2016年）: 73
#
# [253/421] 查询: Doug Flutie (Season 22, Year 2016)
#   ✓ 找到页面: Doug Flutie
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,022,980
#   ✓ 累计编辑次数（至2016年）: 128
#
# [254/421] 查询: Von Miller (Season 22, Year 2016)
#   ✓ 找到页面: Von Miller
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 2,210,224
#   ✓ 累计编辑次数（至2016年）: 720
#
# [255/421] 查询: Antonio Brown (Season 22, Year 2016)
#   ✓ 找到页面: Antonio Brown
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,429,112
#   ✓ 累计编辑次数（至2016年）: 572
#
# [256/421] 查询: Paige VanZant (Season 22, Year 2016)
#   ✓ 找到页面: Paige VanZant
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,568,085
#   ✓ 累计编辑次数（至2016年）: 177
#
# [257/421] 查询: Geraldo Rivera (Season 22, Year 2016)
#   ✓ 找到页面: Geraldo Rivera
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 842,682
#   ✓ 累计编辑次数（至2016年）: 95
#
# [258/421] 查询: Nyle DiMarco (Season 22, Year 2016)
#   ✓ 找到页面: Nyle DiMarco
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,627,258
#   ✓ 累计编辑次数（至2016年）: 319
#
# [259/421] 查询: Ginger Zee (Season 22, Year 2016)
#   ✓ 找到页面: Ginger Zee
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 743,733
#   ✓ 累计编辑次数（至2016年）: 56
#
# [260/421] 查询: Wanya Morris (Season 22, Year 2016)
#   ✓ 找到页面: Wanya Morris
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 393,803
#   ✓ 累计编辑次数（至2016年）: 10
#
# [261/421] 查询: Marla Maples (Season 22, Year 2016)
#   ✓ 找到页面: Marla Maples
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 8,125,003
#   ✓ 累计编辑次数（至2016年）: 253
#
# [262/421] 查询: Jake T. Austin (Season 23, Year 2016)
#   ✓ 找到页面: Jake T. Austin
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,199,272
#   ✓ 累计编辑次数（至2016年）: 34
#
# [263/421] 查询: Maureen McCormick (Season 23, Year 2016)
#   ✓ 找到页面: Maureen McCormick
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,781,147
#   ✓ 累计编辑次数（至2016年）: 60
#
# [264/421] 查询: Marilu Henner (Season 23, Year 2016)
#   ✓ 找到页面: Marilu Henner
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 978,445
#   ✓ 累计编辑次数（至2016年）: 48
#
# [265/421] 查询: Ryan Lochte (Season 23, Year 2016)
#   ✓ 找到页面: Ryan Lochte
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 2,982,304
#   ✓ 累计编辑次数（至2016年）: 521
#
# [266/421] 查询: Calvin Johnson Jr. (Season 23, Year 2016)
#   ✓ 找到页面: Calvin Johnson
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,485,822
#   ✓ 累计编辑次数（至2016年）: 448
#
# [267/421] 查询: Laurie Hernandez (Season 23, Year 2016)
#   ✓ 找到页面: Laurie Hernandez
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,581,890
#   ✓ 累计编辑次数（至2016年）: 318
#
# [268/421] 查询: Amber Rose (Season 23, Year 2016)
#   ✓ 找到页面: Amber Rose
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 4,575,897
#   ✓ 累计编辑次数（至2016年）: 424
#
# [269/421] 查询: Rick Perry (Season 23, Year 2016)
#   ✓ 找到页面: Rick Perry
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 826,678
#   ✓ 累计编辑次数（至2016年）: 265
#
# [270/421] 查询: James Hinchcliffe (Season 23, Year 2016)
#   ✓ 找到页面: James Hinchcliffe
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 545,926
#   ✓ 累计编辑次数（至2016年）: 89
#
# [271/421] 查询: Babyface (Season 23, Year 2016)
#   ✓ 找到页面: Babyface (musician)
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 737,054
#   ✓ 累计编辑次数（至2016年）: 84
#
# [272/421] 查询: Vanilla Ice (Season 23, Year 2016)
#   ✓ 找到页面: Vanilla Ice
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,441,109
#   ✓ 累计编辑次数（至2016年）: 80
#
# [273/421] 查询: Jana Kramer (Season 23, Year 2016)
#   ✓ 找到页面: Jana Kramer
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 1,707,311
#   ✓ 累计编辑次数（至2016年）: 138
#
# [274/421] 查询: Terra Jole (Season 23, Year 2016)
#   ✓ 找到页面: Dancing with the Stars (American TV series)
#     统计年份范围: 2016
#   ✓ 累计浏览量（至2016年）: 0
#   ✓ 累计编辑次数（至2016年）: 715
#
# [275/421] 查询: Charo (Season 24, Year 2017)
#   ✓ 找到页面: Charo
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,961,433
#   ✓ 累计编辑次数（至2017年）: 129
#
# [276/421] 查询: Mr. T (Season 24, Year 2017)
#   ✓ 找到页面: Mr. T
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,843,493
#   ✓ 累计编辑次数（至2017年）: 51
#
# [277/421] 查询: Heather Morris (Season 24, Year 2017)
#   ✓ 找到页面: Heather Morris
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 691,195
#   ✓ 累计编辑次数（至2017年）: 75
#
# [278/421] 查询: Nancy Kerrigan (Season 24, Year 2017)
#   ✓ 找到页面: Nancy Kerrigan
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 2,362,017
#   ✓ 累计编辑次数（至2017年）: 104
#
# [279/421] 查询: Bonner Bolton (Season 24, Year 2017)
#   ✓ 找到页面: Bonner Bolton
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 373,210
#   ✓ 累计编辑次数（至2017年）: 55
#
# [280/421] 查询: Simone Biles (Season 24, Year 2017)
#   ✓ 找到页面: Simone Biles
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,238,180
#   ✓ 累计编辑次数（至2017年）: 261
#
# [281/421] 查询: David Ross (Season 24, Year 2017)
#   ✓ 找到页面: David Ross (baseball)
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 757,693
#   ✓ 累计编辑次数（至2017年）: 201
#
# [282/421] 查询: Rashad Jennings (Season 24, Year 2017)
#   ✓ 找到页面: Rashad Jennings
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 884,474
#   ✓ 累计编辑次数（至2017年）: 116
#
# [283/421] 查询: Chris Kattan (Season 24, Year 2017)
#   ✓ 找到页面: Chris Kattan
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 909,538
#   ✓ 累计编辑次数（至2017年）: 63
#
# [284/421] 查询: Erika Jayne (Season 24, Year 2017)
#   ✓ 找到页面: Erika Jayne
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,421,023
#   ✓ 累计编辑次数（至2017年）: 187
#
# [285/421] 查询: Normani (Season 24, Year 2017)
#   ✓ 找到页面: Normani
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,632
#   ✓ 累计编辑次数（至2017年）: 435
#
# [286/421] 查询: Nick Viall (Season 24, Year 2017)
#   ✓ 找到页面: Nick Viall
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 248,256
#   ✓ 累计编辑次数（至2017年）: 88
#
# [287/421] 查询: Sasha Pieterse (Season 25, Year 2017)
#   ✓ 找到页面: Sasha Pieterse
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,330,647
#   ✓ 累计编辑次数（至2017年）: 168
#
# [288/421] 查询: Frankie Muniz (Season 25, Year 2017)
#   ✓ 找到页面: Frankie Muniz
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 2,141,520
#   ✓ 累计编辑次数（至2017年）: 195
#
# [289/421] 查询: Jordan Fisher (Season 25, Year 2017)
#   ✓ 找到页面: Jordan Fisher
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,397,516
#   ✓ 累计编辑次数（至2017年）: 126
#
# [290/421] 查询: Derek Fisher (Season 25, Year 2017)
#   ✓ 找到页面: Derek Fisher
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 629,109
#   ✓ 累计编辑次数（至2017年）: 88
#
# [291/421] 查询: Nikki Bella (Season 25, Year 2017)
#   ✓ 找到页面: Nikki Bella
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 3,115,522
#   ✓ 累计编辑次数（至2017年）: 641
#
# [292/421] 查询: Terrell Owens (Season 25, Year 2017)
#   ✓ 找到页面: Terrell Owens
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,243,732
#   ✓ 累计编辑次数（至2017年）: 596
#
# [293/421] 查询: Victoria Arlen (Season 25, Year 2017)
#   ✓ 找到页面: Victoria Arlen
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 714,410
#   ✓ 累计编辑次数（至2017年）: 24
#
# [294/421] 查询: Barbara Corcoran (Season 25, Year 2017)
#   ✓ 找到页面: Barbara Corcoran
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,251,685
#   ✓ 累计编辑次数（至2017年）: 65
#
# [295/421] 查询: Lindsey Stirling (Season 25, Year 2017)
#   ✓ 找到页面: Lindsey Stirling
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,501,365
#   ✓ 累计编辑次数（至2017年）: 176
#
# [296/421] 查询: Debbie Gibson (Season 25, Year 2017)
#   ✓ 找到页面: Debbie Gibson
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 889,211
#   ✓ 累计编辑次数（至2017年）: 72
#
# [297/421] 查询: Nick Lachey (Season 25, Year 2017)
#   ✓ 找到页面: Nick Lachey
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 1,142,121
#   ✓ 累计编辑次数（至2017年）: 50
#
# [298/421] 查询: Drew Scott (Season 25, Year 2017)
#   ✓ 找到页面: Drew Scott
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 975,277
#   ✓ 累计编辑次数（至2017年）: 464
#
# [299/421] 查询: Vanessa Lachey (Season 25, Year 2017)
#   ✓ 找到页面: Vanessa Lachey
#     统计年份范围: 2017
#   ✓ 累计浏览量（至2017年）: 970,093
#   ✓ 累计编辑次数（至2017年）: 38
#
# [300/421] 查询: Jamie Anderson (Season 26, Year 2018)
#   ✓ 找到页面: Jamie Anderson (snowboarder)
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 345,458
#   ✓ 累计编辑次数（至2018年）: 46
#
# [301/421] 查询: Johnny Damon (Season 26, Year 2018)
#   ✓ 找到页面: Johnny Damon
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 357,296
#   ✓ 累计编辑次数（至2018年）: 24
#
# [302/421] 查询: Kareem Abdul-Jabbar (Season 26, Year 2018)
#   ✓ 找到页面: Kareem Abdul-Jabbar
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 3,152,865
#   ✓ 累计编辑次数（至2018年）: 133
#
# [303/421] 查询: Arike Ogunbowale (Season 26, Year 2018)
#   ✓ 找到页面: Arike Ogunbowale
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 51,692
#   ✓ 累计编辑次数（至2018年）: 35
#
# [304/421] 查询: Jennie Finch Daigle (Season 26, Year 2018)
#   ✓ 找到页面: Jennie Finch
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 350,815
#   ✓ 累计编辑次数（至2018年）: 47
#
# [305/421] 查询: Chris Mazdzer (Season 26, Year 2018)
#   ✓ 找到页面: Chris Mazdzer
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 196,107
#   ✓ 累计编辑次数（至2018年）: 43
#
# [306/421] 查询: Mirai Nagasu (Season 26, Year 2018)
#   ✓ 找到页面: Mirai Nagasu
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 820,929
#   ✓ 累计编辑次数（至2018年）: 133
#
# [307/421] 查询: Tonya Harding (Season 26, Year 2018)
#   ✓ 找到页面: Tonya Harding
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 10,642,024
#   ✓ 累计编辑次数（至2018年）: 1,813
#
# [308/421] 查询: Josh Norman (Season 26, Year 2018)
#   ✓ 找到页面: Josh Norman
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 331,029
#   ✓ 累计编辑次数（至2018年）: 240
#
# [309/421] 查询: Adam Rippon (Season 26, Year 2018)
#   ✓ 找到页面: Adam Rippon
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 1,425,534
#   ✓ 累计编辑次数（至2018年）: 230
#
# [310/421] 查询: Juan Pablo Di Pace (Season 27, Year 2018)
#   ✓ 找到页面: Juan Pablo Di Pace
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 577,909
#   ✓ 累计编辑次数（至2018年）: 44
#
# [311/421] 查询: Evanna Lynch (Season 27, Year 2018)
#   ✓ 找到页面: Evanna Lynch
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 1,038,138
#   ✓ 累计编辑次数（至2018年）: 123
#
# [312/421] 查询: Nancy McKeon (Season 27, Year 2018)
#   ✓ 找到页面: Nancy McKeon
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 888,149
#   ✓ 累计编辑次数（至2018年）: 69
#
# [313/421] 查询: John Schneider (Season 27, Year 2018)
#   ✓ 找到页面: John Schneider (screen actor)
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 1,113,704
#   ✓ 累计编辑次数（至2018年）: 115
#
# [314/421] 查询: Milo Manheim (Season 27, Year 2018)
#   ✓ 找到页面: Milo Manheim
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 929,796
#   ✓ 累计编辑次数（至2018年）: 246
#
# [315/421] 查询: Danelle Umstead (Season 27, Year 2018)
#   ✓ 找到页面: Danelle Umstead
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 189,859
#   ✓ 累计编辑次数（至2018年）: 11
#
# [316/421] 查询: Mary Lou Retton (Season 27, Year 2018)
#   ✓ 找到页面: Mary Lou Retton
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 911,859
#   ✓ 累计编辑次数（至2018年）: 84
#
# [317/421] 查询: DeMarcus Ware (Season 27, Year 2018)
#   ✓ 找到页面: DeMarcus Ware
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 453,456
#   ✓ 累计编辑次数（至2018年）: 32
#
# [318/421] 查询: Nikki Glaser (Season 27, Year 2018)
#   ✓ 找到页面: Nikki Glaser
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 841,092
#   ✓ 累计编辑次数（至2018年）: 54
#
# [319/421] 查询: Bobby Bones (Season 27, Year 2018)
#   ✓ 找到页面: Bobby Bones
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 855,656
#   ✓ 累计编辑次数（至2018年）: 166
#
# [320/421] 查询: Tinashe (Season 27, Year 2018)
#   ✓ 找到页面: Tinashe
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 1,163,249
#   ✓ 累计编辑次数（至2018年）: 415
#
# [321/421] 查询: Alexis Ren (Season 27, Year 2018)
#   ✓ 找到页面: Alexis Ren
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 975,502
#   ✓ 累计编辑次数（至2018年）: 182
#
# [322/421] 查询: Joe Amabile (Season 27, Year 2018)
#   ✓ 找到页面: Joe Amabile
#     统计年份范围: 2018
#   ✓ 累计浏览量（至2018年）: 44,569
#   ✓ 累计编辑次数（至2018年）: 4
#
# [323/421] 查询: Kate Flannery (Season 28, Year 2019)
#   ✓ 找到页面: Kate Flannery
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 649,234
#   ✓ 累计编辑次数（至2019年）: 71
#
# [324/421] 查询: James Van Der Beek (Season 28, Year 2019)
#   ✓ 找到页面: James Van Der Beek
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 1,480,010
#   ✓ 累计编辑次数（至2019年）: 71
#
# [325/421] 查询: Kel Mitchell (Season 28, Year 2019)
#   ✓ 找到页面: Kel Mitchell
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 1,071,445
#   ✓ 累计编辑次数（至2019年）: 163
#
# [326/421] 查询: Ray Lewis (Season 28, Year 2019)
#   ✓ 找到页面: Ray Lewis
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 1,085,511
#   ✓ 累计编辑次数（至2019年）: 130
#
# [327/421] 查询: Lamar Odom (Season 28, Year 2019)
#   ✓ 找到页面: Lamar Odom
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 1,399,474
#   ✓ 累计编辑次数（至2019年）: 59
#
# [328/421] 查询: Sailor Brinkley-Cook (Season 28, Year 2019)
#   ✓ 找到页面: Billy Joel
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 2,266,796
#   ✓ 累计编辑次数（至2019年）: 339
#
# [329/421] 查询: Sean Spicer (Season 28, Year 2019)
#   ✓ 找到页面: Sean Spicer
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 731,924
#   ✓ 累计编辑次数（至2019年）: 38
#
# [330/421] 查询: Mary Wilson (Season 28, Year 2019)
#   ✓ 找到页面: Mary Wilson (singer)
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 464,617
#   ✓ 累计编辑次数（至2019年）: 31
#
# [331/421] 查询: Lauren Alaina (Season 28, Year 2019)
#   ✓ 找到页面: Lauren Alaina
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 704,976
#   ✓ 累计编辑次数（至2019年）: 120
#
# [332/421] 查询: Ally Brooke (Season 28, Year 2019)
#   ✓ 找到页面: Ally Brooke
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 973,231
#   ✓ 累计编辑次数（至2019年）: 362
#
# [333/421] 查询: Karamo Brown (Season 28, Year 2019)
#   ✓ 找到页面: Karamo Brown
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 1,820,858
#   ✓ 累计编辑次数（至2019年）: 86
#
# [334/421] 查询: Hannah Brown (Season 28, Year 2019)
#   ✓ 找到页面: Hannah Brown
#     统计年份范围: 2019
#   ✓ 累计浏览量（至2019年）: 892,652
#   ✓ 累计编辑次数（至2019年）: 155
#
# [335/421] 查询: Anne Heche (Season 29, Year 2020)
#   ✓ 找到页面: Anne Heche
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 2,030,527
#   ✓ 累计编辑次数（至2020年）: 48
#
# [336/421] 查询: Jesse Metcalfe (Season 29, Year 2020)
#   ✓ 找到页面: Jesse Metcalfe
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 1,522,583
#   ✓ 累计编辑次数（至2020年）: 69
#
# [337/421] 查询: Chrishell Stause (Season 29, Year 2020)
#   ✓ 找到页面: Chrishell Stause
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 3,454,832
#   ✓ 累计编辑次数（至2020年）: 80
#
# [338/421] 查询: Skai Jackson (Season 29, Year 2020)
#   ✓ 找到页面: Skai Jackson
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 1,405,707
#   ✓ 累计编辑次数（至2020年）: 102
#
# [339/421] 查询: Justina Machado (Season 29, Year 2020)
#   ✓ 找到页面: Justina Machado
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 950,052
#   ✓ 累计编辑次数（至2020年）: 54
#
# [340/421] 查询: Charles Oakley (Season 29, Year 2020)
#   ✓ 找到页面: Charles Oakley
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 713,318
#   ✓ 累计编辑次数（至2020年）: 15
#
# [341/421] 查询: Veron Davis (Season 29, Year 2020)
#   ✓ 找到页面: The Road from Home
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 3,339
#   ✓ 累计编辑次数（至2020年）: 4
#
# [342/421] 查询: Johnny Weir (Season 29, Year 2020)
#   ✓ 找到页面: Johnny Weir
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 665,830
#   ✓ 累计编辑次数（至2020年）: 221
#
# [343/421] 查询: Nev Schulman (Season 29, Year 2020)
#   ✓ 找到页面: Nev Schulman
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 919,436
#   ✓ 累计编辑次数（至2020年）: 50
#
# [344/421] 查询: AJ McLean (Season 29, Year 2020)
#   ✓ 找到页面: AJ McLean
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 668,746
#   ✓ 累计编辑次数（至2020年）: 96
#
# [345/421] 查询: Nelly (Season 29, Year 2020)
#   ✓ 找到页面: Nelly
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 1,439,364
#   ✓ 累计编辑次数（至2020年）: 37
#
# [346/421] 查询: Kaitlyn Bristowe (Season 29, Year 2020)
#   ✓ 找到页面: Kaitlyn Bristowe
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 633,968
#   ✓ 累计编辑次数（至2020年）: 47
#
# [347/421] 查询: Carole Baskin (Season 29, Year 2020)
#   ✓ 找到页面: Carole Baskin
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 8,957,891
#   ✓ 累计编辑次数（至2020年）: 429
#
# [348/421] 查询: Monica Aldama (Season 29, Year 2020)
#   ✓ 找到页面: Monica Aldama
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 410,498
#   ✓ 累计编辑次数（至2020年）: 57
#
# [349/421] 查询: Jeannie Mai (Season 29, Year 2020)
#   ✓ 找到页面: Jeannie Mai
#     统计年份范围: 2020
#   ✓ 累计浏览量（至2020年）: 1,191,954
#   ✓ 累计编辑次数（至2020年）: 126
#
# [350/421] 查询: Martin Kove (Season 30, Year 2021)
#   ✓ 找到页面: Martin Kove
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 1,203,876
#   ✓ 累计编辑次数（至2021年）: 200
#
# [351/421] 查询: Brian Austin Green (Season 30, Year 2021)
#   ✓ 找到页面: Brian Austin Green
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 2,634,189
#   ✓ 累计编辑次数（至2021年）: 115
#
# [352/421] 查询: Melora Hardin (Season 30, Year 2021)
#   ✓ 找到页面: Melora Hardin
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 1,579,107
#   ✓ 累计编辑次数（至2021年）: 51
#
# [353/421] 查询: Matt James (Season 30, Year 2021)
#   ✓ 找到页面: Matt James (television personality)
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 638,048
#   ✓ 累计编辑次数（至2021年）: 60
#
# [354/421] 查询: Mike "The Miz" Mizanin (Season 30, Year 2021)
#   ✓ 找到页面: The Miz
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 1,231,814
#   ✓ 累计编辑次数（至2021年）: 163
#
# [355/421] 查询: Suni Lee (Season 30, Year 2021)
#   ✓ 找到页面: Simone Biles
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 6,685,016
#   ✓ 累计编辑次数（至2021年）: 532
#
# [356/421] 查询: Iman Shumpert (Season 30, Year 2021)
#   ✓ 找到页面: Iman Shumpert
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 1,361,438
#   ✓ 累计编辑次数（至2021年）: 142
#
# [357/421] 查询: Cody Rigsby (Season 30, Year 2021)
#   ✓ 找到页面: Cody Rigsby
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 54,956
#   ✓ 累计编辑次数（至2021年）: 16
#
# [358/421] 查询: Melanie C (Season 30, Year 2021)
#   ✓ 找到页面: Melanie C
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 1,170,104
#   ✓ 累计编辑次数（至2021年）: 165
#
# [359/421] 查询: Jimmie Allen (Season 30, Year 2021)
#   ✓ 找到页面: Jimmie Allen
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 722,102
#   ✓ 累计编辑次数（至2021年）: 110
#
# [360/421] 查询: Olivia Jade (Season 30, Year 2021)
#   ✓ 找到页面: Olivia Jade
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 755,136
#   ✓ 累计编辑次数（至2021年）: 82
#
# [361/421] 查询: JoJo Siwa (Season 30, Year 2021)
#   ✓ 找到页面: JoJo Siwa
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 4,836,759
#   ✓ 累计编辑次数（至2021年）: 186
#
# [362/421] 查询: Christine Chiu (Season 30, Year 2021)
#   ✓ 找到页面: Dancing with the Stars (American TV series) season 30
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 0
#   ✓ 累计编辑次数（至2021年）: 2,072
#
# [363/421] 查询: Kenya Moore (Season 30, Year 2021)
#   ✓ 找到页面: Kenya Moore
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 553,778
#   ✓ 累计编辑次数（至2021年）: 96
#
# [364/421] 查询: Amanda Kloots (Season 30, Year 2021)
#   ✓ 找到页面: Amanda Kloots
#     统计年份范围: 2021
#   ✓ 累计浏览量（至2021年）: 984,673
#   ✓ 累计编辑次数（至2021年）: 55
#
# [365/421] 查询: Jason Lewis (Season 31, Year 2022)
#   ✓ 找到页面: Jason Lewis (actor)
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 299,469
#   ✓ 累计编辑次数（至2022年）: 15
#
# [366/421] 查询: Cheryl Ladd (Season 31, Year 2022)
#   ✓ 找到页面: Cheryl Ladd
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 764,256
#   ✓ 累计编辑次数（至2022年）: 24
#
# [367/421] 查询: Selma Blair (Season 31, Year 2022)
#   ✓ 找到页面: Selma Blair
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 2,414,891
#   ✓ 累计编辑次数（至2022年）: 54
#
# [368/421] 查询: Joseph Baena (Season 31, Year 2022)
#   ✓ 找到页面: Joseph Baena
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 418,731
#   ✓ 累计编辑次数（至2022年）: 117
#
# [369/421] 查询: Trevor Donovan (Season 31, Year 2022)
#   ✓ 找到页面: Trevor Donovan
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 575,787
#   ✓ 累计编辑次数（至2022年）: 25
#
# [370/421] 查询: Daniel Durant (Season 31, Year 2022)
#   ✓ 找到页面: Daniel Durant
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 700,278
#   ✓ 累计编辑次数（至2022年）: 41
#
# [371/421] 查询: Wayne Brady (Season 31, Year 2022)
#   ✓ 找到页面: Wayne Brady
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 983,611
#   ✓ 累计编辑次数（至2022年）: 51
#
# [372/421] 查询: Sam Champion (Season 31, Year 2022)
#   ✓ 找到页面: Sam Champion
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 192,491
#   ✓ 累计编辑次数（至2022年）: 12
#
# [373/421] 查询: Jessie James Decker (Season 31, Year 2022)
#   ✓ 找到页面: Jessie James Decker
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 669,000
#   ✓ 累计编辑次数（至2022年）: 68
#
# [374/421] 查询: Jordin Sparks (Season 31, Year 2022)
#   ✓ 找到页面: Jordin Sparks
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 717,789
#   ✓ 累计编辑次数（至2022年）: 109
#
# [375/421] 查询: Heidi D'Amelio (Season 31, Year 2022)
#   ✓ 找到页面: Dancing with the Stars (American TV series)
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 1,335,108
#   ✓ 累计编辑次数（至2022年）: 317
#
# [376/421] 查询: Charli D'Amelio (Season 31, Year 2022)
#   ✓ 找到页面: Charli D'Amelio
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 2,330,896
#   ✓ 累计编辑次数（至2022年）: 184
#
# [377/421] 查询: Teresa Giudice (Season 31, Year 2022)
#   ✓ 找到页面: Teresa Giudice
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 668,671
#   ✓ 累计编辑次数（至2022年）: 85
#
# [378/421] 查询: Vinny Guadagnino (Season 31, Year 2022)
#   ✓ 找到页面: Vinny Guadagnino
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 361,345
#   ✓ 累计编辑次数（至2022年）: 82
#
# [379/421] 查询: Shangela (Season 31, Year 2022)
#   ✓ 找到页面: Shangela
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 336,379
#   ✓ 累计编辑次数（至2022年）: 73
#
# [380/421] 查询: Gabby Windey (Season 31, Year 2022)
#   ✓ 找到页面: Gabby Windey
#     统计年份范围: 2022
#   ✓ 累计浏览量（至2022年）: 383,604
#   ✓ 累计编辑次数（至2022年）: 66
#
# [381/421] 查询: Jamie Lynn Spears (Season 32, Year 2023)
#   ✓ 找到页面: Jamie Lynn Spears
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 3,423,592
#   ✓ 累计编辑次数（至2023年）: 279
#
# [382/421] 查询: Mira Sorvino (Season 32, Year 2023)
#   ✓ 找到页面: Mira Sorvino
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 2,380,433
#   ✓ 累计编辑次数（至2023年）: 67
#
# [383/421] 查询: Barry Williams (Season 32, Year 2023)
#   ✓ 找到页面: Barry Williams (actor)
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 1,123,277
#   ✓ 累计编辑次数（至2023年）: 30
#
# [384/421] 查询: Alyson Hannigan (Season 32, Year 2023)
#   ✓ 找到页面: Alyson Hannigan
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 2,228,849
#   ✓ 累计编辑次数（至2023年）: 58
#
# [385/421] 查询: Xochitl Gomez (Season 32, Year 2023)
#   ✓ 找到页面: Xochitl Gomez
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 1,479,002
#   ✓ 累计编辑次数（至2023年）: 141
#
# [386/421] 查询: Adrian Peterson (Season 32, Year 2023)
#   ✓ 找到页面: Adrian Peterson
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 1,115,849
#   ✓ 累计编辑次数（至2023年）: 63
#
# [387/421] 查询: Matt Walsh (Season 32, Year 2023)
#   ✓ 找到页面: Matt Walsh (political commentator)
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 1,496,290
#   ✓ 累计编辑次数（至2023年）: 577
#
# [388/421] 查询: Tyson Beckford (Season 32, Year 2023)
#   ✓ 找到页面: Tyson Beckford
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 416,809
#   ✓ 累计编辑次数（至2023年）: 30
#
# [389/421] 查询: Jason Mraz (Season 32, Year 2023)
#   ✓ 找到页面: Jason Mraz
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 1,345,123
#   ✓ 累计编辑次数（至2023年）: 117
#
# [390/421] 查询: Lele Pons (Season 32, Year 2023)
#   ✓ 找到页面: Lele Pons
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 979,353
#   ✓ 累计编辑次数（至2023年）: 120
#
# [391/421] 查询: Harry Jowsey (Season 32, Year 2023)
#   ✓ 找到页面: Harry Jowsey
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 87,252
#   ✓ 累计编辑次数（至2023年）: 2
#
# [392/421] 查询: Mauricio Umansky (Season 32, Year 2023)
#   ✓ 找到页面: Mauricio Umansky
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 79,157
#   ✓ 累计编辑次数（至2023年）: 31
#
# [393/421] 查询: Charity Lawson (Season 32, Year 2023)
#   ✓ 找到页面: Jenn Tran
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 0
#   ✓ 累计编辑次数（至2023年）: 0
#
# [394/421] 查询: Ariana Madix (Season 32, Year 2023)
#   ✓ 找到页面: Ariana Madix
#     统计年份范围: 2023
#   ✓ 累计浏览量（至2023年）: 1,134,525
#   ✓ 累计编辑次数（至2023年）: 244
#
# [395/421] 查询: Tori Spelling (Season 33, Year 2024)
#   ✓ 找到页面: Tori Spelling
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 1,135,199
#   ✓ 累计编辑次数（至2024年）: 52
#
# [396/421] 查询: Eric Roberts (Season 33, Year 2024)
#   ✓ 找到页面: Eric Roberts filmography
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 246,587
#   ✓ 累计编辑次数（至2024年）: 36
#
# [397/421] 查询: Reginald VelJohnson (Season 33, Year 2024)
#   ✓ 找到页面: Reginald VelJohnson
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 931,266
#   ✓ 累计编辑次数（至2024年）: 67
#
# [398/421] 查询: Chandler Kinney (Season 33, Year 2024)
#   ✓ 找到页面: Chandler Kinney
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 408,968
#   ✓ 累计编辑次数（至2024年）: 62
#
# [399/421] 查询: Dwight Howard  (Season 33, Year 2024)
#   ✓ 找到页面: Dwight Howard
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 1,797,883
#   ✓ 累计编辑次数（至2024年）: 79
#
# [400/421] 查询: Danny Amendola (Season 33, Year 2024)
#   ✓ 找到页面: Danny Amendola
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 1,531,397
#   ✓ 累计编辑次数（至2024年）: 73
#
# [401/421] 查询: Stephen Nedoroscik (Season 33, Year 2024)
#   ✓ 找到页面: Stephen Nedoroscik
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 1,332,032
#   ✓ 累计编辑次数（至2024年）: 305
#
# [402/421] 查询: Ilona Maher (Season 33, Year 2024)
#   ✓ 找到页面: Ilona Maher
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 2,709,146
#   ✓ 累计编辑次数（至2024年）: 184
#
# [403/421] 查询: Anna Delvey (Season 33, Year 2024)
#   ✓ 找到页面: Anna Delvey
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 79,886
#   ✓ 累计编辑次数（至2024年）: 104
#
# [404/421] 查询: Brooks Nader (Season 33, Year 2024)
#   ✓ 找到页面: Brooks Nader
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 680,762
#   ✓ 累计编辑次数（至2024年）: 68
#
# [405/421] 查询: Phaedra Parks (Season 33, Year 2024)
#   ✓ 找到页面: Phaedra Parks
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 592,503
#   ✓ 累计编辑次数（至2024年）: 71
#
# [406/421] 查询: Jenn Tran (Season 33, Year 2024)
#   ✓ 找到页面: Jenn Tran
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 503,683
#   ✓ 累计编辑次数（至2024年）: 45
#
# [407/421] 查询: Joey Graziadei (Season 33, Year 2024)
#   ✓ 找到页面: Joey Graziadei
#     统计年份范围: 2024
#   ✓ 累计浏览量（至2024年）: 960,753
#   ✓ 累计编辑次数（至2024年）: 80
#
# [408/421] 查询: Corey Feldman (Season 34, Year 2025)
#   ✓ 找到页面: Corey Feldman
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 2,453,269
#   ✓ 累计编辑次数（至2025年）: 196
#
# [409/421] 查询: Danielle Fishel (Season 34, Year 2025)
#   ✓ 找到页面: Danielle Fishel
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 1,457,994
#   ✓ 累计编辑次数（至2025年）: 65
#
# [410/421] 查询: Elaine Hendrix (Season 34, Year 2025)
#   ✓ 找到页面: Elaine Hendrix
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 1,357,163
#   ✓ 累计编辑次数（至2025年）: 40
#
# [411/421] 查询: Baron Davis (Season 34, Year 2025)
#   ✓ 找到页面: Baron Davis
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 377,556
#   ✓ 累计编辑次数（至2025年）: 18
#
# [412/421] 查询: Jordan Chiles (Season 34, Year 2025)
#   ✓ 找到页面: Jordan Chiles
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 592,414
#   ✓ 累计编辑次数（至2025年）: 63
#
# [413/421] 查询: Andy Richter (Season 34, Year 2025)
#   ✓ 找到页面: Andy Richter
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 944,473
#   ✓ 累计编辑次数（至2025年）: 59
#
# [414/421] 查询: Robert Irwin (Season 34, Year 2025)
#   ✓ 找到页面: Robert Irwin (conservationist)
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 549,700
#   ✓ 累计编辑次数（至2025年）: 147
#
# [415/421] 查询: Hilaria Baldwin (Season 34, Year 2025)
#   ✓ 找到页面: Hilaria Baldwin
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 2,527,971
#   ✓ 累计编辑次数（至2025年）: 30
#
# [416/421] 查询: Lauren Jauregui (Season 34, Year 2025)
#   ✓ 找到页面: Lauren Jauregui
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 511,434
#   ✓ 累计编辑次数（至2025年）: 52
#
# [417/421] 查询: Scott Hoying (Season 34, Year 2025)
#   ✓ 找到页面: Scott Hoying
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 486,278
#   ✓ 累计编辑次数（至2025年）: 66
#
# [418/421] 查询: Alix Earle (Season 34, Year 2025)
#   ✓ 找到页面: Alix Earle
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 2,959,943
#   ✓ 累计编辑次数（至2025年）: 90
#
# [419/421] 查询: Jen Affleck (Season 34, Year 2025)
#   ✓ 找到页面: Jan Ravnik
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 77,361
#   ✓ 累计编辑次数（至2025年）: 29
#
# [420/421] 查询: Whitney Leavitt (Season 34, Year 2025)
#   ✓ 找到页面: Whitney Leavitt
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 128,544
#   ✓ 累计编辑次数（至2025年）: 33
#
# [421/421] 查询: Dylan Efron (Season 34, Year 2025)
#   ✓ 找到页面: Dylan Efron
#     统计年份范围: 2025
#   ✓ 累计浏览量（至2025年）: 1,402,920
#   ✓ 累计编辑次数（至2025年）: 83
#
# ============================================================
# 查询完成！结果已保存到: celebrity_wikipedia_stats(one_year).csv
# ============================================================
#
# 成功查询: 421 个
# 失败查询: 0 个
#
# 结果预览:
#       celebrity_name  year          wikipedia_title  total_pageviews  \
# 0      John O'Hurley  2005            John O'Hurley                0
# 1       Kelly Monaco  2005             Kelly Monaco                0
# 2  Evander Holyfield  2005        Evander Holyfield                0
# 3      Rachel Hunter  2005            Rachel Hunter                0
# 4      Joey McIntyre  2005            Joey McIntyre                0
# 5      Trista Sutter  2005            Trista Sutter                0
# 6       Tatum O'Neal  2006             Tatum O'Neal                0
# 7        Tia Carrere  2006              Tia Carrere                0
# 8    George Hamilton  2006  George Hamilton (actor)                0
# 9         Lisa Rinna  2006               Lisa Rinna                0
#
#    total_edits
# 0           49
# 1          114
# 2           47
# 3           24
# 4           31
# 5           39
# 6           83
# 7          123
# 8            0
# 9           98

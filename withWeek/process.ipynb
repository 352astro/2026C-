# %%
import pandas as pd

# %%
# 读取CSV文件
df = pd.read_csv('2026_MCM_Problem_C_Data.csv')

# 定义season到年份的映射函数
def season_to_year(season):
    """
    映射规则：
    - Season 1 = 2005
    - Season 2-27 = 2006-2018 (每年2季)
    - Season 28-34 = 2019-2025 (每年1季)
    """
    if season == 1:
        return 2005
    elif 2 <= season <= 27:
        # 2006-2018年，每年2季
        # Season 2-3 -> 2006, Season 4-5 -> 2007, ...
        return 2005 + (season - 2) // 2 + 1
    elif season >= 28:
        # 2019-2025年，每年1季
        return 2019 + (season - 28)
    else:
        return None

# 添加年份列
df['year'] = df['season'].apply(season_to_year)

# 提取需要的列：celebrity_name, ballroom_partner, season, year
df_filtered = df[['celebrity_name', 'ballroom_partner', 'season', 'year']]

# 保存处理后的数据到新文件
df_filtered.to_csv('name.csv', index=False)

print(f"处理完成！共处理了 {len(df_filtered)} 行数据")
print("处理后的数据已保存到: name.csv")
print("\n前10行数据预览:")
print(df_filtered.head(10))
print("\n各season对应的年份:")
print(df_filtered[['season', 'year']].drop_duplicates().sort_values('season'))
# Out:
# 处理完成！共处理了 421 行数据
# 处理后的数据已保存到: name.csv
#
# 前10行数据预览:
#       celebrity_name     ballroom_partner  season  year
# 0      John O'Hurley  Charlotte Jorgensen       1  2005
# 1       Kelly Monaco            Alec Mazo       1  2005
# 2  Evander Holyfield      Edyta Sliwinska       1  2005
# 3      Rachel Hunter     Jonathan Roberts       1  2005
# 4      Joey McIntyre      Ashly DelGrosso       1  2005
# 5      Trista Sutter     Louis van Amstel       1  2005
# 6       Tatum O'Neal        Nick Kosovich       2  2006
# 7        Tia Carrere   Maksim Chmerkoskiy       2  2006
# 8    George Hamilton      Edyta Sliwinska       2  2006
# 9         Lisa Rinna     Louis van Amstel       2  2006
#
# 各season对应的年份:
#      season  year
# 0         1  2005
# 6         2  2006
# 16        3  2006
# 27        4  2007
# 38        5  2007
# 50        6  2008
# 62        7  2008
# 75        8  2009
# 88        9  2009
# 104      10  2010
# 115      11  2010
# 127      12  2011
# 138      13  2011
# 150      14  2012
# 162      15  2012
# 175      16  2013
# 187      17  2013
# 199      18  2014
# 211      19  2014
# 224      20  2015
# 236      21  2015
# 249      22  2016
# 261      23  2016
# 274      24  2017
# 286      25  2017
# 299      26  2018
# 309      27  2018
# 322      28  2019
# 334      29  2020
# 349      30  2021
# 364      31  2022
# 380      32  2023
# 394      33  2024
# 407      34  2025

# %%
# 统计所有ballroom_partner的姓名并去重
# 如果df_filtered存在，直接使用；否则从name.csv读取
if 'df_filtered' in globals():
    partners = df_filtered['ballroom_partner'].unique()
else:
    df_name = pd.read_csv('name.csv')
    partners = df_name['ballroom_partner'].unique()

# 创建DataFrame并保存
df_partners = pd.DataFrame({'partner_name': sorted(partners)})
df_partners.to_csv('partner_name.csv', index=False)

print(f"统计完成！共找到 {len(partners)} 个不同的舞伴")
print("去重后的舞伴姓名已保存到: partner_name.csv")
print("\n前10个舞伴姓名:")
print(df_partners.head(10))
# Out:
# 统计完成！共找到 60 个不同的舞伴
# 去重后的舞伴姓名已保存到: partner_name.csv
#
# 前10个舞伴姓名:
#                             partner_name
# 0                           Alan Bersten
# 1  Alan Bersten (Rashad Jennings week 9)
# 2                              Alec Mazo
# 3                         Allison Holker
# 4                            Andrea Hale
# 5                          Anna Demidova
# 6                       Anna Trebunskaya
# 7                      Artem Chigvintsev
# 8                        Ashly DelGrosso
# 9                      Brandon Armstrong

# %%
import wikipedia
import requests
import pandas as pd
import time
from urllib.parse import quote
from datetime import datetime, timedelta

def get_yearly_pageviews(page_title, year):
    # 1. 标题规范化
    page_title = page_title.replace(" ", "_")
    page_title = quote(page_title, safe="")

    url = (
        "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/"
        f"en.wikipedia.org/all-access/all-agents/"
        f"{page_title}/monthly/"
        f"{year}0101/{year}1231"
    )

    headers = {
        "User-Agent": "Academic-Research-Bot/1.0 (contact: your_email@example.com)"
    }

    r = requests.get(url, headers=headers)

    if r.status_code != 200:
        print("Pageviews API failed:")
        print("URL:", url)
        print("Status:", r.status_code)
        print("Response:", r.text)
        return None

    items = r.json().get("items", [])
    return sum(item["views"] for item in items)

def get_yearly_edit_count(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的编辑次数
    """
    url = "https://en.wikipedia.org/w/api.php"

    start = f"{year}-01-01T00:00:00Z"
    end = f"{year}-12-31T23:59:59Z"

    params = {
        "action": "query",
        "format": "json",
        "prop": "revisions",
        "titles": page_title,
        "rvstart": end,      # 注意：先新后旧
        "rvend": start,
        "rvlimit": "max"
    }

    headers = {
        "User-Agent": "Academic-Research-Bot/1.0 (contact: your_email@example.com)"
    }

    total_edits = 0

    while True:
        r = requests.get(url, params=params, headers=headers)
        data = r.json()

        pages = data["query"]["pages"]
        page_data = next(iter(pages.values()))

        if "revisions" in page_data:
            total_edits += len(page_data["revisions"])

        if "continue" in data:
            params.update(data["continue"])
        else:
            break

    return total_edits


wikipedia.set_lang("en")  # 设置为英文维基，如需中文改为"zh"

# 获取前5个celebrity_name
if 'df_filtered' in globals():
    celebrities = df_filtered['celebrity_name'].head(5).tolist()
else:
    df_name = pd.read_csv('name.csv')
    celebrities = df_name['celebrity_name'].head(5).tolist()

print(f"查询前5个名人: {celebrities}\n")

results = []

for name in celebrities:
    search_results = wikipedia.search(name)
    # print(f"搜索结果列表{search_results}")

    page=wikipedia.page(search_results[0], auto_suggest=False)
    print("---匹配结果---")
    print(f"页面标题：{page.title}")
    print(f"页面URL：{page.url}")
    print(f"页面摘要：{page.summary[:100]}")

    year = 2023
    views = get_yearly_pageviews(page.title, year)
    print(f"{page.title} 在 {year} 年的浏览量：{views}")

    edit_counts=get_yearly_edit_count("Donald Trump", year)
    print(f"{page.title} 在 {year} 年的编辑次数：{edit_counts}")
# Out:
# 查询前5个名人: ["John O'Hurley", 'Kelly Monaco', 'Evander Holyfield', 'Rachel Hunter', 'Joey McIntyre']
#
# ---匹配结果---
# 页面标题：John O'Hurley
# 页面URL：https://en.wikipedia.org/wiki/John_O%27Hurley
# 页面摘要：John George O'Hurley Jr. (born October 9, 1954) is an American actor and game show host. He played J
# John O'Hurley 在 2023 年的浏览量：388916
# John O'Hurley 在 2023 年的编辑次数：1863
# ---匹配结果---
# 页面标题：Kelly Monaco
# 页面URL：https://en.wikipedia.org/wiki/Kelly_Monaco
# 页面摘要：Kelly Marie Monaco (born May 23, 1976) is an American actress, model, and reality television persona
# Kelly Monaco 在 2023 年的浏览量：254426
# Kelly Monaco 在 2023 年的编辑次数：1863
# ---匹配结果---
# 页面标题：Evander Holyfield
# 页面URL：https://en.wikipedia.org/wiki/Evander_Holyfield
# 页面摘要：Evander Holyfield (born October 19, 1962) is an American former professional boxer who competed betw
# Evander Holyfield 在 2023 年的浏览量：1331834
# Evander Holyfield 在 2023 年的编辑次数：1863
# ---匹配结果---
# 页面标题：Rachel Hunter
# 页面URL：https://en.wikipedia.org/wiki/Rachel_Hunter
# 页面摘要：Rachel Hunter (born 8 September 1969) is a New Zealand model, actress, and the host of Imagination T
# Rachel Hunter 在 2023 年的浏览量：622236
# Rachel Hunter 在 2023 年的编辑次数：1863
# ---匹配结果---
# 页面标题：Joey McIntyre
# 页面URL：https://en.wikipedia.org/wiki/Joey_McIntyre
# 页面摘要：Joseph Mulrey McIntyre (born December 31, 1972) is an American singer-songwriter and actor. He is be
# Joey McIntyre 在 2023 年的浏览量：408759
# Joey McIntyre 在 2023 年的编辑次数：1863

# %%
# Out:
# 3777

# %%
import wikipedia
import requests
import pandas as pd
import time
from urllib.parse import quote
from datetime import datetime

# 设置维基百科语言为英文
wikipedia.set_lang("en")

def get_yearly_pageviews(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的总浏览量
    """
    try:
        page_title = page_title.replace(" ", "_")
        page_title = quote(page_title, safe="")
        
        url = (
            "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/"
            f"en.wikipedia.org/all-access/all-agents/"
            f"{page_title}/monthly/"
            f"{year}0101/{year}1231"
        )
        
        headers = {
            "User-Agent": "Academic-Research-Bot/1.0"
        }
        
        r = requests.get(url, headers=headers, timeout=10)
        
        if r.status_code != 200:
            return 0
        
        items = r.json().get("items", [])
        return sum(item["views"] for item in items)
    except Exception as e:
        return 0

def get_yearly_edit_count(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的编辑次数
    """
    try:
        url = "https://en.wikipedia.org/w/api.php"
        
        start = f"{year}-01-01T00:00:00Z"
        end = f"{year}-12-31T23:59:59Z"
        
        params = {
            "action": "query",
            "format": "json",
            "prop": "revisions",
            "titles": page_title,
            "rvstart": end,
            "rvend": start,
            "rvlimit": "max"
        }
        
        headers = {
            "User-Agent": "Academic-Research-Bot/1.0"
        }
        
        total_edits = 0
        
        while True:
            r = requests.get(url, params=params, headers=headers, timeout=10)
            data = r.json()
            
            if "query" not in data or "pages" not in data["query"]:
                break
                
            pages = data["query"]["pages"]
            if not pages:
                break
                
            page_data = next(iter(pages.values()))
            
            if "revisions" in page_data:
                total_edits += len(page_data["revisions"])
            
            if "continue" in data:
                params.update(data["continue"])
            else:
                break
        
        return total_edits
    except Exception as e:
        return 0

def get_cumulative_stats(page_title, target_year):
    """
    获取页面在target_year及之前所有年份的累计浏览量和编辑次数
    """
    total_pageviews = 0
    total_edits = 0
    
    # 从2005年开始统计（因为第一季是2005年）
    start_year = 2005
    current_year = datetime.now().year
    
    # 只统计到target_year
    end_year = min(target_year, current_year)
    
    print(f"    统计年份范围: {start_year} - {end_year}")
    
    for year in range(start_year, end_year + 1):
        year_views = get_yearly_pageviews(page_title, year)
        year_edits = get_yearly_edit_count(page_title, year)
        
        total_pageviews += year_views
        total_edits += year_edits
        
        # 避免请求过快
        time.sleep(0.3)
    
    return total_pageviews, total_edits

# 读取name.csv文件
if 'df_filtered' in globals():
    df_celebrities = df_filtered.copy()
else:
    df_celebrities = pd.read_csv('name.csv')

print(f"开始查询 {len(df_celebrities)} 个celebrity的维基百科数据...\n")
print("注意：每个celebrity需要查询多个年份的数据，请耐心等待...\n")

results = []

for idx, row in df_celebrities.iterrows():
    celebrity_name = row['celebrity_name']
    year = row['year']
    season = row['season']
    
    print(f"[{idx+1}/{len(df_celebrities)}] 查询: {celebrity_name} (Season {season}, Year {year})")
    
    try:
        # 搜索维基百科页面
        search_results = wikipedia.search(celebrity_name, results=5)
        
        if not search_results:
            print(f"  ✗ 未找到页面")
            results.append({
                'celebrity_name': celebrity_name,
                'season': season,
                'year': year,
                'wikipedia_title': 'Not Found',
                'wikipedia_url': '',
                'total_pageviews': 0,
                'total_edits': 0,
                'status': 'Not Found'
            })
            continue
        
        # 尝试使用第一个搜索结果
        page = None
        for search_result in search_results:
            try:
                page = wikipedia.page(search_result, auto_suggest=False)
                # 验证页面标题是否匹配（简单检查）
                if celebrity_name.lower() in page.title.lower() or page.title.lower() in celebrity_name.lower():
                    break
            except:
                continue
        
        if page is None:
            # 如果都失败，使用第一个结果
            page = wikipedia.page(search_results[0], auto_suggest=False)
        
        print(f"  ✓ 找到页面: {page.title}")
        
        # 获取累计统计（到对应年份及之前）
        total_pageviews, total_edits = get_cumulative_stats(page.title, year)
        
        print(f"  ✓ 累计浏览量（至{year}年）: {total_pageviews:,}")
        print(f"  ✓ 累计编辑次数（至{year}年）: {total_edits:,}\n")
        
        results.append({
            'celebrity_name': celebrity_name,
            'season': season,
            'year': year,
            'wikipedia_title': page.title,
            'wikipedia_url': page.url,
            'total_pageviews': total_pageviews,
            'total_edits': total_edits,
            'status': 'Success'
        })
        
        # 避免请求过快
        time.sleep(1)
        
    except wikipedia.exceptions.DisambiguationError as e:
        print(f"  ✗ 存在歧义，尝试第一个选项: {e.options[0] if e.options else 'N/A'}")
        try:
            if e.options:
                page = wikipedia.page(e.options[0], auto_suggest=False)
                total_pageviews, total_edits = get_cumulative_stats(page.title, year)
                results.append({
                    'celebrity_name': celebrity_name,
                    'season': season,
                    'year': year,
                    'wikipedia_title': page.title,
                    'wikipedia_url': page.url,
                    'total_pageviews': total_pageviews,
                    'total_edits': total_edits,
                    'status': 'Disambiguation'
                })
                print(f"  ✓ 使用歧义选项: {page.title}\n")
            else:
                results.append({
                    'celebrity_name': celebrity_name,
                    'season': season,
                    'year': year,
                    'wikipedia_title': 'Disambiguation Error',
                    'wikipedia_url': '',
                    'total_pageviews': 0,
                    'total_edits': 0,
                    'status': 'Disambiguation Error'
                })
        except Exception as e2:
            print(f"  ✗ 处理歧义失败: {str(e2)}\n")
            results.append({
                'celebrity_name': celebrity_name,
                'season': season,
                'year': year,
                'wikipedia_title': 'Error',
                'wikipedia_url': '',
                'total_pageviews': 0,
                'total_edits': 0,
                'status': f'Error: {str(e2)}'
            })
    except Exception as e:
        print(f"  ✗ 查询失败: {str(e)}\n")
        results.append({
            'celebrity_name': celebrity_name,
            'season': season,
            'year': year,
            'wikipedia_title': 'Error',
            'wikipedia_url': '',
            'total_pageviews': 0,
            'total_edits': 0,
            'status': f'Error: {str(e)}'
        })

# 保存结果到CSV
df_results = pd.DataFrame(results)
df_results.to_csv('celebrity_wikipedia_stats.csv', index=False, encoding='utf-8-sig')

print("=" * 60)
print("查询完成！结果已保存到: celebrity_wikipedia_stats.csv")
print("=" * 60)
print(f"\n成功查询: {len(df_results[df_results['status'] == 'Success'])} 个")
print(f"失败查询: {len(df_results[df_results['status'] != 'Success'])} 个")
print("\n结果预览:")
print(df_results[['celebrity_name', 'year', 'wikipedia_title', 'total_pageviews', 'total_edits']].head(10))
# Out:
# 开始查询 421 个celebrity的维基百科数据...
#
# 注意：每个celebrity需要查询多个年份的数据，请耐心等待...
#
# [1/421] 查询: John O'Hurley (Season 1, Year 2005)
#   ✓ 找到页面: John O'Hurley
#     统计年份范围: 2005 - 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 49
#
# [2/421] 查询: Kelly Monaco (Season 1, Year 2005)
#   ✓ 找到页面: Kelly Monaco
#     统计年份范围: 2005 - 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 114
#
# [3/421] 查询: Evander Holyfield (Season 1, Year 2005)
#   ✓ 找到页面: Evander Holyfield
#     统计年份范围: 2005 - 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 47
#
# [4/421] 查询: Rachel Hunter (Season 1, Year 2005)
#   ✓ 找到页面: Rachel Hunter
#     统计年份范围: 2005 - 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 24
#
# [5/421] 查询: Joey McIntyre (Season 1, Year 2005)
#   ✓ 找到页面: Joey McIntyre
#     统计年份范围: 2005 - 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 31
#
# [6/421] 查询: Trista Sutter (Season 1, Year 2005)
#   ✓ 找到页面: Trista Sutter
#     统计年份范围: 2005 - 2005
#   ✓ 累计浏览量（至2005年）: 0
#   ✓ 累计编辑次数（至2005年）: 39
#
# [7/421] 查询: Tatum O'Neal (Season 2, Year 2006)
#   ✓ 找到页面: Tatum O'Neal
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 118
#
# [8/421] 查询: Tia Carrere (Season 2, Year 2006)
#   ✓ 找到页面: Tia Carrere
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 167
#
# [9/421] 查询: George Hamilton (Season 2, Year 2006)
#   ✓ 找到页面: George Hamilton (actor)
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 109
#
# [10/421] 查询: Lisa Rinna (Season 2, Year 2006)
#   ✓ 找到页面: Lisa Rinna
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 129
#
# [11/421] 查询: Stacy Keibler (Season 2, Year 2006)
#   ✓ 找到页面: Stacy Keibler
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 1,690
#
# [12/421] 查询: Jerry Rice (Season 2, Year 2006)
#   ✓ 找到页面: Jerry Rice
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 637
#
# [13/421] 查询: Giselle Fernandez (Season 2, Year 2006)
#   ✓ 找到页面: Barbie & Teresa: Recipe for Friendship
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 0
#
# [14/421] 查询: Master P (Season 2, Year 2006)
#   ✓ 找到页面: Master P
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 865
#
# [15/421] 查询: Drew Lachey (Season 2, Year 2006)
#   ✓ 找到页面: Drew Lachey
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 107
#
# [16/421] 查询: Kenny Mayne (Season 2, Year 2006)
#   ✓ 找到页面: Kenny Mayne
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 74
#
# [17/421] 查询: Harry Hamlin (Season 3, Year 2006)
#   ✓ 找到页面: Harry Hamlin
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 79
#
# [18/421] 查询: Vivica A. Fox (Season 3, Year 2006)
#   ✓ 找到页面: Vivica A. Fox
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 157
#
# [19/421] 查询: Monique Coleman (Season 3, Year 2006)
#   ✓ 找到页面: Monique Coleman
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 427
#
# [20/421] 查询: Joey Lawrence (Season 3, Year 2006)
#   ✓ 找到页面: Joey Lawrence
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 158
#
# [21/421] 查询: Mario Lopez (Season 3, Year 2006)
#   ✓ 找到页面: Mario Lopez
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 424
#
# [22/421] 查询: Emmitt Smith (Season 3, Year 2006)
#   ✓ 找到页面: Emmitt Smith
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 438
#
# [23/421] 查询: Shanna Moakler (Season 3, Year 2006)
#   ✓ 找到页面: Shanna Moakler
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 228
#
# [24/421] 查询: Willa Ford (Season 3, Year 2006)
#   ✓ 找到页面: Willa Ford
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 897
#
# [25/421] 查询: Sara Evans (Season 3, Year 2006)
#   ✓ 找到页面: Sara Evans
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 544
#
# [26/421] 查询: Jerry Springer (Season 3, Year 2006)
#   ✓ 找到页面: Jerry Springer
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 431
#
# [27/421] 查询: Tucker Carlson (Season 3, Year 2006)
#   ✓ 找到页面: Tucker Carlson
#     统计年份范围: 2005 - 2006
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 999
#
# [28/421] 查询: John Ratzenberger (Season 4, Year 2007)
#   ✓ 找到页面: John Ratzenberger
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 359
#
# [29/421] 查询: Ian Ziering (Season 4, Year 2007)
#   ✓ 找到页面: Ian Ziering
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 145
#
# [30/421] 查询: Clyde Drexler (Season 4, Year 2007)
#   ✓ 找到页面: Clyde Drexler
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 236
#
# [31/421] 查询: Laila Ali (Season 4, Year 2007)
#   ✓ 找到页面: Laila Ali
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 277
#
# [32/421] 查询: Apolo Anton Ohno (Season 4, Year 2007)
#   ✓ 找到页面: Karina Smirnoff
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 218
#
# [33/421] 查询: Shandi Finnessey (Season 4, Year 2007)
#   ✓ 找到页面: Shandi Finnessey
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 295
#
# [34/421] 查询: Paulina Porizkova (Season 4, Year 2007)
#   ✓ 找到页面: Paulina Porizkova
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 330
#
# [35/421] 查询: Heather Mills (Season 4, Year 2007)
#   ✓ 找到页面: Heather Mills
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 1,087
#
# [36/421] 查询: Billy Ray Cyrus (Season 4, Year 2007)
#   ✓ 找到页面: Billy Ray Cyrus
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 2,199
#
# [37/421] 查询: Joey Fatone (Season 4, Year 2007)
#   ✓ 找到页面: Joey Fatone
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 452
#
# [38/421] 查询: Leeza Gibbons (Season 4, Year 2007)
#   ✓ 找到页面: Leeza Gibbons
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 93
#
# [39/421] 查询: Cameron Mathison (Season 5, Year 2007)
#   ✓ 找到页面: Cameron Mathison
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 94
#
# [40/421] 查询: Jane Seymour (Season 5, Year 2007)
#   ✓ 找到页面: Jane Seymour
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 416
#
# [41/421] 查询: Sabrina Bryan (Season 5, Year 2007)
#   ✓ 找到页面: Sabrina Bryan
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 801
#
# [42/421] 查询: Jennie Garth (Season 5, Year 2007)
#   ✓ 找到页面: Jennie Garth
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 279
#
# [43/421] 查询: Floyd Mayweather Jr.  (Season 5, Year 2007)
#   ✓ 找到页面: Floyd Mayweather Jr.
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 1,603
#
# [44/421] 查询: Josie Maran (Season 5, Year 2007)
#   ✓ 找到页面: Josie Maran
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 461
#
# [45/421] 查询: Albert Reed (Season 5, Year 2007)
# d:\app\miniconda3\envs\mlwork\Lib\site-packages\wikipedia\wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file d:\app\miniconda3\envs\mlwork\Lib\site-packages\wikipedia\wikipedia.py. To get rid of this warning, pass the additional argument 'features="html.parser"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')
#   ✓ 找到页面: Albert Reed (model)
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 49
#
# [46/421] 查询: Helio Castroneves (Season 5, Year 2007)
#   ✓ 找到页面: 2002 Indy Racing League
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 30
#
# [47/421] 查询: Mel B (Season 5, Year 2007)
#   ✓ 找到页面: Mel B
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 1,039
#
# [48/421] 查询: Wayne Newton (Season 5, Year 2007)
#   ✓ 找到页面: Wayne Newton
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 333
#
# [49/421] 查询: Marie Osmond (Season 5, Year 2007)
#   ✓ 找到页面: Marie Osmond
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 558
#
# [50/421] 查询: Mark Cuban (Season 5, Year 2007)
#   ✓ 找到页面: Mark Cuban
#     统计年份范围: 2005 - 2007
#   ✓ 累计浏览量（至2007年）: 0
#   ✓ 累计编辑次数（至2007年）: 1,405
#
# [51/421] 查询: Cristian de la Fuente (Season 6, Year 2008)
#   ✓ 找到页面: Corazón salvaje (2009 TV series)
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [52/421] 查询: Steve Guttenberg (Season 6, Year 2008)
#   ✓ 找到页面: Steve Guttenberg
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 662
#
# [53/421] 查询: Priscilla Presley (Season 6, Year 2008)
#   ✓ 找到页面: Priscilla Presley
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 634
#
# [54/421] 查询: Marlee Matlin (Season 6, Year 2008)
#   ✓ 找到页面: Marlee Matlin
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 417
#
# [55/421] 查询: Shannon Elizabeth (Season 6, Year 2008)
#   ✓ 找到页面: Shannon Elizabeth
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 780
#
# [56/421] 查询: Marissa Jaret Winokur (Season 6, Year 2008)
#   ✓ 找到页面: Marissa Jaret Winokur
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 223
#
# [57/421] 查询: Jason Taylor (Season 6, Year 2008)
#   ✓ 找到页面: Jason Taylor (American football)
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 650
#
# [58/421] 查询: Kristi Yamaguchi (Season 6, Year 2008)
#   ✓ 找到页面: Kristi Yamaguchi
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 643
#
# [59/421] 查询: Monica Seles (Season 6, Year 2008)
#   ✓ 找到页面: Monica Seles
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 1,026
#
# [60/421] 查询: Penn Jillette (Season 6, Year 2008)
#   ✓ 找到页面: Penn Jillette
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 729
#
# [61/421] 查询: Adam Carolla (Season 6, Year 2008)
#   ✓ 找到页面: Adam Carolla
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 1,307
#
# [62/421] 查询: Mario (Season 6, Year 2008)
#   ✓ 找到页面: The Super Mario Galaxy Movie
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [63/421] 查询: Ted McGinley (Season 7, Year 2008)
#   ✓ 找到页面: Ted McGinley
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 237
#
# [64/421] 查询: Cloris Leachman (Season 7, Year 2008)
#   ✓ 找到页面: Cloris Leachman
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 555
#
# [65/421] 查询: Susan Lucci (Season 7, Year 2008)
#   ✓ 找到页面: Susan Lucci
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 438
#
# [66/421] 查询: Cody Linley (Season 7, Year 2008)
#   ✓ 找到页面: Cody Linley
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 1,832
#
# [67/421] 查询: Misty May-Treanor (Season 7, Year 2008)
#   ✓ 找到页面: Misty May-Treanor
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 661
#
# [68/421] 查询: Maurice Greene (Season 7, Year 2008)
#   ✓ 找到页面: Maurice Greene (fighter)
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [69/421] 查询: Warren Sapp (Season 7, Year 2008)
#   ✓ 找到页面: Warren Sapp
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 732
#
# [70/421] 查询: Jeffrey Ross (Season 7, Year 2008)
#   ✓ 找到页面: Jeffrey Ross Gunter
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [71/421] 查询: Toni Braxton (Season 7, Year 2008)
#   ✓ 找到页面: Toni Braxton
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 1,944
#
# [72/421] 查询: Lance Bass (Season 7, Year 2008)
#   ✓ 找到页面: Lance Bass
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 2,675
#
# [73/421] 查询: Kim Kardashian (Season 7, Year 2008)
#   ✓ 找到页面: Kim Kardashian
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 2,719
#
# [74/421] 查询: Rocco DiSpirito (Season 7, Year 2008)
#   ✓ 找到页面: Rocco DiSpirito
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 140
#
# [75/421] 查询: Brooke Burke (Season 7, Year 2008)
#   ✓ 找到页面: Brooke Burke
#     统计年份范围: 2005 - 2008
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 754
#
# [76/421] 查询: Gilles Marini (Season 8, Year 2009)
#   ✓ 找到页面: Gilles Marini
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 128
#
# [77/421] 查询: Denise Richards (Season 8, Year 2009)
#   ✓ 找到页面: Denise Richards
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,215
#
# [78/421] 查询: David Alan Grier (Season 8, Year 2009)
#   ✓ 找到页面: David Alan Grier
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 419
#
# [79/421] 查询: Lawrence Taylor (Season 8, Year 2009)
#   ✓ 找到页面: Lawrence Taylor
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,911
#
# [80/421] 查询: Ty Murray (Season 8, Year 2009)
#   ✓ 找到页面: Ty Murray
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 243
#
# [81/421] 查询: Shawn Johnson (Season 8, Year 2009)
#   ✓ 找到页面: Shawn Johnson East
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,293
#
# [82/421] 查询: Steve Wozniak (Season 8, Year 2009)
#   ✓ 找到页面: Steve Wozniak
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 2,458
#
# [83/421] 查询: Belinda Carlisle (Season 8, Year 2009)
#   ✓ 找到页面: Belinda Carlisle
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,185
#
# [84/421] 查询: Chuck Wicks (Season 8, Year 2009)
#   ✓ 找到页面: Chuck Wicks
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 425
#
# [85/421] 查询: Lil' Kim (Season 8, Year 2009)
#   ✓ 找到页面: Lil' Kim
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 4,336
#
# [86/421] 查询: Steve-O (Season 8, Year 2009)
#   ✓ 找到页面: Steve-O
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,684
#
# [87/421] 查询: Holly Madison (Season 8, Year 2009)
#   ✓ 找到页面: Holly Madison
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,205
#
# [88/421] 查询: Melissa Rycroft (Season 8, Year 2009)
#   ✓ 找到页面: Melissa Rycroft
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 381
#
# [89/421] 查询: Ashley Hamiliton (Season 9, Year 2009)
#   ✓ 找到页面: Chronology of discoveries of water on Mars
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 0
#
# [90/421] 查询: Debi Mazar (Season 9, Year 2009)
#   ✓ 找到页面: Debi Mazar
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 264
#
# [91/421] 查询: Melissa Joan Hart (Season 9, Year 2009)
#   ✓ 找到页面: Melissa Joan Hart
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,220
#
# [92/421] 查询: Mark Dacascos (Season 9, Year 2009)
#   ✓ 找到页面: Mark Dacascos
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 302
#
# [93/421] 查询: Chuck Liddell (Season 9, Year 2009)
#   ✓ 找到页面: Chuck Liddell
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 3,603
#
# [94/421] 查询: Natalie Coughlin (Season 9, Year 2009)
#   ✓ 找到页面: Natalie Coughlin
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 213
#
# [95/421] 查询: Louie Vito (Season 9, Year 2009)
#   ✓ 找到页面: Louie Vito
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 146
#
# [96/421] 查询: Michael Irvin (Season 9, Year 2009)
#   ✓ 找到页面: Michael Irvin
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,154
#
# [97/421] 查询: Joanna Krupa (Season 9, Year 2009)
#   ✓ 找到页面: Joanna Krupa
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 615
#
# [98/421] 查询: Kathy Ireland (Season 9, Year 2009)
#   ✓ 找到页面: Kathy Ireland
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 466
#
# [99/421] 查询: Tom DeLay (Season 9, Year 2009)
#   ✓ 找到页面: Tom DeLay
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 3,207
#
# [100/421] 查询: Macy Gray (Season 9, Year 2009)
#   ✓ 找到页面: Macy Gray
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 822
#
# [101/421] 查询: Aaron Carter (Season 9, Year 2009)
#   ✓ 找到页面: Aaron Carter
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 2,433
#
# [102/421] 查询: Mya (Season 9, Year 2009)
#   ✓ 找到页面: Mya (singer)
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 4,259
#
# [103/421] 查询: Donny Osmond (Season 9, Year 2009)
#   ✓ 找到页面: Donny Osmond
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 982
#
# [104/421] 查询: Kelly Osbourne (Season 9, Year 2009)
#   ✓ 找到页面: Kelly Osbourne
#     统计年份范围: 2005 - 2009
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 1,342
#
# [105/421] 查询: Aiden Turner (Season 10, Year 2010)
#   ✓ 找到页面: Aiden Turner
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 167
#
# [106/421] 查询: Shannen Doherty (Season 10, Year 2010)
#   ✓ 找到页面: Shannen Doherty
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,768
#
# [107/421] 查询: Niecy Nash (Season 10, Year 2010)
#   ✓ 找到页面: Niecy Nash
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 325
#
# [108/421] 查询: Buzz Aldrin (Season 10, Year 2010)
#   ✓ 找到页面: Buzz Aldrin
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,964
#
# [109/421] 查询: Chad Ochocinco (Season 10, Year 2010)
#   ✓ 找到页面: American Reunion
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 0
#
# [110/421] 查询: Evan Lysacek (Season 10, Year 2010)
#   ✓ 找到页面: Evan Lysacek
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,279
#
# [111/421] 查询: Pamela Anderson (Season 10, Year 2010)
#   ✓ 找到页面: Pamela Anderson
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 5,171
#
# [112/421] 查询: Nicole Scherzinger (Season 10, Year 2010)
#   ✓ 找到页面: Nicole Scherzinger
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 7,063
#
# [113/421] 查询: Erin Andrews (Season 10, Year 2010)
#   ✓ 找到页面: Erin Andrews
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,318
#
# [114/421] 查询: Kate Gosselin (Season 10, Year 2010)
#   ✓ 找到页面: Kate Gosselin
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,530
#
# [115/421] 查询: Jake Pavelka (Season 10, Year 2010)
#   ✓ 找到页面: Jake Pavelka
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 70
#
# [116/421] 查询: David Hasselhoff (Season 11, Year 2010)
#   ✓ 找到页面: David Hasselhoff
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 4,679
#
# [117/421] 查询: Florence Henderson (Season 11, Year 2010)
#   ✓ 找到页面: Florence Henderson
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 436
#
# [118/421] 查询: Kyle Massey (Season 11, Year 2010)
#   ✓ 找到页面: Kyle Massey
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 2,205
#
# [119/421] 查询: Jennifer Grey (Season 11, Year 2010)
#   ✓ 找到页面: Jennifer Grey
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 538
#
# [120/421] 查询: Rick Fox (Season 11, Year 2010)
#   ✓ 找到页面: Rick Fox
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 640
#
# [121/421] 查询: Kurt Warner (Season 11, Year 2010)
#   ✓ 找到页面: Kurt Warner
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 2,339
#
# [122/421] 查询: Margaret Cho (Season 11, Year 2010)
#   ✓ 找到页面: Margaret Cho
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,217
#
# [123/421] 查询: Michael Bolton (Season 11, Year 2010)
#   ✓ 找到页面: Michael Bolton
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,482
#
# [124/421] 查询: Brandy (Season 11, Year 2010)
#   ✓ 找到页面: Brandy
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 884
#
# [125/421] 查询: The Situation (Season 11, Year 2010)
#   ✓ 找到页面: Michael Sorrentino
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 206
#
# [126/421] 查询: Audrina Patridge (Season 11, Year 2010)
#   ✓ 找到页面: Audrina Patridge
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,550
#
# [127/421] 查询: Bristol Palin (Season 11, Year 2010)
#   ✓ 找到页面: Bristol Palin
#     统计年份范围: 2005 - 2010
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 1,109
#
# [128/421] 查询: Ralph Macchio (Season 12, Year 2011)
#   ✓ 找到页面: Ralph Macchio
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,221
#
# [129/421] 查询: Chelsea Kane (Season 12, Year 2011)
#   ✓ 找到页面: Chelsea Kane
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,869
#
# [130/421] 查询: Kirstie Alley (Season 12, Year 2011)
#   ✓ 找到页面: Kirstie Alley
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,546
#
# [131/421] 查询: Hines Ward (Season 12, Year 2011)
#   ✓ 找到页面: Hines Ward
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,890
#
# [132/421] 查询: Sugar Ray Leonard (Season 12, Year 2011)
#   ✓ 找到页面: Sugar Ray Leonard
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,295
#
# [133/421] 查询: Chris Jericho (Season 12, Year 2011)
#   ✓ 找到页面: Chris Jericho
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 8,158
#
# [134/421] 查询: Petra Nemcova (Season 12, Year 2011)
#   ✓ 找到页面: A Model Life
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 124
#
# [135/421] 查询: Mike Catherwood (Season 12, Year 2011)
#   ✓ 找到页面: Drew Pinsky
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 994
#
# [136/421] 查询: Romeo (Season 12, Year 2011)
#   ✓ 找到页面: Romeo
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 913
#
# [137/421] 查询: Wendy Williams (Season 12, Year 2011)
#   ✓ 找到页面: Wendy Williams
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,813
#
# [138/421] 查询: Kendra Wilkinson (Season 12, Year 2011)
#   ✓ 找到页面: Kendra Wilkinson
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 2,224
#
# [139/421] 查询: Elisabetta Canalis (Season 13, Year 2011)
#   ✓ 找到页面: Elisabetta Canalis
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 340
#
# [140/421] 查询: David Arquette (Season 13, Year 2011)
#   ✓ 找到页面: David Arquette
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,205
#
# [141/421] 查询: Ricki Lake (Season 13, Year 2011)
#   ✓ 找到页面: Ricki Lake
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 914
#
# [142/421] 查询: J.R. Martinez (Season 13, Year 2011)
#   ✓ 找到页面: Sergio Martínez (boxer)
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 495
#
# [143/421] 查询: Metta World Peace (Ron) (Season 13, Year 2011)
#   ✓ 找到页面: Sichuan Blue Whales
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 0
#
# [144/421] 查询: Hope Solo (Season 13, Year 2011)
#   ✓ 找到页面: Hope Solo
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 701
#
# [145/421] 查询: Chynna Phillips (Season 13, Year 2011)
#   ✓ 找到页面: Chynna Phillips
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 245
#
# [146/421] 查询: Kristin Cavallari (Season 13, Year 2011)
#   ✓ 找到页面: Kristin Cavallari
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 2,036
#
# [147/421] 查询: Carson Kressley (Season 13, Year 2011)
#   ✓ 找到页面: Carson Kressley
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 453
#
# [148/421] 查询: Chaz Bono (Season 13, Year 2011)
#   ✓ 找到页面: Chaz Bono
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 945
#
# [149/421] 查询: Nancy Grace (Season 13, Year 2011)
#   ✓ 找到页面: Nancy Grace
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 2,857
#
# [150/421] 查询: Rob Kardashian (Season 13, Year 2011)
#   ✓ 找到页面: Rob Kardashian
#     统计年份范围: 2005 - 2011
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 1,567
#
# [151/421] 查询: William Levy (Season 14, Year 2012)
#   ✓ 找到页面: William Levy (actor)
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,942
#
# [152/421] 查询: Jack Wagner (Season 14, Year 2012)
#   ✓ 找到页面: Jack Wagner (actor)
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 403
#
# [153/421] 查询: Sherri Sheperd (Season 14, Year 2012)
#   ✓ 找到页面: List of dramatic television series with LGBTQ characters: 1960s–2000s
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 0
#
# [154/421] 查询: Jaleel White (Season 14, Year 2012)
#   ✓ 找到页面: Jaleel White
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,994
#
# [155/421] 查询: Roshon Fegan (Season 14, Year 2012)
#   ✓ 找到页面: Roshon Fegan
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 943
#
# [156/421] 查询: Melissa Gilbert (Season 14, Year 2012)
#   ✓ 找到页面: Melissa Gilbert
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 678
#
# [157/421] 查询: Martina Navratilova (Season 14, Year 2012)
#   ✓ 找到页面: Martina Navratilova
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,848
#
# [158/421] 查询: Donald Driver (Season 14, Year 2012)
#   ✓ 找到页面: Donald Driver
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 738
#
# [159/421] 查询: Gavin DeGraw (Season 14, Year 2012)
#   ✓ 找到页面: Gavin DeGraw
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,362
#
# [160/421] 查询: Gladys Knight (Season 14, Year 2012)
#   ✓ 找到页面: Gladys Knight
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,160
#
# [161/421] 查询: Katherine Jenkins (Season 14, Year 2012)
#   ✓ 找到页面: Katherine Jenkins
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,195
#
# [162/421] 查询: Maria Menounos (Season 14, Year 2012)
#   ✓ 找到页面: Maria Menounos
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 911
#
# [163/421] 查询: Gilles Marini (Season 15, Year 2012)
#   ✓ 找到页面: Gilles Marini
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 244
#
# [164/421] 查询: Sabrina Bryan (Season 15, Year 2012)
#   ✓ 找到页面: Sabrina Bryan
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 2,048
#
# [165/421] 查询: Kirstie Alley (Season 15, Year 2012)
#   ✓ 找到页面: Kirstie Alley
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,668
#
# [166/421] 查询: Kelly Monaco (Season 15, Year 2012)
#   ✓ 找到页面: Kelly Monaco
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 941
#
# [167/421] 查询: Apolo Anton Ohno (Season 15, Year 2012)
#   ✓ 找到页面: Karina Smirnoff
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 974
#
# [168/421] 查询: Emmitt Smith (Season 15, Year 2012)
#   ✓ 找到页面: Emmitt Smith
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 2,154
#
# [169/421] 查询: Shawn Johnson (Season 15, Year 2012)
#   ✓ 找到页面: Shawn Johnson East
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,929
#
# [170/421] 查询: Pamela Anderson (Season 15, Year 2012)
#   ✓ 找到页面: Pamela Anderson
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 5,720
#
# [171/421] 查询: Helio Castroneves (Season 15, Year 2012)
#   ✓ 找到页面: 2002 Indy Racing League
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 130
#
# [172/421] 查询: Joey Fatone (Season 15, Year 2012)
#   ✓ 找到页面: Joey Fatone
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 980
#
# [173/421] 查询: Drew Lachey (Season 15, Year 2012)
#   ✓ 找到页面: Drew Lachey
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 346
#
# [174/421] 查询: Bristol Palin (Season 15, Year 2012)
#   ✓ 找到页面: Bristol Palin
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,514
#
# [175/421] 查询: Melissa Rycroft (Season 15, Year 2012)
#   ✓ 找到页面: Melissa Rycroft
#     统计年份范围: 2005 - 2012
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 554
#
# [176/421] 查询: Ingo Rademacher (Season 16, Year 2013)
#   ✓ 找到页面: Ingo Rademacher
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 241
#
# [177/421] 查询: Zendaya (Season 16, Year 2013)
#   ✓ 找到页面: Zendaya
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 1,757
#
# [178/421] 查询: Dorothy Hamill (Season 16, Year 2013)
#   ✓ 找到页面: Dorothy Hamill
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 391
#
# [179/421] 查询: Victor Ortiz (Season 16, Year 2013)
#   ✓ 找到页面: Victor Ortiz
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 993
#
# [180/421] 查询: Alexandra Raisman (Season 16, Year 2013)
#   ✓ 找到页面: Gymnastics at the 2016 Summer Olympics – Women's balance beam
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [181/421] 查询: Jacoby Jones (Season 16, Year 2013)
#   ✓ 找到页面: Jacoby Jones
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 457
#
# [182/421] 查询: D. L. Hughley (Season 16, Year 2013)
#   ✓ 找到页面: D. L. Hughley
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 587
#
# [183/421] 查询: Andy Dick (Season 16, Year 2013)
#   ✓ 找到页面: Andy Dick
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 2,355
#
# [184/421] 查询: Wynonna Judd (Season 16, Year 2013)
#   ✓ 找到页面: Wynonna Judd
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 743
#
# [185/421] 查询: Kellie Pickler (Season 16, Year 2013)
#   ✓ 找到页面: Kellie Pickler
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 3,532
#
# [186/421] 查询: Lisa Vanderpump (Season 16, Year 2013)
#   ✓ 找到页面: Lisa Vanderpump
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 102
#
# [187/421] 查询: Sean Lowe (Season 16, Year 2013)
#   ✓ 找到页面: Sean Lowe (television personality)
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 0
#
# [188/421] 查询: Valerie Harper (Season 17, Year 2013)
#   ✓ 找到页面: Valerie Harper
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 581
#
# [189/421] 查询: Brant Daugherty (Season 17, Year 2013)
#   ✓ 找到页面: Brant Daugherty
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 199
#
# [190/421] 查询: Elizabeth Berkley Lauren (Season 17, Year 2013)
#   ✓ 找到页面: Elizabeth Berkley
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 1,019
#
# [191/421] 查询: Leah Remini (Season 17, Year 2013)
#   ✓ 找到页面: Leah Remini
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 1,459
#
# [192/421] 查询: Corbin Bleu (Season 17, Year 2013)
#   ✓ 找到页面: Corbin Bleu
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 5,967
#
# [193/421] 查询: Amber Riley (Season 17, Year 2013)
#   ✓ 找到页面: Amber Riley
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 519
#
# [194/421] 查询: Keyshawn Johnson (Season 17, Year 2013)
#   ✓ 找到页面: Keyshawn Johnson
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 720
#
# [195/421] 查询: Bill Engvall (Season 17, Year 2013)
#   ✓ 找到页面: Bill Engvall
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 676
#
# [196/421] 查询: Christina Milian (Season 17, Year 2013)
#   ✓ 找到页面: Christina Milian
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 4,663
#
# [197/421] 查询: Nicole "Snooki" Polizzi (Season 17, Year 2013)
#   ✓ 找到页面: Snooki
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 1,514
#
# [198/421] 查询: Jack Osbourne (Season 17, Year 2013)
#   ✓ 找到页面: Jack Osbourne
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 787
#
# [199/421] 查询: Bill Nye (Season 17, Year 2013)
#   ✓ 找到页面: Bill Nye
#     统计年份范围: 2005 - 2013
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 3,841
#
# [200/421] 查询: Billy Dee Williams (Season 18, Year 2014)
#   ✓ 找到页面: Billy Dee Williams
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,103
#
# [201/421] 查询: Danica McKellar (Season 18, Year 2014)
#   ✓ 找到页面: Danica McKellar
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 998
#
# [202/421] 查询: James Maslow (Season 18, Year 2014)
#   ✓ 找到页面: James Maslow
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 2,337
#
# [203/421] 查询: Candace Cameron Bure (Season 18, Year 2014)
#   ✓ 找到页面: Candace Cameron Bure
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,335
#
# [204/421] 查询: Sean Avery (Season 18, Year 2014)
#   ✓ 找到页面: Sean Avery
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 3,080
#
# [205/421] 查询: Diana Nyad (Season 18, Year 2014)
#   ✓ 找到页面: Diana Nyad
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 663
#
# [206/421] 查询: Charlie White (Season 18, Year 2014)
#   ✓ 找到页面: Charlie White (figure skater)
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 853
#
# [207/421] 查询: Amy Purdy (Season 18, Year 2014)
#   ✓ 找到页面: Amy Purdy
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 254
#
# [208/421] 查询: Meryl Davis (Season 18, Year 2014)
#   ✓ 找到页面: Meryl Davis
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,020
#
# [209/421] 查询: Drew Carey (Season 18, Year 2014)
#   ✓ 找到页面: Drew Carey
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 2,528
#
# [210/421] 查询: Cody Simpson (Season 18, Year 2014)
#   ✓ 找到页面: Cody Simpson
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,777
#
# [211/421] 查询: NeNe Leakes (Season 18, Year 2014)
#   ✓ 找到页面: NeNe Leakes
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 707
#
# [212/421] 查询: Antonio Sabato Jr. (Season 19, Year 2014)
#   ✓ 找到页面: Virginia Madsen
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 739
#
# [213/421] 查询: Jonathan Bennett (Season 19, Year 2014)
#   ✓ 找到页面: Jonathan Bennett (actor)
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 682
#
# [214/421] 查询: Lea Thompson (Season 19, Year 2014)
#   ✓ 找到页面: Lea Thompson
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 655
#
# [215/421] 查询: Janel Parrish (Season 19, Year 2014)
#   ✓ 找到页面: Janel Parrish
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 686
#
# [216/421] 查询: Alfonso Ribeiro (Season 19, Year 2014)
#   ✓ 找到页面: Alfonso Ribeiro
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,740
#
# [217/421] 查询: Lolo Jones (Season 19, Year 2014)
#   ✓ 找到页面: Lolo Jones
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 787
#
# [218/421] 查询: Randy Couture (Season 19, Year 2014)
#   ✓ 找到页面: Randy Couture
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 4,245
#
# [219/421] 查询: Tommy Chong (Season 19, Year 2014)
#   ✓ 找到页面: Tommy Chong
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,246
#
# [220/421] 查询: Betsey Johnson (Season 19, Year 2014)
#   ✓ 找到页面: Betsey Johnson
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 436
#
# [221/421] 查询: Michael Waltrip (Season 19, Year 2014)
#   ✓ 找到页面: Michael Waltrip
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 1,190
#
# [222/421] 查询: Tavis Smiley (Season 19, Year 2014)
#   ✓ 找到页面: Tavis Smiley
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 586
#
# [223/421] 查询: Bethany Mota (Season 19, Year 2014)
#   ✓ 找到页面: Bethany Mota
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 412
#
# [224/421] 查询: Sadie Robertson (Season 19, Year 2014)
#   ✓ 找到页面: Sadie Robertson
#     统计年份范围: 2005 - 2014
#   ✓ 累计浏览量（至2014年）: 0
#   ✓ 累计编辑次数（至2014年）: 211
#
# [225/421] 查询: Suzanne Somers (Season 20, Year 2015)
#   ✓ 找到页面: Suzanne Somers
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 235,691
#   ✓ 累计编辑次数（至2015年）: 904
#
# [226/421] 查询: Willow Shields (Season 20, Year 2015)
#   ✓ 找到页面: Willow Shields
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 234,385
#   ✓ 累计编辑次数（至2015年）: 567
#
# [227/421] 查询: Riker Lynch (Season 20, Year 2015)
#   ✓ 找到页面: Riker Lynch
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 159,374
#   ✓ 累计编辑次数（至2015年）: 684
#
# [228/421] 查询: Rumer Willis (Season 20, Year 2015)
#   ✓ 找到页面: Rumer Willis
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 439,034
#   ✓ 累计编辑次数（至2015年）: 877
#
# [229/421] 查询: Nastia Liukin (Season 20, Year 2015)
#   ✓ 找到页面: Nastia Liukin Cup
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 3,461
#   ✓ 累计编辑次数（至2015年）: 47
#
# [230/421] 查询: Michael Sam (Season 20, Year 2015)
#   ✓ 找到页面: Michael Sam
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 317,811
#   ✓ 累计编辑次数（至2015年）: 611
#
# [231/421] 查询: Robert Herjavec (Season 20, Year 2015)
#   ✓ 找到页面: Robert Herjavec
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 553,249
#   ✓ 累计编辑次数（至2015年）: 491
#
# [232/421] 查询: Charlotte McKinney (Season 20, Year 2015)
#   ✓ 找到页面: Charlotte McKinney
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 493,035
#   ✓ 累计编辑次数（至2015年）: 190
#
# [233/421] 查询: Noah Galloway (Season 20, Year 2015)
#   ✓ 找到页面: Noah Galloway
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 94,003
#   ✓ 累计编辑次数（至2015年）: 166
#
# [234/421] 查询: Redfoo (Season 20, Year 2015)
#   ✓ 找到页面: Redfoo
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 436,746
#   ✓ 累计编辑次数（至2015年）: 978
#
# [235/421] 查询: Patti LaBelle (Season 20, Year 2015)
#   ✓ 找到页面: Patti LaBelle
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 324,013
#   ✓ 累计编辑次数（至2015年）: 2,450
#
# [236/421] 查询: Chris Soules (Season 20, Year 2015)
#   ✓ 找到页面: Chris Soules
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 99,152
#   ✓ 累计编辑次数（至2015年）: 65
#
# [237/421] 查询: Gary Busey (Season 21, Year 2015)
#   ✓ 找到页面: Gary Busey
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 1,365,004
#   ✓ 累计编辑次数（至2015年）: 2,819
#
# [238/421] 查询: Alexa PenaVega (Season 21, Year 2015)
#   ✓ 找到页面: Alexa PenaVega
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 233,251
#   ✓ 累计编辑次数（至2015年）: 2,125
#
# [239/421] 查询: Carlos PenaVega (Season 21, Year 2015)
#   ✓ 找到页面: Carlos PenaVega
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 97,826
#   ✓ 累计编辑次数（至2015年）: 1,942
#
# [240/421] 查询: Victor Espinoza (Season 21, Year 2015)
#   ✓ 找到页面: Victor Espinoza
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 189,012
#   ✓ 累计编辑次数（至2015年）: 241
#
# [241/421] 查询: Alek Skarlatos (Season 21, Year 2015)
#   ✓ 找到页面: Alek Skarlatos
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 520,847
#   ✓ 累计编辑次数（至2015年）: 150
#
# [242/421] 查询: Chaka Khan (Season 21, Year 2015)
#   ✓ 找到页面: Chaka Khan
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 508,082
#   ✓ 累计编辑次数（至2015年）: 1,761
#
# [243/421] 查询: Andy Grammer (Season 21, Year 2015)
#   ✓ 找到页面: Andy Grammer
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 775,284
#   ✓ 累计编辑次数（至2015年）: 802
#
# [244/421] 查询: Tamar Braxton (Season 21, Year 2015)
#   ✓ 找到页面: Tamar Braxton
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 828,412
#   ✓ 累计编辑次数（至2015年）: 1,847
#
# [245/421] 查询: Nick Carter (Season 21, Year 2015)
#   ✓ 找到页面: Nick Carter
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 25,902
#   ✓ 累计编辑次数（至2015年）: 3,039
#
# [246/421] 查询: Hayes Grier (Season 21, Year 2015)
#   ✓ 找到页面: Hayes Grier
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 384,198
#   ✓ 累计编辑次数（至2015年）: 147
#
# [247/421] 查询: Bindi Irwin (Season 21, Year 2015)
#   ✓ 找到页面: Bindi Irwin
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 1,561,823
#   ✓ 累计编辑次数（至2015年）: 2,156
#
# [248/421] 查询: Kim Zolciak-Biermann (Season 21, Year 2015)
#   ✓ 找到页面: Kim Zolciak
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 1,242,975
#   ✓ 累计编辑次数（至2015年）: 1,411
#
# [249/421] 查询: Paula Deen (Season 21, Year 2015)
#   ✓ 找到页面: Paula Deen
#     统计年份范围: 2005 - 2015
#   ✓ 累计浏览量（至2015年）: 416,444
#   ✓ 累计编辑次数（至2015年）: 2,128
#
# [250/421] 查询: Mischa Barton (Season 22, Year 2016)
#   ✓ 找到页面: Mischa Barton
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,763,736
#   ✓ 累计编辑次数（至2016年）: 3,309
#
# [251/421] 查询: Kim Fields (Season 22, Year 2016)
#   ✓ 找到页面: Kim Fields
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,417,823
#   ✓ 累计编辑次数（至2016年）: 494
#
# [252/421] 查询: Jodie Sweetin (Season 22, Year 2016)
#   ✓ 找到页面: Jodie Sweetin
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 4,574,790
#   ✓ 累计编辑次数（至2016年）: 1,449
#
# [253/421] 查询: Doug Flutie (Season 22, Year 2016)
#   ✓ 找到页面: Doug Flutie
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,503,008
#   ✓ 累计编辑次数（至2016年）: 1,603
#
# [254/421] 查询: Von Miller (Season 22, Year 2016)
#   ✓ 找到页面: Von Miller
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 2,365,234
#   ✓ 累计编辑次数（至2016年）: 1,400
#
# [255/421] 查询: Antonio Brown (Season 22, Year 2016)
#   ✓ 找到页面: Antonio Brown
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,925,484
#   ✓ 累计编辑次数（至2016年）: 1,423
#
# [256/421] 查询: Paige VanZant (Season 22, Year 2016)
#   ✓ 找到页面: Paige VanZant
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 2,125,788
#   ✓ 累计编辑次数（至2016年）: 389
#
# [257/421] 查询: Geraldo Rivera (Season 22, Year 2016)
#   ✓ 找到页面: Geraldo Rivera
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,252,260
#   ✓ 累计编辑次数（至2016年）: 2,384
#
# [258/421] 查询: Nyle DiMarco (Season 22, Year 2016)
#   ✓ 找到页面: Nyle DiMarco
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 2,029,702
#   ✓ 累计编辑次数（至2016年）: 471
#
# [259/421] 查询: Ginger Zee (Season 22, Year 2016)
#   ✓ 找到页面: Ginger Zee
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 963,171
#   ✓ 累计编辑次数（至2016年）: 251
#
# [260/421] 查询: Wanya Morris (Season 22, Year 2016)
#   ✓ 找到页面: Wanya Morris
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 476,173
#   ✓ 累计编辑次数（至2016年）: 197
#
# [261/421] 查询: Marla Maples (Season 22, Year 2016)
#   ✓ 找到页面: Marla Maples
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 9,481,148
#   ✓ 累计编辑次数（至2016年）: 687
#
# [262/421] 查询: Jake T. Austin (Season 23, Year 2016)
#   ✓ 找到页面: Jake T. Austin
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,670,226
#   ✓ 累计编辑次数（至2016年）: 4,160
#
# [263/421] 查询: Maureen McCormick (Season 23, Year 2016)
#   ✓ 找到页面: Maureen McCormick
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 2,122,152
#   ✓ 累计编辑次数（至2016年）: 1,132
#
# [264/421] 查询: Marilu Henner (Season 23, Year 2016)
#   ✓ 找到页面: Marilu Henner
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,156,233
#   ✓ 累计编辑次数（至2016年）: 666
#
# [265/421] 查询: Ryan Lochte (Season 23, Year 2016)
#   ✓ 找到页面: Ryan Lochte
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 3,136,723
#   ✓ 累计编辑次数（至2016年）: 1,979
#
# [266/421] 查询: Calvin Johnson Jr. (Season 23, Year 2016)
#   ✓ 找到页面: Calvin Johnson
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,986,082
#   ✓ 累计编辑次数（至2016年）: 3,294
#
# [267/421] 查询: Laurie Hernandez (Season 23, Year 2016)
#   ✓ 找到页面: Laurie Hernandez
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,590,395
#   ✓ 累计编辑次数（至2016年）: 357
#
# [268/421] 查询: Amber Rose (Season 23, Year 2016)
#   ✓ 找到页面: Amber Rose
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 6,361,156
#   ✓ 累计编辑次数（至2016年）: 2,165
#
# [269/421] 查询: Rick Perry (Season 23, Year 2016)
#   ✓ 找到页面: Rick Perry
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,193,544
#   ✓ 累计编辑次数（至2016年）: 5,363
#
# [270/421] 查询: James Hinchcliffe (Season 23, Year 2016)
#   ✓ 找到页面: James Hinchcliffe
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 566,746
#   ✓ 累计编辑次数（至2016年）: 397
#
# [271/421] 查询: Babyface (Season 23, Year 2016)
#   ✓ 找到页面: Babyface (musician)
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 1,060,942
#   ✓ 累计编辑次数（至2016年）: 1,229
#
# [272/421] 查询: Vanilla Ice (Season 23, Year 2016)
#   ✓ 找到页面: Vanilla Ice
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 2,008,799
#   ✓ 累计编辑次数（至2016年）: 3,672
#
# [273/421] 查询: Jana Kramer (Season 23, Year 2016)
#   ✓ 找到页面: Jana Kramer
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 2,165,404
#   ✓ 累计编辑次数（至2016年）: 966
#
# [274/421] 查询: Terra Jole (Season 23, Year 2016)
#   ✓ 找到页面: Dancing with the Stars (American TV series)
#     统计年份范围: 2005 - 2016
#   ✓ 累计浏览量（至2016年）: 0
#   ✓ 累计编辑次数（至2016年）: 9,391
#
# [275/421] 查询: Charo (Season 24, Year 2017)
#   ✓ 找到页面: Charo
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 2,708,486
#   ✓ 累计编辑次数（至2017年）: 1,295
#
# [276/421] 查询: Mr. T (Season 24, Year 2017)
#   ✓ 找到页面: Mr. T and Tina
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 72,855
#   ✓ 累计编辑次数（至2017年）: 67
#
# [277/421] 查询: Heather Morris (Season 24, Year 2017)
#   ✓ 找到页面: Heather Morris
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,155,297
#   ✓ 累计编辑次数（至2017年）: 1,252
#
# [278/421] 查询: Nancy Kerrigan (Season 24, Year 2017)
#   ✓ 找到页面: Nancy Kerrigan
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 3,398,530
#   ✓ 累计编辑次数（至2017年）: 999
#
# [279/421] 查询: Bonner Bolton (Season 24, Year 2017)
#   ✓ 找到页面: Bonner Bolton
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 373,210
#   ✓ 累计编辑次数（至2017年）: 55
#
# [280/421] 查询: Simone Biles (Season 24, Year 2017)
#   ✓ 找到页面: Simone Biles
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 5,994,602
#   ✓ 累计编辑次数（至2017年）: 1,586
#
# [281/421] 查询: David Ross (Season 24, Year 2017)
#   ✓ 找到页面: David Ross (baseball)
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,854,925
#   ✓ 累计编辑次数（至2017年）: 834
#
# [282/421] 查询: Rashad Jennings (Season 24, Year 2017)
#   ✓ 找到页面: Rashad Jennings
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,088,475
#   ✓ 累计编辑次数（至2017年）: 334
#
# [283/421] 查询: Chris Kattan (Season 24, Year 2017)
#   ✓ 找到页面: Chris Kattan
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,439,631
#   ✓ 累计编辑次数（至2017年）: 822
#
# [284/421] 查询: Erika Jayne (Season 24, Year 2017)
#   ✓ 找到页面: Erika Jayne
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 2,804,510
#   ✓ 累计编辑次数（至2017年）: 593
#
# [285/421] 查询: Normani (Season 24, Year 2017)
#   ✓ 找到页面: Normani
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 2,112
#   ✓ 累计编辑次数（至2017年）: 481
#
# [286/421] 查询: Nick Viall (Season 24, Year 2017)
#   ✓ 找到页面: Nick Viall
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 248,256
#   ✓ 累计编辑次数（至2017年）: 88
#
# [287/421] 查询: Sasha Pieterse (Season 25, Year 2017)
#   ✓ 找到页面: Sasha Pieterse
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 3,013,180
#   ✓ 累计编辑次数（至2017年）: 1,978
#
# [288/421] 查询: Frankie Muniz (Season 25, Year 2017)
#   ✓ 找到页面: Frankie Muniz
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 4,019,337
#   ✓ 累计编辑次数（至2017年）: 4,068
#
# [289/421] 查询: Jordan Fisher (Season 25, Year 2017)
#   ✓ 找到页面: Jordan Fisher
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,606,476
#   ✓ 累计编辑次数（至2017年）: 279
#
# [290/421] 查询: Derek Fisher (Season 25, Year 2017)
#   ✓ 找到页面: Derek Fisher
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,466,528
#   ✓ 累计编辑次数（至2017年）: 2,438
#
# [291/421] 查询: Nikki Bella (Season 25, Year 2017)
#   ✓ 找到页面: Nikki Bella
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 4,847,406
#   ✓ 累计编辑次数（至2017年）: 1,259
#
# [292/421] 查询: Terrell Owens (Season 25, Year 2017)
#   ✓ 找到页面: Terrell Owens
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 2,758,639
#   ✓ 累计编辑次数（至2017年）: 8,398
#
# [293/421] 查询: Victoria Arlen (Season 25, Year 2017)
#   ✓ 找到页面: Victoria Arlen
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 736,161
#   ✓ 累计编辑次数（至2017年）: 84
#
# [294/421] 查询: Barbara Corcoran (Season 25, Year 2017)
#   ✓ 找到页面: Daniel Mac
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 0
#   ✓ 累计编辑次数（至2017年）: 0
#
# [295/421] 查询: Lindsey Stirling (Season 25, Year 2017)
#   ✓ 找到页面: Lindsey Stirling
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 3,208,895
#   ✓ 累计编辑次数（至2017年）: 2,391
#
# [296/421] 查询: Debbie Gibson (Season 25, Year 2017)
#   ✓ 找到页面: Debbie Gibson
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,700,404
#   ✓ 累计编辑次数（至2017年）: 2,011
#
# [297/421] 查询: Nick Lachey (Season 25, Year 2017)
#   ✓ 找到页面: Nick Lachey
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 2,258,892
#   ✓ 累计编辑次数（至2017年）: 2,704
#
# [298/421] 查询: Drew Scott (Season 25, Year 2017)
#   ✓ 找到页面: Drew Scott
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,495,065
#   ✓ 累计编辑次数（至2017年）: 569
#
# [299/421] 查询: Vanessa Lachey (Season 25, Year 2017)
#   ✓ 找到页面: Vanessa Lachey
#     统计年份范围: 2005 - 2017
#   ✓ 累计浏览量（至2017年）: 1,636,204
#   ✓ 累计编辑次数（至2017年）: 1,656
#
# [300/421] 查询: Jamie Anderson (Season 26, Year 2018)
#   ✓ 找到页面: Jamie Anderson (snowboarder)
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 416,929
#   ✓ 累计编辑次数（至2018年）: 266
#
# [301/421] 查询: Johnny Damon (Season 26, Year 2018)
#   ✓ 找到页面: Johnny Damon
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 1,045,001
#   ✓ 累计编辑次数（至2018年）: 3,394
#
# [302/421] 查询: Kareem Abdul-Jabbar (Season 26, Year 2018)
#   ✓ 找到页面: Kareem Abdul-Jabbar
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 9,663,765
#   ✓ 累计编辑次数（至2018年）: 4,050
#
# [303/421] 查询: Arike Ogunbowale (Season 26, Year 2018)
#   ✓ 找到页面: Arike Ogunbowale
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 51,692
#   ✓ 累计编辑次数（至2018年）: 35
#
# [304/421] 查询: Jennie Finch Daigle (Season 26, Year 2018)
#   ✓ 找到页面: Jennie Finch
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 891,822
#   ✓ 累计编辑次数（至2018年）: 1,619
#
# [305/421] 查询: Chris Mazdzer (Season 26, Year 2018)
#   ✓ 找到页面: Chris Mazdzer
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 204,332
#   ✓ 累计编辑次数（至2018年）: 96
#
# [306/421] 查询: Mirai Nagasu (Season 26, Year 2018)
#   ✓ 找到页面: Mirai Nagasu
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 987,172
#   ✓ 累计编辑次数（至2018年）: 1,664
#
# [307/421] 查询: Tonya Harding (Season 26, Year 2018)
#   ✓ 找到页面: Tonya Harding
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 16,007,499
#   ✓ 累计编辑次数（至2018年）: 3,720
#
# [308/421] 查询: Josh Norman (Season 26, Year 2018)
#   ✓ 找到页面: Josh Norman
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 462,546
#   ✓ 累计编辑次数（至2018年）: 1,073
#
# [309/421] 查询: Adam Rippon (Season 26, Year 2018)
#   ✓ 找到页面: Adam Rippon
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 1,565,722
#   ✓ 累计编辑次数（至2018年）: 1,018
#
# [310/421] 查询: Juan Pablo Di Pace (Season 27, Year 2018)
#   ✓ 找到页面: Juan Pablo Di Pace
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 1,311,303
#   ✓ 累计编辑次数（至2018年）: 289
#
# [311/421] 查询: Evanna Lynch (Season 27, Year 2018)
#   ✓ 找到页面: Evanna Lynch
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 3,493,789
#   ✓ 累计编辑次数（至2018年）: 2,569
#
# [312/421] 查询: Nancy McKeon (Season 27, Year 2018)
#   ✓ 找到页面: Nancy McKeon
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 2,498,437
#   ✓ 累计编辑次数（至2018年）: 520
#
# [313/421] 查询: John Schneider (Season 27, Year 2018)
#   ✓ 找到页面: John Schneider (screen actor)
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 2,181,678
#   ✓ 累计编辑次数（至2018年）: 1,108
#
# [314/421] 查询: Milo Manheim (Season 27, Year 2018)
#   ✓ 找到页面: Milo Manheim
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 929,796
#   ✓ 累计编辑次数（至2018年）: 246
#
# [315/421] 查询: Danelle Umstead (Season 27, Year 2018)
#   ✓ 找到页面: Danelle Umstead
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 196,417
#   ✓ 累计编辑次数（至2018年）: 29
#
# [316/421] 查询: Mary Lou Retton (Season 27, Year 2018)
#   ✓ 找到页面: Mary Lou Retton
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 1,723,232
#   ✓ 累计编辑次数（至2018年）: 856
#
# [317/421] 查询: DeMarcus Ware (Season 27, Year 2018)
#   ✓ 找到页面: DeMarcus Ware
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 1,546,144
#   ✓ 累计编辑次数（至2018年）: 1,582
#
# [318/421] 查询: Nikki Glaser (Season 27, Year 2018)
#   ✓ 找到页面: Nikki Glaser
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 1,740,447
#   ✓ 累计编辑次数（至2018年）: 352
#
# [319/421] 查询: Bobby Bones (Season 27, Year 2018)
#   ✓ 找到页面: Bobby Bones
#     统计年份范围: 2005 - 2018
#   ✓ 累计浏览量（至2018年）: 1,077,734
# ...
#
# [328/421] 查询: Sailor Brinkley-Cook (Season 28, Year 2019)
#   ✓ 找到页面: Dancing with the Stars (American TV series)
#     统计年份范围: 2005 - 2019
#   ✓ 累计浏览量（至2019年）: 777,776
#   ✓ 累计编辑次数（至2019年）: 11,512
#
# [329/421] 查询: Sean Spicer (Season 28, Year 2019)
#   ✓ 找到页面: Sean Spicer
#     统计年份范围: 2005 - 2019
#   ✓ 累计浏览量（至2019年）: 6,040,841
#   ✓ 累计编辑次数（至2019年）: 1,198
#
# [330/421] 查询: Mary Wilson (Season 28, Year 2019)
#   ✓ 找到页面: Mary Wilson (singer)
#     统计年份范围: 2005 - 2019
#   ✓ 累计浏览量（至2019年）: 1,189,680
#   ✓ 累计编辑次数（至2019年）: 953
#
# [331/421] 查询: Lauren Alaina (Season 28, Year 2019)
#   ✓ 找到页面: Lauren Alaina
#     统计年份范围: 2005 - 2019
#   ✓ 累计浏览量（至2019年）: 2,069,451
#   ✓ 累计编辑次数（至2019年）: 2,524
#
# [332/421] 查询: Ally Brooke (Season 28, Year 2019)
#   ✓ 找到页面: Ally Brooke
#     统计年份范围: 2005 - 2019
#   ✓ 累计浏览量（至2019年）: 1,556,690
#   ✓ 累计编辑次数（至2019年）: 857
#
# [333/421] 查询: Karamo Brown (Season 28, Year 2019)
#   ✓ 找到页面: Karamo Brown
#     统计年份范围: 2005 - 2019
#   ✓ 累计浏览量（至2019年）: 3,344,522
#   ✓ 累计编辑次数（至2019年）: 220
#
# [334/421] 查询: Hannah Brown (Season 28, Year 2019)
#   ✓ 找到页面: Hannah Brown
#     统计年份范围: 2005 - 2019
#   ✓ 累计浏览量（至2019年）: 892,652
#   ✓ 累计编辑次数（至2019年）: 155
#
# [335/421] 查询: Anne Heche (Season 29, Year 2020)
#   ✓ 找到页面: Anne Heche
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 8,002,928
#   ✓ 累计编辑次数（至2020年）: 1,529
#
# [336/421] 查询: Jesse Metcalfe (Season 29, Year 2020)
#   ✓ 找到页面: Jesse Metcalfe
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 4,723,656
#   ✓ 累计编辑次数（至2020年）: 1,557
#
# [337/421] 查询: Chrishell Stause (Season 29, Year 2020)
#   ✓ 找到页面: Chrishell Stause
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 6,090,442
#   ✓ 累计编辑次数（至2020年）: 397
#
# [338/421] 查询: Skai Jackson (Season 29, Year 2020)
#   ✓ 找到页面: Jessie (2011 TV series)
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 2,271,809
#   ✓ 累计编辑次数（至2020年）: 4,829
#
# [339/421] 查询: Justina Machado (Season 29, Year 2020)
#   ✓ 找到页面: Justina Machado
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 2,713,720
#   ✓ 累计编辑次数（至2020年）: 479
#
# [340/421] 查询: Charles Oakley (Season 29, Year 2020)
#   ✓ 找到页面: Charles Oakley
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 2,270,092
#   ✓ 累计编辑次数（至2020年）: 643
#
# [341/421] 查询: Veron Davis (Season 29, Year 2020)
#   ✓ 找到页面: The Road from Home
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 19,526
#   ✓ 累计编辑次数（至2020年）: 51
#
# [342/421] 查询: Johnny Weir (Season 29, Year 2020)
#   ✓ 找到页面: Johnny Weir
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 4,182,347
#   ✓ 累计编辑次数（至2020年）: 2,376
#
# [343/421] 查询: Nev Schulman (Season 29, Year 2020)
#   ✓ 找到页面: Nev Schulman
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 3,642,965
#   ✓ 累计编辑次数（至2020年）: 487
#
# [344/421] 查询: AJ McLean (Season 29, Year 2020)
#   ✓ 找到页面: AJ McLean
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 2,670,583
#   ✓ 累计编辑次数（至2020年）: 1,571
#
# [345/421] 查询: Nelly (Season 29, Year 2020)
#   ✓ 找到页面: Nelly
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 5,993,633
#   ✓ 累计编辑次数（至2020年）: 5,763
#
# [346/421] 查询: Kaitlyn Bristowe (Season 29, Year 2020)
#   ✓ 找到页面: Kaitlyn Bristowe
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 1,993,083
#   ✓ 累计编辑次数（至2020年）: 250
#
# [347/421] 查询: Carole Baskin (Season 29, Year 2020)
#   ✓ 找到页面: Carole Baskin
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 8,957,891
#   ✓ 累计编辑次数（至2020年）: 429
#
# [348/421] 查询: Monica Aldama (Season 29, Year 2020)
#   ✓ 找到页面: Monica Aldama
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 410,498
#   ✓ 累计编辑次数（至2020年）: 57
#
# [349/421] 查询: Jeannie Mai (Season 29, Year 2020)
#   ✓ 找到页面: Jeannie Mai
#     统计年份范围: 2005 - 2020
#   ✓ 累计浏览量（至2020年）: 4,026,474
#   ✓ 累计编辑次数（至2020年）: 791
#
# [350/421] 查询: Martin Kove (Season 30, Year 2021)
#   ✓ 找到页面: Martin Kove
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 3,898,573
#   ✓ 累计编辑次数（至2021年）: 667
#
# [351/421] 查询: Brian Austin Green (Season 30, Year 2021)
#   ✓ 找到页面: Brian Austin Green
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 11,027,744
#   ✓ 累计编辑次数（至2021年）: 2,390
#
# [352/421] 查询: Melora Hardin (Season 30, Year 2021)
#   ✓ 找到页面: Melora Hardin
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 6,095,124
#   ✓ 累计编辑次数（至2021年）: 619
#
# [353/421] 查询: Matt James (Season 30, Year 2021)
#   ✓ 找到页面: Matt James (television personality)
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 681,146
#   ✓ 累计编辑次数（至2021年）: 117
#
# [354/421] 查询: Mike "The Miz" Mizanin (Season 30, Year 2021)
#   ✓ 找到页面: The Miz
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 8,605,558
#   ✓ 累计编辑次数（至2021年）: 13,433
#
# [355/421] 查询: Suni Lee (Season 30, Year 2021)
#   ✓ 找到页面: Dancing with the Stars (American TV series) season 30
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 0
#   ✓ 累计编辑次数（至2021年）: 2,072
#
# [356/421] 查询: Iman Shumpert (Season 30, Year 2021)
#   ✓ 找到页面: Iman Shumpert
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 5,162,844
#   ✓ 累计编辑次数（至2021年）: 1,602
#
# [357/421] 查询: Cody Rigsby (Season 30, Year 2021)
#   ✓ 找到页面: Cody (given name)
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 103,415
#   ✓ 累计编辑次数（至2021年）: 141
#
# [358/421] 查询: Melanie C (Season 30, Year 2021)
#   ✓ 找到页面: Melanie C
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 6,266,965
#   ✓ 累计编辑次数（至2021年）: 5,408
#
# [359/421] 查询: Jimmie Allen (Season 30, Year 2021)
#   ✓ 找到页面: Jimmie Allen
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 1,108,567
#   ✓ 累计编辑次数（至2021年）: 376
#
# [360/421] 查询: Olivia Jade (Season 30, Year 2021)
#   ✗ 查询失败: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Max retries exceeded with url: /w/api.php?list=search&srprop=&srlimit=5&limit=5&srsearch=Olivia+Jade&format=json&action=query (Caused by ProxyError('Unable to connect to proxy', RemoteDisconnected('Remote end closed connection without response')))
#
# [361/421] 查询: JoJo Siwa (Season 30, Year 2021)
#   ✓ 找到页面: Karma (JoJo Siwa song)
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 0
#   ✓ 累计编辑次数（至2021年）: 0
#
# [362/421] 查询: Christine Chiu (Season 30, Year 2021)
#   ✓ 找到页面: Dancing with the Stars (American TV series) season 30
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 0
#   ✓ 累计编辑次数（至2021年）: 2,072
#
# [363/421] 查询: Kenya Moore (Season 30, Year 2021)
#   ✓ 找到页面: Kenya Moore
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 2,869,046
#   ✓ 累计编辑次数（至2021年）: 1,204
#
# [364/421] 查询: Amanda Kloots (Season 30, Year 2021)
#   ✓ 找到页面: Amanda Kloots
#     统计年份范围: 2005 - 2021
#   ✓ 累计浏览量（至2021年）: 1,033,270
#   ✓ 累计编辑次数（至2021年）: 174
#
# [365/421] 查询: Jason Lewis (Season 31, Year 2022)
#   ✓ 找到页面: Jason Lewis (actor)
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 2,379,688
#   ✓ 累计编辑次数（至2022年）: 548
#
# [366/421] 查询: Cheryl Ladd (Season 31, Year 2022)
#   ✓ 找到页面: Cheryl Ladd
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 4,932,045
#   ✓ 累计编辑次数（至2022年）: 799
#
# [367/421] 查询: Selma Blair (Season 31, Year 2022)
#   ✓ 找到页面: Selma Blair
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 13,279,078
#   ✓ 累计编辑次数（至2022年）: 1,826
#
# [368/421] 查询: Joseph Baena (Season 31, Year 2022)
#   ✓ 找到页面: Joseph Baena
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 502,227
#   ✓ 累计编辑次数（至2022年）: 126
#
# [369/421] 查询: Trevor Donovan (Season 31, Year 2022)
#   ✓ 找到页面: Trevor Donovan
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 2,173,739
#   ✓ 累计编辑次数（至2022年）: 572
#
# [370/421] 查询: Daniel Durant (Season 31, Year 2022)
#   ✓ 找到页面: Daniel Durant
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 919,123
#   ✓ 累计编辑次数（至2022年）: 88
#
# [371/421] 查询: Wayne Brady (Season 31, Year 2022)
#   ✓ 找到页面: Wayne Brady
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 7,827,855
#   ✓ 累计编辑次数（至2022年）: 2,359
#
# [372/421] 查询: Sam Champion (Season 31, Year 2022)
#   ✓ 找到页面: Sam Champion
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 1,228,832
#   ✓ 累计编辑次数（至2022年）: 645
#
# [373/421] 查询: Jessie James Decker (Season 31, Year 2022)
#   ✓ 找到页面: Jessie James Decker
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 4,523,747
#   ✓ 累计编辑次数（至2022年）: 1,821
#
# [374/421] 查询: Jordin Sparks (Season 31, Year 2022)
#   ✓ 找到页面: Jordin Sparks
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 5,610,024
#   ✓ 累计编辑次数（至2022年）: 7,947
#
# [375/421] 查询: Heidi D'Amelio (Season 31, Year 2022)
#   ✓ 找到页面: Dancing with the Stars (American TV series)
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 2,219,664
#   ✓ 累计编辑次数（至2022年）: 10,253
#
# [376/421] 查询: Charli D'Amelio (Season 31, Year 2022)
#   ✓ 找到页面: Charli D'Amelio
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 11,941,670
#   ✓ 累计编辑次数（至2022年）: 1,251
#
# [377/421] 查询: Teresa Giudice (Season 31, Year 2022)
#   ✓ 找到页面: Teresa Giudice
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 4,260,795
#   ✓ 累计编辑次数（至2022年）: 819
#
# [378/421] 查询: Vinny Guadagnino (Season 31, Year 2022)
#   ✓ 找到页面: Vinny Guadagnino
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 3,326,054
#   ✓ 累计编辑次数（至2022年）: 550
#
# [379/421] 查询: Shangela (Season 31, Year 2022)
#   ✓ 找到页面: Shangela
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 1,163,000
#   ✓ 累计编辑次数（至2022年）: 868
#
# [380/421] 查询: Gabby Windey (Season 31, Year 2022)
#   ✓ 找到页面: Gabby Windey
#     统计年份范围: 2005 - 2022
#   ✓ 累计浏览量（至2022年）: 383,604
#   ✓ 累计编辑次数（至2022年）: 66
#
# [381/421] 查询: Jamie Lynn Spears (Season 32, Year 2023)
#   ✓ 找到页面: Jamie Lynn Spears
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 14,571,058
#   ✓ 累计编辑次数（至2023年）: 8,415
#
# [382/421] 查询: Mira Sorvino (Season 32, Year 2023)
#   ✓ 找到页面: Mira Sorvino
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 11,332,499
#   ✓ 累计编辑次数（至2023年）: 1,137
#
# [383/421] 查询: Barry Williams (Season 32, Year 2023)
#   ✓ 找到页面: Barry Williams (actor)
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 4,215,517
#   ✓ 累计编辑次数（至2023年）: 622
#
# [384/421] 查询: Alyson Hannigan (Season 32, Year 2023)
#   ✓ 找到页面: Alyson Hannigan
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 13,829,764
#   ✓ 累计编辑次数（至2023年）: 2,353
#
# [385/421] 查询: Xochitl Gomez (Season 32, Year 2023)
#   ✓ 找到页面: Xochitl Gomez
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 4,684,354
#   ✓ 累计编辑次数（至2023年）: 594
#
# [386/421] 查询: Adrian Peterson (Season 32, Year 2023)
#   ✓ 找到页面: Adrian Peterson
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 9,626,656
#   ✓ 累计编辑次数（至2023年）: 7,910
#
# [387/421] 查询: Matt Walsh (Season 32, Year 2023)
#   ✓ 找到页面: Matt Walsh (political commentator)
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 2,941,830
#   ✓ 累计编辑次数（至2023年）: 2,534
#
# [388/421] 查询: Tyson Beckford (Season 32, Year 2023)
#   ✓ 找到页面: Tyson Beckford
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 2,708,126
#   ✓ 累计编辑次数（至2023年）: 1,237
#
# [389/421] 查询: Jason Mraz (Season 32, Year 2023)
#   ✓ 找到页面: Jason Mraz
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 3,356,729
#   ✓ 累计编辑次数（至2023年）: 4,349
#
# [390/421] 查询: Lele Pons (Season 32, Year 2023)
#   ✓ 找到页面: Lele Pons
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 7,017,184
#   ✓ 累计编辑次数（至2023年）: 3,277
#
# [391/421] 查询: Harry Jowsey (Season 32, Year 2023)
#   ✓ 找到页面: Harry Jowsey
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 87,252
#   ✓ 累计编辑次数（至2023年）: 2
#
# [392/421] 查询: Mauricio Umansky (Season 32, Year 2023)
#   ✓ 找到页面: Mauricio Umansky
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 607,072
#   ✓ 累计编辑次数（至2023年）: 31
#
# [393/421] 查询: Charity Lawson (Season 32, Year 2023)
#   ✓ 找到页面: Joey Graziadei
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 35,960
#   ✓ 累计编辑次数（至2023年）: 19
#
# [394/421] 查询: Ariana Madix (Season 32, Year 2023)
#   ✓ 找到页面: Ariana Madix
#     统计年份范围: 2005 - 2023
#   ✓ 累计浏览量（至2023年）: 1,411,390
#   ✓ 累计编辑次数（至2023年）: 341
#
# [395/421] 查询: Tori Spelling (Season 33, Year 2024)
#   ✓ 找到页面: Tori Spelling
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 9,335,859
#   ✓ 累计编辑次数（至2024年）: 2,280
#
# [396/421] 查询: Eric Roberts (Season 33, Year 2024)
#   ✓ 找到页面: Eric Roberts
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 16,694,612
#   ✓ 累计编辑次数（至2024年）: 1,849
#
# [397/421] 查询: Reginald VelJohnson (Season 33, Year 2024)
#   ✓ 找到页面: Reginald VelJohnson
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 5,513,659
#   ✓ 累计编辑次数（至2024年）: 1,472
#
# [398/421] 查询: Chandler Kinney (Season 33, Year 2024)
#   ✓ 找到页面: Chandler Kinney
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 0
#   ✓ 累计编辑次数（至2024年）: 62
#
# [399/421] 查询: Dwight Howard  (Season 33, Year 2024)
#   ✓ 找到页面: Dwight Howard
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 15,773,500
#   ✓ 累计编辑次数（至2024年）: 4,565
#
# [400/421] 查询: Danny Amendola (Season 33, Year 2024)
#   ✓ 找到页面: Danny Amendola
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 6,931,269
#   ✓ 累计编辑次数（至2024年）: 1,824
#
# [401/421] 查询: Stephen Nedoroscik (Season 33, Year 2024)
#   ✓ 找到页面: Stephen Nedoroscik
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 1,362,723
#   ✓ 累计编辑次数（至2024年）: 368
#
# [402/421] 查询: Ilona Maher (Season 33, Year 2024)
#   ✓ 找到页面: Ilona Maher
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 2,855,783
#   ✓ 累计编辑次数（至2024年）: 217
#
# [403/421] 查询: Anna Delvey (Season 33, Year 2024)
#   ✓ 找到页面: Anna Delvey
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 2,047,323
#   ✓ 累计编辑次数（至2024年）: 1,551
#
# [404/421] 查询: Brooks Nader (Season 33, Year 2024)
#   ✓ 找到页面: Brooks Nader
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 726,152
#   ✓ 累计编辑次数（至2024年）: 83
#
# [405/421] 查询: Phaedra Parks (Season 33, Year 2024)
#   ✓ 找到页面: Phaedra Parks
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 1,239,419
#   ✓ 累计编辑次数（至2024年）: 225
#
# [406/421] 查询: Jenn Tran (Season 33, Year 2024)
#   ✓ 找到页面: Jenn Tran
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 503,683
#   ✓ 累计编辑次数（至2024年）: 45
#
# [407/421] 查询: Joey Graziadei (Season 33, Year 2024)
#   ✓ 找到页面: Joey Graziadei
#     统计年份范围: 2005 - 2024
#   ✓ 累计浏览量（至2024年）: 996,713
#   ✓ 累计编辑次数（至2024年）: 99
#
# [408/421] 查询: Corey Feldman (Season 34, Year 2025)
#   ✓ 找到页面: Corey Feldman
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 20,796,521
#   ✓ 累计编辑次数（至2025年）: 3,402
#
# [409/421] 查询: Danielle Fishel (Season 34, Year 2025)
#   ✓ 找到页面: Danielle Fishel
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 8,968,026
#   ✓ 累计编辑次数（至2025年）: 1,952
#
# [410/421] 查询: Elaine Hendrix (Season 34, Year 2025)
#   ✓ 找到页面: Elaine Hendrix
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 4,863,926
#   ✓ 累计编辑次数（至2025年）: 602
#
# [411/421] 查询: Baron Davis (Season 34, Year 2025)
#   ✓ 找到页面: Baron Davis
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 3,439,142
#   ✓ 累计编辑次数（至2025年）: 2,696
#
# [412/421] 查询: Jordan Chiles (Season 34, Year 2025)
#   ✓ 找到页面: Jordan Chiles
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 3,014,532
#   ✓ 累计编辑次数（至2025年）: 681
#
# [413/421] 查询: Andy Richter (Season 34, Year 2025)
#   ✓ 找到页面: Andy Richter
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 4,659,901
#   ✓ 累计编辑次数（至2025年）: 1,188
#
# [414/421] 查询: Robert Irwin (Season 34, Year 2025)
#   ✓ 找到页面: Robert Irwin (conservationist)
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 665,623
#   ✓ 累计编辑次数（至2025年）: 939
#
# [415/421] 查询: Hilaria Baldwin (Season 34, Year 2025)
#   ✓ 找到页面: Hilaria Baldwin
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 9,481,777
#   ✓ 累计编辑次数（至2025年）: 991
#
# [416/421] 查询: Lauren Jauregui (Season 34, Year 2025)
#   ✓ 找到页面: Lauren Jauregui
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 5,220,654
#   ✓ 累计编辑次数（至2025年）: 2,069
#
# [417/421] 查询: Scott Hoying (Season 34, Year 2025)
#   ✓ 找到页面: Scott Hoying
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 1,941,034
#   ✓ 累计编辑次数（至2025年）: 353
#
# [418/421] 查询: Alix Earle (Season 34, Year 2025)
#   ✓ 找到页面: Alix Earle
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 4,371,756
#   ✓ 累计编辑次数（至2025年）: 325
#
# [419/421] 查询: Jen Affleck (Season 34, Year 2025)
#   ✓ 找到页面: Jan Ravnik
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 77,361
#   ✓ 累计编辑次数（至2025年）: 29
#
# [420/421] 查询: Whitney Leavitt (Season 34, Year 2025)
#   ✓ 找到页面: Whitney Leavitt
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 128,658
#   ✓ 累计编辑次数（至2025年）: 35
#
# [421/421] 查询: Dylan Efron (Season 34, Year 2025)
#   ✓ 找到页面: Dylan Efron
#     统计年份范围: 2005 - 2025
#   ✓ 累计浏览量（至2025年）: 1,414,174
#   ✓ 累计编辑次数（至2025年）: 84
#
# ============================================================
# 查询完成！结果已保存到: celebrity_wikipedia_stats.csv
# ============================================================
#
# 成功查询: 420 个
# 失败查询: 1 个
#
# 结果预览:
#       celebrity_name  year          wikipedia_title  total_pageviews  \
# 0      John O'Hurley  2005            John O'Hurley                0
# 1       Kelly Monaco  2005             Kelly Monaco                0
# 2  Evander Holyfield  2005        Evander Holyfield                0
# 3      Rachel Hunter  2005            Rachel Hunter                0
# 4      Joey McIntyre  2005            Joey McIntyre                0
# 5      Trista Sutter  2005            Trista Sutter                0
# 6       Tatum O'Neal  2006             Tatum O'Neal                0
# 7        Tia Carrere  2006              Tia Carrere                0
# 8    George Hamilton  2006  George Hamilton (actor)                0
# 9         Lisa Rinna  2006               Lisa Rinna                0
#
#    total_edits
# 0           49
# 1          114
# 2           47
# 3           24
# 4           31
# 5           39
# 6          118
# 7          167
# 8          109
# 9          129

# %%
import pandas as pd
import requests
import time
from urllib.parse import unquote, quote
from datetime import datetime

# 读取CSV文件
df = pd.read_csv('celebrity_wikipedia_stats1.csv')

# 找到编辑次数为0的行，需要重新查询
edited_rows = df[df['total_edits'] == 0].copy()

print(f"找到 {len(edited_rows)} 行编辑次数为0的数据，需要重新处理\n")
print("需要重新处理的名人:")
for idx, row in edited_rows.iterrows():
    print(f"  - {row['celebrity_name']} (Year {row['year']}, URL: {row['wikipedia_url']})")
print()

def extract_page_title_from_url(url):
    """
    从Wikipedia URL中提取页面标题
    """
    if pd.isna(url) or url == '':
        return None
    try:
        # 提取URL中的页面标题部分
        # 例如: https://en.wikipedia.org/wiki/Giselle_Fern%C3%A1ndez
        parts = url.split('/wiki/')
        if len(parts) > 1:
            title = unquote(parts[-1])
            return title
    except:
        pass
    return None

def get_yearly_pageviews(page_title, year):
    """
    获取某 Wikipedia 页面在某一年的总浏览量
    """
    try:
        page_title_encoded = page_title.replace(" ", "_")
        page_title_encoded = quote(page_title_encoded, safe="")
        
        url = (
            "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/"
            f"en.wikipedia.org/all-access/all-agents/"
            f"{page_title_encoded}/monthly/"
            f"{year}0101/{year}1231"
        )
        
        headers = {
            "User-Agent": "Academic-Research-Bot/1.0"
        }
        
        r = requests.get(url, headers=headers, timeout=10)
        
        if r.status_code != 200:
            return 0
        
        items = r.json().get("items", [])
        return sum(item["views"] for item in items)
    except Exception as e:
        return 0

def get_yearly_edit_count(page_title, year):
    """
    使用Wikipedia API获取某 Wikipedia 页面在某一年的编辑次数
    """
    try:
        url = "https://en.wikipedia.org/w/api.php"
        
        start = f"{year}-01-01T00:00:00Z"
        end = f"{year}-12-31T23:59:59Z"
        
        params = {
            "action": "query",
            "format": "json",
            "prop": "revisions",
            "titles": page_title,
            "rvstart": end,
            "rvend": start,
            "rvlimit": "max",
            "rvprop": "timestamp"
        }
        
        headers = {
            "User-Agent": "Academic-Research-Bot/1.0"
        }
        
        total_edits = 0
        
        while True:
            r = requests.get(url, params=params, headers=headers, timeout=10)
            data = r.json()
            
            if "query" not in data or "pages" not in data["query"]:
                break
                
            pages = data["query"]["pages"]
            if not pages:
                break
                
            page_data = next(iter(pages.values()))
            
            if "missing" in page_data:
                return 0
            
            if "revisions" in page_data:
                revisions = page_data["revisions"]
                year_edits = 0
                for rev in revisions:
                    if "timestamp" in rev:
                        timestamp = rev["timestamp"]
                        if timestamp.startswith(str(year)):
                            year_edits += 1
                total_edits += year_edits
            
            if "continue" in data:
                params.update(data["continue"])
            else:
                break
        
        return total_edits
    except Exception as e:
        return 0

def get_cumulative_stats(page_title, target_year):
    """
    获取页面在target_year及之前所有年份的累计浏览量和编辑次数
    """
    total_pageviews = 0
    total_edits = 0
    
    start_year = 2005
    current_year = datetime.now().year
    end_year = min(target_year, current_year)
    
    for year in range(start_year, end_year + 1):
        year_views = get_yearly_pageviews(page_title, year)
        year_edits = get_yearly_edit_count(page_title, year)
        
        total_pageviews += year_views
        total_edits += year_edits
        
        time.sleep(0.3)
    
    return total_pageviews, total_edits

# 处理每一行标注了"edited"的数据
for idx, row in edited_rows.iterrows():
    celebrity_name = row['celebrity_name']
    year = row['year']
    wikipedia_url = row['wikipedia_url']
    
    print(f"[{list(edited_rows.index).index(idx)+1}/{len(edited_rows)}] 重新处理: {celebrity_name} (Year {year})")
    
    # 从URL中提取页面标题
    page_title = extract_page_title_from_url(wikipedia_url)
    
    if not page_title:
        print(f"  ✗ 无法从URL提取页面标题: {wikipedia_url}")
        continue
    
    print(f"  ✓ 提取的页面标题: {page_title}")
    
    # 重新计算浏览量和编辑次数
    try:
        total_pageviews, total_edits = get_cumulative_stats(page_title, year)
        
        print(f"  ✓ 累计浏览量（至{year}年）: {total_pageviews:,}")
        print(f"  ✓ 累计编辑次数（至{year}年）: {total_edits:,}\n")
        
        # 更新DataFrame中的值
        df.loc[idx, 'total_pageviews'] = total_pageviews
        df.loc[idx, 'total_edits'] = total_edits
        df.loc[idx, 'wikipedia_title'] = page_title
        df.loc[idx, 'status'] = 'Success'
        
        time.sleep(1)
        
    except Exception as e:
        print(f"  ✗ 处理失败: {str(e)}\n")

# 保存更新后的CSV文件
df.to_csv('celebrity_wikipedia_stats1.csv', index=False, encoding='utf-8-sig')

print("=" * 60)
print("重新处理完成！结果已更新到: celebrity_wikipedia_stats1.csv")
print("=" * 60)
print("\n更新后的数据预览（仅显示重新处理的行）:")
updated_rows = df.loc[edited_rows.index, ['celebrity_name', 'year', 'wikipedia_title', 'total_pageviews', 'total_edits']]
print(updated_rows)
# Out:
# 找到 14 行需要重新处理的数据
#
# 需要重新处理的名人:
#   - Giselle Fernandez (Year 2006)
#   - Cristian de la Fuente (Year 2008)
#   - Mario (Year 2008)
#   - Maurice Greene (Year 2008)
#   - Jeffrey Ross (Year 2008)
#   - Ashley Hamiliton (Year 2009)
#   - Chad Ochocinco (Year 2010)
#   - Metta World Peace (Ron) (Year 2011)
#   - Sherri Sheperd (Year 2012)
#   - Alexandra Raisman (Year 2013)
#   - Barbara Corcoran (Year 2017)
#   - Suni Lee (Year 2021)
#   - Olivia Jade (Year 2021)
#   - JoJo Siwa (Year 2021)
#
# [1/14] 重新处理: Giselle Fernandez (Year 2006)
#   ✓ 提取的页面标题: Giselle_Fernández
#   ✓ 累计浏览量（至2006年）: 0
#   ✓ 累计编辑次数（至2006年）: 48
#
# [2/14] 重新处理: Cristian de la Fuente (Year 2008)
#   ✓ 提取的页面标题: Cristián_de_la_Fuente
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 173
#
# [3/14] 重新处理: Mario (Year 2008)
#   ✓ 提取的页面标题: Mario_(American_singer)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 1,804
#
# [4/14] 重新处理: Maurice Greene (Year 2008)
#   ✓ 提取的页面标题: Maurice_Greene_(sprinter)
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 349
#
# [5/14] 重新处理: Jeffrey Ross (Year 2008)
#   ✓ 提取的页面标题: Jeffrey_Ross_Gunter
#   ✓ 累计浏览量（至2008年）: 0
#   ✓ 累计编辑次数（至2008年）: 0
#
# [6/14] 重新处理: Ashley Hamiliton (Year 2009)
#   ✓ 提取的页面标题: Ashley_Hamilton
#   ✓ 累计浏览量（至2009年）: 0
#   ✓ 累计编辑次数（至2009年）: 69
#
# [7/14] 重新处理: Chad Ochocinco (Year 2010)
#   ✓ 提取的页面标题: Chad_Johnson
#   ✓ 累计浏览量（至2010年）: 0
#   ✓ 累计编辑次数（至2010年）: 3,251
#
# [8/14] 重新处理: Metta World Peace (Ron) (Year 2011)
#   ✓ 提取的页面标题: Metta_Sandiford-Artest
#   ✓ 累计浏览量（至2011年）: 0
#   ✓ 累计编辑次数（至2011年）: 2,658
#
# [9/14] 重新处理: Sherri Sheperd (Year 2012)
#   ✓ 提取的页面标题: Sherri_Shepherd
#   ✓ 累计浏览量（至2012年）: 0
#   ✓ 累计编辑次数（至2012年）: 1,175
#
# [10/14] 重新处理: Alexandra Raisman (Year 2013)
#   ✓ 提取的页面标题: Aly_Raisman
#   ✓ 累计浏览量（至2013年）: 0
#   ✓ 累计编辑次数（至2013年）: 837
#
# [11/14] 重新处理: Barbara Corcoran (Year 2017)
#   ✓ 提取的页面标题: Barbara_Corcoran
#   ✓ 累计浏览量（至2017年）: 2,278,009
#   ✓ 累计编辑次数（至2017年）: 311
#
# [12/14] 重新处理: Suni Lee (Year 2021)
#   ✓ 提取的页面标题: Sunisa_Lee
#   ✓ 累计浏览量（至2021年）: 2,456,822
#   ✓ 累计编辑次数（至2021年）: 508
#
# [13/14] 重新处理: Olivia Jade (Year 2021)
#   ✓ 提取的页面标题: Olivia_Jade
#   ✓ 累计浏览量（至2021年）: 2,139,709
#   ✓ 累计编辑次数（至2021年）: 594
#
# [14/14] 重新处理: JoJo Siwa (Year 2021)
#   ✓ 提取的页面标题: JoJo_Siwa
#   ✓ 累计浏览量（至2021年）: 15,338,110
#   ✓ 累计编辑次数（至2021年）: 1,196
#
# ============================================================
# 重新处理完成！结果已更新到: celebrity_wikipedia_stats1.csv
# ============================================================
#
# 更新后的数据预览（仅显示重新处理的行）:
#               celebrity_name  year            wikipedia_title  \
# 12         Giselle Fernandez  2006          Giselle_Fernández
# 50     Cristian de la Fuente  2008      Cristián_de_la_Fuente
# 61                     Mario  2008    Mario_(American_singer)
# 67            Maurice Greene  2008  Maurice_Greene_(sprinter)
# 69              Jeffrey Ross  2008        Jeffrey_Ross_Gunter
# 88          Ashley Hamiliton  2009            Ashley_Hamilton
# 108           Chad Ochocinco  2010               Chad_Johnson
# 142  Metta World Peace (Ron)  2011     Metta_Sandiford-Artest
# 152           Sherri Sheperd  2012            Sherri_Shepherd
# 179        Alexandra Raisman  2013                Aly_Raisman
# 293         Barbara Corcoran  2017           Barbara_Corcoran
# 354                 Suni Lee  2021                 Sunisa_Lee
# 359              Olivia Jade  2021                Olivia_Jade
# 360                JoJo Siwa  2021                  JoJo_Siwa
#
#      total_pageviews  total_edits
# 12                 0           48
# 50                 0          173
# 61                 0         1804
# 67                 0          349
# 69                 0            0
# 88                 0           69
# 108                0         3251
# 142                0         2658
# 152                0         1175
# 179                0          837
# 293          2278009          311
# 354          2456822          508
# 359          2139709          594
# 360         15338110         1196
